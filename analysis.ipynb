# %% [markdown]
# ## LFPL libraries collection
#
# Louisville Free Public Library has a number of datasets published on their Open Data website.
# One of them is the book inventory. The primary goal is to enrich that dataset with information gathered from APIs.

# %%
# LFPL's collection inventory. Updated on a monthly basis.
import pandas as pd

lfpl_books = pd.read_csv('https://www.arcgis.com/sharing/rest/content/items/372216992aea4b2cb5b02837d7a48eaf/data')
lfpl_books
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1674146  2654219                                Emma of 83rd Street
# 1674147  2654219                                Emma of 83rd Street
# 1674148  2654219                                Emma of 83rd Street
# 1674149  2654220                                      The Sea Witch
# 1674150  2654221                          Murder with Earl Grey Tea
#
#                        Author          ISBN  PublicationYear    ItemType  \
# 0         Magee, David, 1965-  9.780072e+12             2009        Book
# 1        Miller, Robin, 1964-  9.780307e+12             2009        Book
# 2        Miller, Robin, 1964-  9.780307e+12             2009        Book
# 3        Miller, Robin, 1964-  9.780307e+12             2009        Book
# 4        Miller, Robin, 1964-  9.780307e+12             2009        Book
# ...                       ...           ...              ...         ...
# 1674146        Harding, Emily  9.781797e+12             2023  Eaudiobook
# 1674147        Harding, Emily  9.781797e+12             2023  Eaudiobook
# 1674148        Harding, Emily  9.781797e+12             2023  Eaudiobook
# 1674149         Robert, Katee  9.781951e+12             2020  Eaudiobook
# 1674150     Smith, Karen Rose  9.781497e+12             2023       Ebook
#
#             ItemCollection            ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                    Main      25.95
# 1        Adult Non-Fiction               Southwest      19.99
# 2        Adult Non-Fiction               Southwest      19.99
# 3        Adult Non-Fiction  Remote Shelving - Main      19.99
# 4        Adult Non-Fiction  Remote Shelving - Main      19.99
# ...                    ...                     ...        ...
# 1674146         Electronic                    Main       0.00
# 1674147         Electronic                    Main       0.00
# 1674148         Electronic                    Main       0.00
# 1674149         Electronic                    Main       0.00
# 1674150         Electronic                    Main       0.00
#
#                   ReportDate
# 0        06/01/2023 00:00:00
# 1        06/01/2023 00:00:00
# 2        06/01/2023 00:00:00
# 3        06/01/2023 00:00:00
# 4        06/01/2023 00:00:00
# ...                      ...
# 1674146  06/01/2023 00:00:00
# 1674147  06/01/2023 00:00:00
# 1674148  06/01/2023 00:00:00
# 1674149  06/01/2023 00:00:00
# 1674150  06/01/2023 00:00:00
#
# [1674151 rows x 10 columns]

# %%
shape = lfpl_books.shape
print(f"Rows: {shape[0]:,}, Columns: {shape[1]}")
# Out:
# Rows: 1,674,151, Columns: 10

# %% [markdown]
# This is a pretty large dataset.
# We need to do some cleaning first.

# %%
# Leaving only Books in the dataframe
lfpl_books = lfpl_books[lfpl_books['ItemType'] == 'Book']
lfpl_books
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1674140  2654213                                 The Saracen's mark
# 1674141  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1674142  2654215  The maid, the man, and the fans: Elivis is the...
# 1674143  2654216  The monstrous-feminine: film, feminism, psycho...
# 1674144  2654217  Common snese religion: a guide for renewing yo...
#
#                             Author          ISBN  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9.780072e+12             2009     Book
# 1             Miller, Robin, 1964-  9.780307e+12             2009     Book
# 2             Miller, Robin, 1964-  9.780307e+12             2009     Book
# 3             Miller, Robin, 1964-  9.780307e+12             2009     Book
# 4             Miller, Robin, 1964-  9.780307e+12             2009     Book
# ...                            ...           ...              ...      ...
# 1674140                  Perry, SW           NaN                0     Book
# 1674141              Boucher, Mark           NaN                0     Book
# 1674142  Rooks, Nancy; Gutter, Mae           NaN                0     Book
# 1674143             Creed, Barbara           NaN                0     Book
# 1674144               Mann, Gerald           NaN                0     Book
#
#             ItemCollection            ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                    Main      25.95
# 1        Adult Non-Fiction               Southwest      19.99
# 2        Adult Non-Fiction               Southwest      19.99
# 3        Adult Non-Fiction  Remote Shelving - Main      19.99
# 4        Adult Non-Fiction  Remote Shelving - Main      19.99
# ...                    ...                     ...        ...
# 1674140  Interlibrary Loan                    Main       0.00
# 1674141  Interlibrary Loan                    Main       0.00
# 1674142  Interlibrary Loan                    Main       0.00
# 1674143  Interlibrary Loan                    Main       0.00
# 1674144  Interlibrary Loan                    Main       0.00
#
#                   ReportDate
# 0        06/01/2023 00:00:00
# 1        06/01/2023 00:00:00
# 2        06/01/2023 00:00:00
# 3        06/01/2023 00:00:00
# 4        06/01/2023 00:00:00
# ...                      ...
# 1674140  06/01/2023 00:00:00
# 1674141  06/01/2023 00:00:00
# 1674142  06/01/2023 00:00:00
# 1674143  06/01/2023 00:00:00
# 1674144  06/01/2023 00:00:00
#
# [1184052 rows x 10 columns]

# %%
# Finding how many NaN values per column
lfpl_books.isna().sum()
# Out:
# BibNum                 0
# Title                  1
# Author             65316
# ISBN               36002
# PublicationYear        0
# ItemType               0
# ItemCollection       188
# ItemLocation           0
# ItemPrice              0
# ReportDate             0
# dtype: int64

# %%
# Drop rows with missing values in the 'Title' column
lfpl_books = lfpl_books.dropna(subset=['Title'])
lfpl_books.loc[lfpl_books['Title'].isna() ]
# Out:
# Empty DataFrame
# Columns: [BibNum, Title, Author, ISBN, PublicationYear, ItemType, ItemCollection, ItemLocation, ItemPrice, ReportDate]
# Index: []

# %%
# Looking for missing author and ISBN
lfpl_books.loc[(lfpl_books['Author'].isna()) & (lfpl_books['ISBN'].isna())]
# Out:
#           BibNum                                  Title Author  ISBN  \
# 17100    1375916                                 Laptop    NaN   NaN
# 17101    1375916                                 Laptop    NaN   NaN
# 17102    1375916                                 Laptop    NaN   NaN
# 17103    1375916                                 Laptop    NaN   NaN
# 17104    1375916                                 Laptop    NaN   NaN
# ...          ...                                    ...    ...   ...
# 1669175  2647142           Little elephant's big heart.    NaN   NaN
# 1671387  2647603            Why the Dutch are Different    NaN   NaN
# 1672187  2646832              The Saga of Gosta Berling    NaN   NaN
# 1673882  2650013             highlights into the future    NaN   NaN
# 1673883  2650014  KOREA the land the people the culture    NaN   NaN
#
#          PublicationYear ItemType         ItemCollection   ItemLocation  \
# 17100                  0     Book                 Laptop  South Central
# 17101                  0     Book                 Laptop  South Central
# 17102                  0     Book                 Laptop           Main
# 17103                  0     Book                 Laptop           Main
# 17104                  0     Book                 Laptop           Main
# ...                  ...      ...                    ...            ...
# 1669175             2017     Book  Children's Board Book  Jeffersontown
# 1671387                0     Book                    NaN      Southwest
# 1672187             2006     Book              Adult DVD           Main
# 1673882                0     Book                    NaN  Crescent Hill
# 1673883                0     Book                    NaN        Shively
#
#          ItemPrice           ReportDate
# 17100      1077.00  06/01/2023 00:00:00
# 17101      1077.00  06/01/2023 00:00:00
# 17102       900.31  06/01/2023 00:00:00
# 17103       900.31  06/01/2023 00:00:00
# 17104       900.31  06/01/2023 00:00:00
# ...            ...                  ...
# 1669175       5.99  06/01/2023 00:00:00
# 1671387       0.00  06/01/2023 00:00:00
# 1672187      74.19  06/01/2023 00:00:00
# 1673882       0.00  06/01/2023 00:00:00
# 1673883       0.00  06/01/2023 00:00:00
#
# [6721 rows x 10 columns]

# %% [markdown]
# Apparently the Laptops are included as books in this dataset.

# %%
lfpl_books[lfpl_books['Title'] == 'Laptop']
# Out:
#         BibNum   Title Author  ISBN  PublicationYear ItemType ItemCollection  \
# 17100  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17101  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17102  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17103  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17104  1375916  Laptop    NaN   NaN                0     Book         Laptop
# ...        ...     ...    ...   ...              ...      ...            ...
# 17197  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17198  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17199  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17200  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17201  1375916  Laptop    NaN   NaN                0     Book         Laptop
#
#         ItemLocation  ItemPrice           ReportDate
# 17100  South Central    1077.00  06/01/2023 00:00:00
# 17101  South Central    1077.00  06/01/2023 00:00:00
# 17102           Main     900.31  06/01/2023 00:00:00
# 17103           Main     900.31  06/01/2023 00:00:00
# 17104           Main     900.31  06/01/2023 00:00:00
# ...              ...        ...                  ...
# 17197  South Central    1077.00  06/01/2023 00:00:00
# 17198  South Central    1077.00  06/01/2023 00:00:00
# 17199  South Central    1077.00  06/01/2023 00:00:00
# 17200  South Central    1077.00  06/01/2023 00:00:00
# 17201  South Central    1077.00  06/01/2023 00:00:00
#
# [102 rows x 10 columns]

# %%
# Dropping all the laptops from the dataset
lfpl_books = lfpl_books.loc[lfpl_books['Title'] != 'Laptop']
lfpl_books[lfpl_books['Title'] == 'Laptop']
# Out:
# Empty DataFrame
# Columns: [BibNum, Title, Author, ISBN, PublicationYear, ItemType, ItemCollection, ItemLocation, ItemPrice, ReportDate]
# Index: []

# %%
# Looking for missing author and ISBN again
lfpl_books.loc[(lfpl_books['Author'].isna()) & (lfpl_books['ISBN'].isna())]
# Out:
#           BibNum                                            Title Author  \
# 29568    1393469  HAUNTED ENCOUNTERS: DEPARTED FAMILY AND FRIENDS    NaN
# 31413    1395055                         Chengdu : the real China    NaN
# 31414    1395055                         Chengdu : the real China    NaN
# 31415    1395055                         Chengdu : the real China    NaN
# 31585    1395581                              Women of Job Corps.    NaN
# ...          ...                                              ...    ...
# 1669175  2647142                     Little elephant's big heart.    NaN
# 1671387  2647603                      Why the Dutch are Different    NaN
# 1672187  2646832                        The Saga of Gosta Berling    NaN
# 1673882  2650013                       highlights into the future    NaN
# 1673883  2650014            KOREA the land the people the culture    NaN
#
#          ISBN  PublicationYear ItemType         ItemCollection  \
# 29568     NaN                0     Book                    NaN
# 31413     NaN             2012     Book      Adult Non-Fiction
# 31414     NaN             2012     Book      Adult Non-Fiction
# 31415     NaN             2012     Book      Adult Non-Fiction
# 31585     NaN             2016     Book   Government Documents
# ...       ...              ...      ...                    ...
# 1669175   NaN             2017     Book  Children's Board Book
# 1671387   NaN                0     Book                    NaN
# 1672187   NaN             2006     Book              Adult DVD
# 1673882   NaN                0     Book                    NaN
# 1673883   NaN                0     Book                    NaN
#
#                    ItemLocation  ItemPrice           ReportDate
# 29568                   Bon Air       0.00  06/01/2023 00:00:00
# 31413    Remote Shelving - Main      15.00  06/01/2023 00:00:00
# 31414    Remote Shelving - Main      15.00  06/01/2023 00:00:00
# 31415    Remote Shelving - Main      15.00  06/01/2023 00:00:00
# 31585                      Main      25.00  06/01/2023 00:00:00
# ...                         ...        ...                  ...
# 1669175           Jeffersontown       5.99  06/01/2023 00:00:00
# 1671387               Southwest       0.00  06/01/2023 00:00:00
# 1672187                    Main      74.19  06/01/2023 00:00:00
# 1673882           Crescent Hill       0.00  06/01/2023 00:00:00
# 1673883                 Shively       0.00  06/01/2023 00:00:00
#
# [6619 rows x 10 columns]

# %%
# Checking on the ItemCollection column
lfpl_books['ItemCollection'].value_counts()
# Out:
# ItemCollection
# Adult Non-Fiction                          370233
# Adult Fiction                              177792
# Children's Non-Fiction                      84497
# Children's Picture Book                     59912
# Mystery                                     59599
# Preschool  Picture Book                     51591
# Children's Fiction                          47801
# Children's Paperback                        45024
# Adult Paperback                             42702
# Teen Non-Fiction                            24377
# Children's Easy Reader                      24251
# Older Teen Fiction                          23996
# Children's Board Book                       20010
# Younger Teen  Fiction                       17699
# Kentucky History                            16925
# Children's Easy Reader Paperback            15945
# Science Fiction                             15935
# International Collection                    15923
# Holiday                                     15419
# Adult Reference                             11180
# Children's Picture Paperback                 9836
# Urban Fiction                                7605
# Caldecott/Newbery                            6762
# Storytime Collection                         4068
# Government Documents                         3273
# Oversize                                     2293
# Western                                      2077
# Bestsellers                                  1920
# ELL Collection                               1824
# Natural Resources                            1506
# Adult Paperbacks Tall                         742
# Children's Reference                          536
# Interlibrary Loan                             174
# Big Book                                       92
# Children's Non-Fiction Paperback               68
# Large Print                                    61
# Readalongs                                     37
# College Shop                                   18
# Listening Device                               16
# Teen Reference                                  8
# Telereference                                   7
# Younger Teen  Audiobook                         6
# Magazines and Newspaper                         5
# Adult DVD                                       4
# Electronic                                      3
# Children's Music                                3
# Adult Audiobook                                 2
# Music                                           2
# Younger Teen  Paperback                         1
# Book Discussion Kit                             1
# College and Career Connection Reference         1
# Name: count, dtype: int64

# %%
# Specific collections that are not relevant
item_collections = ['Listening Device','Magazines and Newspaper','Adult DVD']
lfpl_books[lfpl_books['ItemCollection'].isin(item_collections)]
# Out:
#           BibNum                                              Title Author  \
# 348739    517726  Index to Best of Popular Music (BPM) (1972 - 1...    NaN
# 773139    939977                            Induction Loop Receiver    NaN
# 773140    939977                            Induction Loop Receiver    NaN
# 773141    939977                            Induction Loop Receiver    NaN
# 773142    939977                            Induction Loop Receiver    NaN
# 773143    939977                            Induction Loop Receiver    NaN
# 773144    939977                            Induction Loop Receiver    NaN
# 773145    939977                            Induction Loop Receiver    NaN
# 773146    939977                            Induction Loop Receiver    NaN
# 773147    939977                            Induction Loop Receiver    NaN
# 773148    939977                            Induction Loop Receiver    NaN
# 773149    939977                            Induction Loop Receiver    NaN
# 773150    939977                            Induction Loop Receiver    NaN
# 773151    939977                            Induction Loop Receiver    NaN
# 773152    939977                            Induction Loop Receiver    NaN
# 773153    939977                            Induction Loop Receiver    NaN
# 773154    939977                            Induction Loop Receiver    NaN
# 1246358  2087356                             Black Scene Millennium    NaN
# 1246359  2087356                             Black Scene Millennium    NaN
# 1246360  2087356                             Black Scene Millennium    NaN
# 1246361  2087356                             Black Scene Millennium    NaN
# 1333236  2650082                                        The rapture    NaN
# 1467895  2224778              A touch of Frost: the complete series    NaN
# 1582182  2632235                                       The visitors    NaN
# 1672187  2646832                          The Saga of Gosta Berling    NaN
#
#          ISBN  PublicationYear ItemType           ItemCollection  \
# 348739    NaN                0     Book  Magazines and Newspaper
# 773139    NaN                0     Book         Listening Device
# 773140    NaN                0     Book         Listening Device
# 773141    NaN                0     Book         Listening Device
# 773142    NaN                0     Book         Listening Device
# 773143    NaN                0     Book         Listening Device
# 773144    NaN                0     Book         Listening Device
# 773145    NaN                0     Book         Listening Device
# 773146    NaN                0     Book         Listening Device
# 773147    NaN                0     Book         Listening Device
# 773148    NaN                0     Book         Listening Device
# 773149    NaN                0     Book         Listening Device
# 773150    NaN                0     Book         Listening Device
# 773151    NaN                0     Book         Listening Device
# 773152    NaN                0     Book         Listening Device
# 773153    NaN                0     Book         Listening Device
# 773154    NaN                0     Book         Listening Device
# 1246358   NaN             2020     Book  Magazines and Newspaper
# 1246359   NaN             2020     Book  Magazines and Newspaper
# 1246360   NaN             2020     Book  Magazines and Newspaper
# 1246361   NaN             2020     Book  Magazines and Newspaper
# 1333236   NaN                0     Book                Adult DVD
# 1467895   NaN             2013     Book                Adult DVD
# 1582182   NaN             2001     Book                Adult DVD
# 1672187   NaN             2006     Book                Adult DVD
#
#           ItemLocation  ItemPrice           ReportDate
# 348739            Main      50.00  06/01/2023 00:00:00
# 773139            Main     156.00  06/01/2023 00:00:00
# 773140            Main     156.00  06/01/2023 00:00:00
# 773141            Main     156.00  06/01/2023 00:00:00
# 773142            Main     156.00  06/01/2023 00:00:00
# 773143            Main     156.00  06/01/2023 00:00:00
# 773144            Main     156.00  06/01/2023 00:00:00
# 773145            Main     156.00  06/01/2023 00:00:00
# 773146            Main     156.00  06/01/2023 00:00:00
# 773147            Main     156.00  06/01/2023 00:00:00
# 773148            Main     156.00  06/01/2023 00:00:00
# 773149            Main     156.00  06/01/2023 00:00:00
# 773150            Main     156.00  06/01/2023 00:00:00
# 773151            Main     156.00  06/01/2023 00:00:00
# 773152            Main     156.00  06/01/2023 00:00:00
# 773153            Main     156.00  06/01/2023 00:00:00
# 773154            Main     156.00  06/01/2023 00:00:00
# 1246358       Portland       5.00  06/01/2023 00:00:00
# 1246359        Western       0.00  06/01/2023 00:00:00
# 1246360        Newburg       5.00  06/01/2023 00:00:00
# 1246361       Portland       5.00  06/01/2023 00:00:00
# 1333236      Northeast       9.99  06/01/2023 00:00:00
# 1467895  South Central      79.99  06/01/2023 00:00:00
# 1582182       Iroquois      10.82  06/01/2023 00:00:00
# 1672187           Main      74.19  06/01/2023 00:00:00

# %%
# Not interested in these rows, dropping them
lfpl_books = lfpl_books[~lfpl_books['ItemCollection'].isin(item_collections)]

# %%
# Dataframe info
lfpl_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1183924 entries, 0 to 1674144
# Data columns (total 10 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   BibNum           1183924 non-null  int64
#  1   Title            1183924 non-null  object
#  2   Author           1118736 non-null  object
#  3   ISBN             1148050 non-null  float64
#  4   PublicationYear  1183924 non-null  int64
#  5   ItemType         1183924 non-null  object
#  6   ItemCollection   1183737 non-null  object
#  7   ItemLocation     1183924 non-null  object
#  8   ItemPrice        1183924 non-null  float64
#  9   ReportDate       1183924 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 99.4+ MB

# %% [markdown]
# The ISBN column is a float. We will convert it to string.

# %%
#lfpl_books['ISBN'] = lfpl_books['ISBN'].astype(str)
# From float to string

lfpl_books.loc[:, 'ISBN'] = lfpl_books['ISBN'].astype(str)
lfpl_books
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1674140  2654213                                 The Saracen's mark
# 1674141  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1674142  2654215  The maid, the man, and the fans: Elivis is the...
# 1674143  2654216  The monstrous-feminine: film, feminism, psycho...
# 1674144  2654217  Common snese religion: a guide for renewing yo...
#
#                             Author             ISBN  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878.0             2009     Book
# 1             Miller, Robin, 1964-  9780307451408.0             2009     Book
# 2             Miller, Robin, 1964-  9780307451408.0             2009     Book
# 3             Miller, Robin, 1964-  9780307451408.0             2009     Book
# 4             Miller, Robin, 1964-  9780307451408.0             2009     Book
# ...                            ...              ...              ...      ...
# 1674140                  Perry, SW              nan                0     Book
# 1674141              Boucher, Mark              nan                0     Book
# 1674142  Rooks, Nancy; Gutter, Mae              nan                0     Book
# 1674143             Creed, Barbara              nan                0     Book
# 1674144               Mann, Gerald              nan                0     Book
#
#             ItemCollection            ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                    Main      25.95
# 1        Adult Non-Fiction               Southwest      19.99
# 2        Adult Non-Fiction               Southwest      19.99
# 3        Adult Non-Fiction  Remote Shelving - Main      19.99
# 4        Adult Non-Fiction  Remote Shelving - Main      19.99
# ...                    ...                     ...        ...
# 1674140  Interlibrary Loan                    Main       0.00
# 1674141  Interlibrary Loan                    Main       0.00
# 1674142  Interlibrary Loan                    Main       0.00
# 1674143  Interlibrary Loan                    Main       0.00
# 1674144  Interlibrary Loan                    Main       0.00
#
#                   ReportDate
# 0        06/01/2023 00:00:00
# 1        06/01/2023 00:00:00
# 2        06/01/2023 00:00:00
# 3        06/01/2023 00:00:00
# 4        06/01/2023 00:00:00
# ...                      ...
# 1674140  06/01/2023 00:00:00
# 1674141  06/01/2023 00:00:00
# 1674142  06/01/2023 00:00:00
# 1674143  06/01/2023 00:00:00
# 1674144  06/01/2023 00:00:00
#
# [1183924 rows x 10 columns]

# %%
# Get rid of '.0' at the end after the conversion
#lfpl_books['ISBN'] = lfpl_books['ISBN'].astype(str).str.rstrip('.0')

lfpl_books.loc[:, 'ISBN'] = lfpl_books['ISBN'].astype(str).str.rstrip('.0')
lfpl_books
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1674140  2654213                                 The Saracen's mark
# 1674141  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1674142  2654215  The maid, the man, and the fans: Elivis is the...
# 1674143  2654216  The monstrous-feminine: film, feminism, psycho...
# 1674144  2654217  Common snese religion: a guide for renewing yo...
#
#                             Author           ISBN  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878             2009     Book
# 1             Miller, Robin, 1964-  9780307451408             2009     Book
# 2             Miller, Robin, 1964-  9780307451408             2009     Book
# 3             Miller, Robin, 1964-  9780307451408             2009     Book
# 4             Miller, Robin, 1964-  9780307451408             2009     Book
# ...                            ...            ...              ...      ...
# 1674140                  Perry, SW            nan                0     Book
# 1674141              Boucher, Mark            nan                0     Book
# 1674142  Rooks, Nancy; Gutter, Mae            nan                0     Book
# 1674143             Creed, Barbara            nan                0     Book
# 1674144               Mann, Gerald            nan                0     Book
#
#             ItemCollection            ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                    Main      25.95
# 1        Adult Non-Fiction               Southwest      19.99
# 2        Adult Non-Fiction               Southwest      19.99
# 3        Adult Non-Fiction  Remote Shelving - Main      19.99
# 4        Adult Non-Fiction  Remote Shelving - Main      19.99
# ...                    ...                     ...        ...
# 1674140  Interlibrary Loan                    Main       0.00
# 1674141  Interlibrary Loan                    Main       0.00
# 1674142  Interlibrary Loan                    Main       0.00
# 1674143  Interlibrary Loan                    Main       0.00
# 1674144  Interlibrary Loan                    Main       0.00
#
#                   ReportDate
# 0        06/01/2023 00:00:00
# 1        06/01/2023 00:00:00
# 2        06/01/2023 00:00:00
# 3        06/01/2023 00:00:00
# 4        06/01/2023 00:00:00
# ...                      ...
# 1674140  06/01/2023 00:00:00
# 1674141  06/01/2023 00:00:00
# 1674142  06/01/2023 00:00:00
# 1674143  06/01/2023 00:00:00
# 1674144  06/01/2023 00:00:00
#
# [1183924 rows x 10 columns]

# %%
# ISBN is an string now
lfpl_books.dtypes
# Out:
# BibNum               int64
# Title               object
# Author              object
# ISBN                object
# PublicationYear      int64
# ItemType            object
# ItemCollection      object
# ItemLocation        object
# ItemPrice          float64
# ReportDate          object
# dtype: object

# %%
# Nothing is NaN after the conversion, it's the string 'nan' instead
lfpl_books[lfpl_books['ISBN'] == 'nan']
# Out:
#           BibNum                                              Title  \
# 4968     1348353  Stolen legacy: the Egyptian origins of western...
# 7938     1353427  A symposium in public librarianship; three add...
# 8150     1353740                     WWI : the Great War, 1914-1918
# 8165     1353780                                     LANKIE MANTITA
# 10449    1362079                                         Act of War
# ...          ...                                                ...
# 1674140  2654213                                 The Saracen's mark
# 1674141  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1674142  2654215  The maid, the man, and the fans: Elivis is the...
# 1674143  2654216  The monstrous-feminine: film, feminism, psycho...
# 1674144  2654217  Common snese religion: a guide for renewing yo...
#
#                                                     Author ISBN  \
# 4968                                    James, George G. M  nan
# 7938     University of California, Berkeley. School of ...  nan
# 8150         Brown, Hilary (Author of Two-liners for kids)  nan
# 8165                                     LESLIE PATRICELLI  nan
# 10449                                          Brown, Dale  nan
# ...                                                    ...  ...
# 1674140                                          Perry, SW  nan
# 1674141                                      Boucher, Mark  nan
# 1674142                          Rooks, Nancy; Gutter, Mae  nan
# 1674143                                     Creed, Barbara  nan
# 1674144                                       Mann, Gerald  nan
#
#          PublicationYear ItemType     ItemCollection ItemLocation  ItemPrice  \
# 4968                   0     Book  Interlibrary Loan         Main        0.0
# 7938                1952     Book   Kentucky History         Main       25.0
# 8150                2014     Book  Adult Non-Fiction         Main       15.0
# 8165                   0     Book                NaN      Shively        0.0
# 10449                  0     Book                NaN      Bon Air        0.0
# ...                  ...      ...                ...          ...        ...
# 1674140                0     Book  Interlibrary Loan         Main        0.0
# 1674141                0     Book  Interlibrary Loan         Main        0.0
# 1674142                0     Book  Interlibrary Loan         Main        0.0
# 1674143                0     Book  Interlibrary Loan         Main        0.0
# 1674144                0     Book  Interlibrary Loan         Main        0.0
#
#                   ReportDate
# 4968     06/01/2023 00:00:00
# 7938     06/01/2023 00:00:00
# 8150     06/01/2023 00:00:00
# 8165     06/01/2023 00:00:00
# 10449    06/01/2023 00:00:00
# ...                      ...
# 1674140  06/01/2023 00:00:00
# 1674141  06/01/2023 00:00:00
# 1674142  06/01/2023 00:00:00
# 1674143  06/01/2023 00:00:00
# 1674144  06/01/2023 00:00:00
#
# [35874 rows x 10 columns]

# %%
# Changing 'nan' to an empty string
#lfpl_books['ISBN'] = lfpl_books['ISBN'].replace('nan', '')
lfpl_books.loc[:, 'ISBN'] = lfpl_books['ISBN'].replace('nan', '')

# %%
# At this point we will save a copy of this cleaned dataset. It can be used later if we are offline
import os
data_folder = 'data'
csv_file_path = os.path.join(data_folder, 'lfpl_books.csv.gz')

# Save merged_df to a compressed CSV file (gzip compression)
lfpl_books.to_csv(csv_file_path, index=False, compression='gzip')

# %%
# Open Books API test. Trying to use compression, if possible, to reduce the size of the data transfered over the network - v1
# Exploring all the information available on the API
import requests
import gzip
from io import BytesIO

def get_book_info(book_name):
    base_url = "https://openlibrary.org/search.json"

    response = requests.get(base_url, params={'q': book_name})

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Check if the response is gzip compressed
        if 'Content-Encoding' in response.headers and response.headers['Content-Encoding'] == 'gzip':
            # Parse the JSON response from a gzip-compressed content
            with gzip.GzipFile(fileobj=BytesIO(response.content), mode='rb') as gz:
                data = gz.read().decode('iso-8859-1')
        else:
            # If not compressed, decode as utf-8
            data = response.content.decode('utf-8')

        # Display information from the JSON response
        data = response.json()

        if 'docs' in data and data['docs']:
            first_book = data['docs'][0]

            # Traverse and display information
            for key, value in first_book.items():
                print(f"{key}: {value}")
        else:
            print(f"No information found for the book: {book_name}")
    else:
        print(f"Error: Unable to fetch information for the book {book_name}")

#get_book_info("The Great Gatsby")
get_book_info("Mr. Fortune's maggot")
# Out:
# key: /works/OL112774W
# type: work
# seed: ['/books/OL6709107M', '/books/OL14545606M', '/books/OL16471246M', '/books/OL23821669M', '/books/OL21615912M', '/books/OL21028669M', '/books/OL20445431M', '/books/OL3006486M', '/books/OL5212435M', '/books/OL3938676M', '/books/OL9420148M', '/books/OL33391606M', '/books/OL25046078M', '/books/OL29515185M', '/books/OL38803780M', '/works/OL112774W', '/subjects/missionaries', '/subjects/gay', '/subjects/british', '/subjects/fiction', '/subjects/boys', '/subjects/widows', '/subjects/fiction_general', '/subjects/fiction_romance_general', '/subjects/fiction_psychological', '/subjects/brazil_fiction', '/subjects/pacific_area_fiction', '/subjects/widows_fiction', '/subjects/missionaries_fiction', '/subjects/london_(england)_fiction', '/subjects/english_literature', '/subjects/fantasy_fiction', '/subjects/place:oceania', '/subjects/place:brazil', '/authors/OL20510A']
# title: Mr. Fortune's Maggot
# title_suggest: Mr. Fortune's Maggot
# title_sort: Mr. Fortune's Maggot
# edition_count: 15
# edition_key: ['OL6709107M', 'OL14545606M', 'OL16471246M', 'OL23821669M', 'OL21615912M', 'OL21028669M', 'OL20445431M', 'OL3006486M', 'OL5212435M', 'OL3938676M', 'OL9420148M', 'OL33391606M', 'OL25046078M', 'OL29515185M', 'OL38803780M']
# publish_date: ['1978', 'July 30, 2004', '1980', '2001', '2011', '1927', '1948', '2021']
# publish_year: [1978, 1980, 2001, 2011, 1927, 1948, 2004, 2021]
# first_publish_year: 1927
# number_of_pages_median: 241
# lccn: ['84673750', '27026459', '2011022234', '2001004272', '75041290']
# publish_place: ['New York', 'Harmondsworth', 'London']
# oclc: ['2164061', '47650717', '1333886', '40524412']
# contributor: ['Warner, Sylvia Townsend, 1893-']
# lcc: ['PR-6045.00000000.A812 Mr2', 'PR-6045.00000000.A812M74 2001', 'PR-6045.00000000.A812 M7x 1978', 'PR-6045.00000000.A812M74 2011', 'PZ-0003.00000000.W2473 Mi 1980', 'PR-6045.00000000.A812 Mi 1980', 'PR-6045.00000000.A812', 'PR-6045.00000000.A812 M74 2001', 'PR-6045.00000000.A812 M7 1948', 'PR-6045.00000000.A812 M74 2011', 'PZ-0003.00000000.W2473 Mr2']
# ddc: ['823.914', '823.912']
# isbn: ['1405513780', '9780141994819', '9780241476093', '0241476097', '9781417926138', '9780404146276', '1590174585', '9781590174586', '9780860680437', '1417926139', '0141994819', '0404146279', '9781405513784', '0860680436', '9780940322837', '0940322838']
# last_modified_i: 1686890517
# ebook_count_i: 2
# ebook_access: borrowable
# has_fulltext: True
# public_scan_b: False
# ia: ['mrfortunesmaggot0000warn_u9d3', 'mrfortunesmaggot00warn']
# ia_collection: ['americanuniversity-ol', 'china', 'drakeuniversity-ol', 'inlibrary', 'internetarchivebooks', 'johnshopkins-ol', 'printdisabled', 'universityofarizona-ol', 'wilsoncollege-ol']
# ia_collection_s: americanuniversity-ol;china;drakeuniversity-ol;inlibrary;internetarchivebooks;johnshopkins-ol;printdisabled;universityofarizona-ol;wilsoncollege-ol
# lending_edition_s: OL3006486M
# lending_identifier_s: mrfortunesmaggot0000warn_u9d3
# printdisabled_s: OL3006486M;OL3938676M
# readinglog_count: 11
# want_to_read_count: 10
# currently_reading_count: 0
# already_read_count: 1
# cover_edition_key: OL3006486M
# cover_i: 717600
# publisher: ['Kessinger Publishing', 'Chatto and Windus', 'The Viking Press', 'New York Review Books', 'AMS Press', 'Little, Brown Book Group Limited', 'The Literary Guild', 'Penguin', 'Virago', 'Penguin Books', 'Penguin Books, Limited']
# language: ['eng']
# author_key: ['OL20510A']
# author_name: ['Sylvia Townsend Warner']
# author_alternative_name: ['Sylvia Townsend 1893- Warner']
# place: ['Oceania', 'Brazil']
# subject: ['Missionaries', 'Gay', 'British', 'Fiction', 'Boys', 'Widows', 'Fiction, general', 'Fiction, romance, general', 'Fiction, psychological', 'Brazil, fiction', 'Pacific area, fiction', 'Widows, fiction', 'Missionaries, fiction', 'London (england), fiction', 'English literature', 'Fantasy fiction']
# id_goodreads: ['2756743', '1327033', '264840']
# id_librarything: ['218087', '9295133']
# ia_loaded_id: ['mrfortunesmaggot00warn']
# ia_box_id: ['IA140004', 'IA40978513']
# publisher_facet: ['AMS Press', 'Chatto and Windus', 'Kessinger Publishing', 'Little, Brown Book Group Limited', 'New York Review Books', 'Penguin', 'Penguin Books', 'Penguin Books, Limited', 'The Literary Guild', 'The Viking Press', 'Virago']
# place_key: ['brazil', 'oceania']
# subject_facet: ['Boys', 'Brazil, fiction', 'British', 'English literature', 'Fantasy fiction', 'Fiction', 'Fiction, general', 'Fiction, psychological', 'Fiction, romance, general', 'Gay', 'London (england), fiction', 'Missionaries', 'Missionaries, fiction', 'Pacific area, fiction', 'Widows', 'Widows, fiction']
# _version_: 1769193120589676546
# place_facet: ['Brazil', 'Oceania']
# lcc_sort: PR-6045.00000000.A812 M7x 1978
# author_facet: ['OL20510A Sylvia Townsend Warner']
# subject_key: ['boys', 'brazil_fiction', 'british', 'english_literature', 'fantasy_fiction', 'fiction', 'fiction_general', 'fiction_psychological', 'fiction_romance_general', 'gay', 'london_(england)_fiction', 'missionaries', 'missionaries_fiction', 'pacific_area_fiction', 'widows', 'widows_fiction']
# ddc_sort: 823.914

# %%
# Modifying the previous script to only return the ISBN number. Handling some exceptions. v1
import requests
import gzip
from io import BytesIO
import time

def get_book_isbn(book_title, max_retries=3):
    base_url = "https://openlibrary.org/search.json"
    
    for attempt in range(max_retries + 1):
        try:
            # Sending a request to the Open Books API with the book title
            response = requests.get(base_url, params={'q': book_title})

            # Check if the request was successful (status code 200)
            response.raise_for_status()

            # Check if the response is gzip compressed
            if 'Content-Encoding' in response.headers and response.headers['Content-Encoding'] == 'gzip':
                # Parse the JSON response from a gzip-compressed content
                with gzip.GzipFile(fileobj=BytesIO(response.content), mode='rb') as gz:
                    data = gz.read().decode('iso-8859-1')
            else:
                # If not compressed, decode as utf-8
                data = response.content.decode('utf-8')

            # Parse the JSON response
            data = response.json()

            if 'docs' in data and data['docs']:
                first_book = data['docs'][0]

                # Check if ISBN information is available
                if 'isbn' in first_book:
                    # Return the ISBN
                    return first_book['isbn'][0] if first_book['isbn'] else ""
                else:
                    print(f"ISBN information not found for the book: {book_title}")
                    return ""
            else:
                print(f"No information found for the book: {book_title}")
                return ""

        except requests.exceptions.HTTPError as e:
            if attempt < max_retries and e.response.status_code == 429:
                # Retry if the status code is 429 (Too Many Requests)
                retry_after = int(e.response.headers.get('Retry-After', 5))  # Default to 5 seconds if Retry-After is not present
                print(f"Retrying after {retry_after} seconds due to status code 429 (Too Many Requests)...")
                time.sleep(retry_after)
            else:
                print(f"Error: {e}")
                return ""

isbn = get_book_isbn("The Great Gatsby")
print(f"ISBN: {isbn}")
# Out:
# ISBN: 9781716075735

# %%
# Testing functionality

# Function to apply to the DataFrame
def fill_missing_isbn(row):
    if row["ISBN"] == '':
        return get_book_isbn(row["Title"])
    else:
        return row["ISBN"]

# Dictionary to test
data = {
    "Title": ["Cognitive Mapping : Past, Present, and Future","LANKIE MANTITA", "WWI : the Great War, 1914-1918", "the girl in the road", "Sharp Edges", "My First Pet"],
    "ISBN": ["", "", "", "", "","9781405309035"]
}

df = pd.DataFrame(data)

# Apply the function using lambda only to rows with missing ISBN
df["ISBN"] = df.apply(lambda row: fill_missing_isbn(row), axis=1)

print(df)
# Out:
# No information found for the book: LANKIE MANTITA
#                                            Title           ISBN
# 0  Cognitive Mapping : Past, Present, and Future     1315812282
# 1                                 LANKIE MANTITA
# 2                 WWI : the Great War, 1914-1918     1869792637
# 3                           the girl in the road  9798791410146
# 4                                    Sharp Edges  9780671524098
# 5                                   My First Pet  9781405309035

# %%
# Testing with the Open Library Books API - v2
import json

def get_isbn_from_openlibrary(title):
    base_url = "http://openlibrary.org/search.json"
    params = {"title": title}
    response = requests.get(base_url, params, headers={"Accept-Encoding": "gzip"})
    if response.status_code == 429:
        retry_after = int(response.headers.get("Retry-After"))
        print(f"API rate limit exceeded. Retrying after {retry_after} seconds.")
        time.sleep(retry_after)
        return get_isbn_from_openlibrary(title)
    if response.status_code != 200:
        print(f"Error retrieving ISBN for title '{title}': {response.status_code}")
        return None
    content_type = response.headers.get("Content-Type")
    if content_type == "application/gzip":
        with gzip.decompress(response.content) as decompressed_data:
            data = json.loads(decompressed_data.decode("utf-8"))
    else:
        data = json.loads(response.content.decode("utf-8"))
    isbn = data.get("docs")[0].get("isbn")[0] if data.get("docs") and data.get("docs")[0].get("isbn") else None
    return isbn

#isbn = get_isbn_from_openlibrary("The Great Gatsby")
isbn = get_isbn_from_openlibrary("The French literary horizon")
print(f"ISBN: {isbn}")
# Out:
# ISBN: None

# %%
# Testing with the Open Library Books API - v3
# Modifying v1 to return the Author too

def get_book_data_01(book_title, max_retries=3):
    base_url = "https://openlibrary.org/search.json"
    
    for attempt in range(max_retries + 1):
        try:
            # Sending a request to the Open Books API with the book title
            response = requests.get(base_url, params={'q': book_title})

            # Check if the request was successful (status code 200)
            response.raise_for_status()

            # Check if the response is gzip compressed
            if 'Content-Encoding' in response.headers and response.headers['Content-Encoding'] == 'gzip':
                # Parse the JSON response from a gzip-compressed content
                with gzip.GzipFile(fileobj=BytesIO(response.content), mode='rb') as gz:
                    data = gz.read().decode('iso-8859-1')
            else:
                # If not compressed, decode as utf-8
                data = response.content.decode('utf-8')

            # Parse the JSON response
            data = response.json()

            if 'docs' in data and data['docs']:
                first_book = data['docs'][0]

                if first_book:

                    # Check if ISBN information is available
                    if 'isbn' in first_book:
                        # Return the ISBN
                        isbn = first_book['isbn'][0] if first_book['isbn'] else ""
                    else:
                        print(f"ISBN information not found for the book: {book_title}")
                        isbn = ""
                        #return ""
                    if 'author_name' in first_book:
                        # Return the author
                        author = first_book['author_name'][0] if first_book['author_name'] else ""
                    else:
                        print(f"Author information not found for the book: {book_title}")
                        author = ""
                        #return ""    
                    return isbn, author
            else:
                print(f"No information found for the book: {book_title}")
                return "", ""

        except requests.exceptions.HTTPError as e:
            if attempt < max_retries and e.response.status_code == 429:
                # Retry if the status code is 429 (Too Many Requests)
                retry_after = int(e.response.headers.get('Retry-After', 5))  # Default to 5 seconds if Retry-After is not present
                print(f"Retrying after {retry_after} seconds due to status code 429 (Too Many Requests)...")
                time.sleep(retry_after)
            else:
                print(f"Error: {e}")
                return "", ""

isbn, author = get_book_data_01("Mr. Fortune's maggot")
print(f"ISBN: {isbn}, Author: {author}")
# Out:
# ISBN: 1405513780, Author: Sylvia Townsend Warner

# %%
# Similar to the function above, with a few variations
# We will use this one to find missing authors and ISBNs
def get_book_data_ol(book_title):
    base_url = "https://openlibrary.org/search.json"
    params = {'q': book_title}

    try:
        headers = {'Accept-Encoding': 'gzip'}
        response = requests.get(base_url, params=params, headers=headers)

        # Check for HTTP error 429 (rate limit exceeded)
        if response.status_code == 429:
            # If "Retry-After" header is present, wait and retry
            retry_after = response.headers.get('Retry-After')
            if retry_after:
                time.sleep(int(retry_after))
                response = requests.get(base_url, params=params, headers=headers)

        response.raise_for_status()

        # Decompress gzip response
        if 'content-encoding' in response.headers and response.headers['content-encoding'] == 'gzip':
            compressed_data = BytesIO(response.content)
            with gzip.GzipFile(fileobj=compressed_data, mode='rb') as f:
                content = f.read()
        else:
            content = response.content

        data = response.json()  

        works = data.get('docs', [])

        if works:
            # Assuming the first result is the most relevant
            work = works[0]
            # Extract ISBN and Author from the response
            isbn = work.get('isbn', [])[0] if 'isbn' in work else ''
            author = work.get('author_name', [''])[0] if 'author_name' in work else ''
            return isbn, author

    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}, Title: {book_title}")
    except requests.exceptions.RequestException as req_err:
        print(f"Request error occurred: {req_err}, Title: {book_title}")
    except Exception as e:
        print(f"An error occurred: {e}, Title: {book_title}")

    # Return empty strings if any exception occurs or 'docs' list is empty
    return '', ''


isbn, author = get_book_data_ol("The high cost of writing")
print(f"ISBN: {isbn}, Author: {author}")
# Out:
# ISBN: , Author: Rebecca Caudill

# %%
# Records without author
(lfpl_books['Author'].isna()).sum()
# Out:
# 65188

# %% [markdown]
# It will take a lot of time to get the information about the authors using API calls

# %%
# Records without isbn
(lfpl_books['ISBN']=="").sum()
# Out:
# 35874

# %%
# Records that have missing Author and/or ISBN values missing
# We only need one book title, dropping duplicates
lfpl_books.loc[(lfpl_books['ISBN'] == '') | (lfpl_books['Author'].isna()), 'Title'].drop_duplicates().count()
# Out:
# 54616

# %% [markdown]
# Using APIs has been harder than expected: many APIs will block too many requests in a certain period of time.
# I tried using concurrency, but that made things even worse with the API rejecting calls.
# The following portion will attempt to gather author and ISBN using the book title from the Open Library API.
# For a variety of reasons the process can be interrupted(learned it the hard way), so a csv file is being updated every time a call is made.
# Not recommended to be run it for testing because it takes hours to complete. The resulting csv is already available.

# %%
# This one is to obtain isbn and author from the Open Libary
# Saving in a csv to don't lose our time and effort
# This takes hour to finish. There is no need to run it again: we already have the csv

import os

# Create a 'data' folder if it doesn't exist
data_folder = 'data'
os.makedirs(data_folder, exist_ok=True)

# New CSV file name and path
csv_file = os.path.join(data_folder, 'openlib_data.csv')

# Check if the CSV file exists
csv_exists = os.path.exists(csv_file)

# If the CSV file doesn't exist, create an empty DataFrame with headers
if not csv_exists:
    openlib_data = pd.DataFrame(columns=['Title', 'Author', 'ISBN'], dtype='str')
else:
    openlib_data = pd.read_csv(csv_file) 

# Check if the CSV file has any data
csv_has_data = not openlib_data.empty

# Identify the remaining rows that need processing
remaining_rows = lfpl_books.loc[(lfpl_books['ISBN'] == '') | (lfpl_books['Author'].isna()), 'Title'].drop_duplicates()

# Iterate over remaining rows
for title in remaining_rows:
    # Check if the title is already in openlib_data DataFrame
    # On subsequent calls, if the API failed to get any result, try again
    
    title_exists = title in openlib_data['Title'].values if csv_has_data else False
    
    # Check if either the ISBN or Author is missing
   
    isbn_author_missing = (
    (openlib_data.loc[openlib_data['Title'] == title, 'ISBN'].values.size > 0 and
     openlib_data.loc[openlib_data['Title'] == title, 'ISBN'].values[0] == '') and
    pd.isna(openlib_data.loc[openlib_data['Title'] == title, 'Author'].values[0])
)
    if not title_exists or isbn_author_missing:
        try:
            # Obtain ISBN and Author using the get_book_data_ol function
            isbn, author = get_book_data_ol(title)
            new_row = {'Title': title, 'Author': author, 'ISBN': isbn}
            openlib_data = openlib_data._append(pd.Series(new_row), ignore_index=True)

            # Append the new row to the CSV file
            new_row_df = pd.DataFrame([new_row])
            new_row_df.to_csv(csv_file, index=False, header=not csv_exists, mode='a')
            print(f"Saving - Title: {title}, Author: {author}, ISBN: {isbn}")

            # Update csv_exists flag
            csv_exists = True

        except Exception as e:
            print(f"Error processing title '{title}': {e}")
# Out:
# Saving - Title: Quarters One : the United States Army Chief of Staff's residence, Fort Myer, Virginia, Author: William Gardner Bell, ISBN: 0160359112
# Saving - Title: Men of WW II : fighting men at ease, Author: Evan Bachner, ISBN: 9780810992870
# Saving - Title: The ancestors, Author: Brandon Massey, ISBN: 0758264615
# Saving - Title: The furies : a novel, Author: Natalie Haynes, ISBN: 1250048001
# Saving - Title: The healthy woman : a complete guide for all ages., Author: Government Publications Office, ISBN: 0160771838
# Saving - Title: Quantico, crossroads of the Marine Corps, Author: Fleming, USMC, Lieutenant Colonel Charles A., ISBN: 1499748485
# Saving - Title: Black Americans in Congress, 1870-2007, Author: Matthew Wasniewski, ISBN: 016080194X
# Saving - Title: Spanish ballads, Author: Guy Le Strange, ISBN:
# Saving - Title: Best African American essays. 2009, Author: Gerald Lyn Early, ISBN: 0553806912
# Saving - Title: Classic movie themes., Author: Hal Leonard Corp., ISBN: 0793593123
# Saving - Title: Joanna and Ulysses, a tale., Author: May Sarton, ISBN: 9780393304145
# Saving - Title: Updated master plan, Author: HMM Associates., ISBN:
# Saving - Title: Pushcart prize XXXIII, 2009 : best of the small presses, Author: Bill Henderson, ISBN: 9781888889512
# Saving - Title: American Medical Association complete guide to prevention and wellness : what you need to know about preventing illness, staying healthy, and living longer., Author: American Medical Association, ISBN: 9780470251300
# Saving - Title: We are all born free : the Universal Declaration of Human Rights in pictures, Author: Amnesty International, ISBN: 9781847801517
# Saving - Title: Stories of bravery!, Author: O'Brien, Terry (Quiz master), ISBN: 8129124513
# Saving - Title: Princeton review gre prep, 2024: 5 practice tests + review & techniques + online features, Author: The Princeton The Princeton Review, ISBN: 0593516958
# Saving - Title: Wanting: women writing about desire, Author: Lisa Solod Warren, ISBN: 9781580052146
# Saving - Title: Carnage, vol. 1. in the court of crimson, Author: Ram V, ISBN: 1302934600
# Saving - Title: Princess collection., Author: George MacDonald, ISBN: 1798640511
# Saving - Title: 5-Minute Avengers stories., Author: Marvel Press Book Group, ISBN: 1484743318
# Saving - Title: The explanation of ideology: family structures and social systems, Author: Emmanuel Todd, ISBN: 0631154914
# Saving - Title: Policies for an aging society, Author: Stuart H. Altman, ISBN: 9780801869075
# Saving - Title: Simone Manuel Swimming Star, Author: Heather E. Schwartz, ISBN: 1515797112
# Saving - Title: Louisville coloring book, Author: Creative Company, ISBN: 1493021168
# Saving - Title: BRIDE BY ROYAL DECREE, Author: Caitlin Crews, ISBN: 9781459292673
# Saving - Title: The edinburgh mystery: and other tales of scottish crime, Author: Robert Louis Stevenson, ISBN: 9782070332991
# Saving - Title: Austin noir, Author: Hopeton Hay, ISBN: 9781636140896
# Saving - Title: Persian myths & legends: tales of heroes, gods & monsters, Author: , ISBN:
# Saving - Title: The book of strange but true science., Author: Harry Golding, ISBN: 9781844036554
# Saving - Title: The essential Gnostic Gospels : including the Gospel of Thomas and the Gospel of Mary Magdalene, Author: , ISBN:
# Saving - Title: The Negro leagues are major leagues : essays and research for overdue recognition, Author: , ISBN:
# Saving - Title: The life and times of Seargent Smith Prenties, Author: , ISBN:
# Saving - Title: Survivor, Author: Survivor Survivor Dinosaurs, ISBN: 9798825306995
# Saving - Title: Stitch crashes disney, Author: Disney Books, ISBN: 9781368080118
# Saving - Title: Why can't we be friends?, Author: Jenine May, ISBN: 1096896451
# Saving - Title: Stamps & Stamps: style & sensibility, Author: Diane Dorrans Saeks, ISBN: 0847868648
# Saving - Title: The guise of exceptionalism: unmasking the national narratives of Haiti and the U.S., Author: , ISBN:
# Saving - Title: Vincent van Gogh: the lost Arles sketchbook, Author: Bogomila Welsh-Ovcharov, ISBN: 1419725947
# Saving - Title: highlights into the future, Author: Heather Bingham, ISBN: 9780906421093
# Saving - Title: KOREA the land the people the culture, Author: Karen L. Gatz, ISBN:
# Saving - Title: The Saracen's mark, Author: S.W. Perry, ISBN: 0655663452
# Saving - Title: The hedge fund edge: maximum profit/minimum risk global trend trading, Author: Mark Boucher, ISBN: 9780471185383
# Saving - Title: The monstrous-feminine: film, feminism, psychoanalysis, Author: Barbara Creed, ISBN: 9781136750755
# Saving - Title: Common snese religion: a guide for renewing your Christian values, Author: , ISBN:

# %%
# Checking for duplicates, just in case
import os

# Read information from the openlib_data csv in the data folder
data_folder = 'data'
csv_file = os.path.join(data_folder, 'openlib_data.csv')
if os.path.exists(csv_file):
    ol = pd.read_csv(csv_file)
else:
    print("Error: openlib_data.csv not found.")
    exit()

# check for duplicates in the 'Title' column
duplicates = ol[ol.duplicated(['Title'], keep=False)]

# display the duplicates
if len(duplicates) > 0:
    print(f'The following {len(duplicates)} titles are duplicated:')
    print(duplicates['Title'])
else:
    print('There are no duplicates in the Title column.')
# Out:
# There are no duplicates in the Title column.

# %%
ol.isna().sum()
# Out:
# Title         0
# Author    10801
# ISBN      23166
# dtype: int64

# %% [markdown]
# There is still have some missing data.
# We now will use the Google Books API see if we can collect the author and ISBN that weren't returned by the Open Library API

# %%
# This function has the same functionality that get_book_data_ol, used previously.
# The implementation is different because this API returns the data in a different format

def get_book_data_gb(book_title):
    # Your implementation of get_book_data_gb (Google Books API)
    base_url = "https://www.googleapis.com/books/v1/volumes"
    params = {"q": f"intitle:{book_title}", "maxResults": 1}

    # Retry mechanism with exponential backoff for HTTP 429
    retries = 3
    for attempt in range(retries):
        response = requests.get(base_url, params=params)

        if response.status_code == 200:
            # Successful response
            data = response.json()
            if "items" in data and data["items"]:
                volume_info = data["items"][0]["volumeInfo"]
                identifiers = volume_info.get("industryIdentifiers", [])

                if identifiers:
                    # Prioritize ISBN-13, then ISBN-10
                    isbn_13 = next((id.get("identifier", "") for id in identifiers if id.get("type") == "ISBN_13"), "")
                    isbn_10 = next((id.get("identifier", "") for id in identifiers if id.get("type") == "ISBN_10"), "")
                    
                    # Use ISBN-13 if available, otherwise ISBN-10
                    isbn = isbn_13 or isbn_10 
                else:
                    # No identifiers available
                    isbn = ""

                author = volume_info.get("authors", [""])[0]
                return author, isbn
            else:
                # No book information found in the Google Books API response
                return "", ""
        elif response.status_code == 429:
            # HTTP 429: Too Many Requests, wait for Retry-After seconds
            retry_after = int(response.headers.get("Retry-After", 5))
            print(f"HTTP 429 - Too Many Requests. Retrying after {retry_after} seconds...")
            time.sleep(retry_after)
        else:
            # Other HTTP errors
            print(f"Error in API call: HTTP {response.status_code}")
            time.sleep(5)  # Introduce a delay before retrying to avoid potential issues

    # Failed to retrieve book information from the Google Books API
    print("Failed to retrieve book information from the Google Books API.")
    return "", ""

get_book_data_gb("Little tortoise's starry night")
# Out:
# ('', '9781640380165')

# %%
# This script takes hours to complete
# It saves every row collected from the API(save as you go), which makes it slower(but safer)
# Read information from the openlib_data csv in the data folder
# Reloading the csv file, just in case

data_folder = 'data'
csv_file = os.path.join(data_folder, 'openlib_data.csv')

if os.path.exists(csv_file):
    ol = pd.read_csv(csv_file)
else:
    print("Error: openlib_data.csv not found.")
    exit()

# Create or load the book_info_updated csv file
output_csv = os.path.join(data_folder, 'book_info_updated.csv')

# Check if the CSV file exists
csv_exists = os.path.exists(output_csv)

if csv_exists:
    book_info_updated = pd.read_csv(output_csv)
else:
    book_info_updated = pd.DataFrame(columns=['Title', 'Author', 'ISBN'])


# Iterate over every row of the dataframe
for index, row in ol.iterrows():
    title = row['Title']
    author = row['Author']
    isbn = row['ISBN']

    # Check if the Author or the ISBN are missing
    
    if title not in book_info_updated['Title'].values:
        try:
            if pd.isna(author) or pd.isna(isbn):
                # Make a call to the Google Books API with the Book title as a parameter
                author_gb, isbn_gb = get_book_data_gb(title)
                # Keep previous values, if they were present
                new_author  = author_gb if pd.isna(author)  and author_gb   != '' else author
                new_isbn    = isbn_gb   if pd.isna(isbn)    and isbn_gb     != '' else isbn
                
                new_row = {'Title': title, 'Author': new_author, 'ISBN': new_isbn}
                print(f"Updating - Title: {title}, Author: {new_author}, ISBN: {new_isbn}")
            else:
                # Book title has the required information, saving it
                new_row = {'Title': title, 'Author': author, 'ISBN': isbn}
                print(f"Book title '{title}' has all the information. Saving and skipping API call.")

            book_info_updated = book_info_updated._append(pd.Series(new_row), ignore_index=True)

            # Append the new row to the CSV file
            new_row_df = pd.DataFrame([new_row])
            new_row_df.to_csv(output_csv, index=False, header=not csv_exists, mode='a')
            
            # Update csv_exists flag
            csv_exists = True
        except Exception as e:
            # Handle any exceptions with the API call
            print(f"Error processing title '{title}': {e}")
            # Update the values in the book_info_updated dataframe with empty strings
            new_row = {'Title': title, 'Author': '', 'ISBN': ''}
            book_info_updated = book_info_updated._append(pd.Series(new_row), ignore_index=True)
# Out:
# Updating - Title: Captain Canuck 3 : Agent of Pact, Author: Kalman Andrasofszky, ISBN: 9781988247281
# Updating - Title: Martin Krpan, Author: Fran Levstik, ISBN: 9789612790820
# Book title 'Home to you' has all the information. Saving and skipping API call.
# Book title 'Esquire dress code : a man's guide to personal style.' has all the information. Saving and skipping API call.
# Book title 'Never stop driving : a better life behind the wheel' has all the information. Saving and skipping API call.
# Book title 'Eastern Europe phrasebook and dictionary' has all the information. Saving and skipping API call.
# Book title 'The U.S. Constitution : a reader' has all the information. Saving and skipping API call.
# Book title 'Wyoming's Red Desert : a photographic journey' has all the information. Saving and skipping API call.
# Book title 'Site planning and design handbook' has all the information. Saving and skipping API call.
# Book title 'William Shakespeare's The Winter's Tale' has all the information. Saving and skipping API call.
# Book title 'Evangelicals : who they have been, are now, and could be' has all the information. Saving and skipping API call.
# Updating - Title: Aesthetic theory : essential texts : for architecture and design, Author: Mark Foster Gage, ISBN: 9780393733495
# Book title 'All of me : stories of love, anger, and the female body' has all the information. Saving and skipping API call.
# Book title 'Full figured 13' has all the information. Saving and skipping API call.
# Book title 'J.K. Lasser's your income tax 2020' has all the information. Saving and skipping API call.
# Book title 'Saga, book 3' has all the information. Saving and skipping API call.
# Book title 'The Memory Box' has all the information. Saving and skipping API call.
# Updating - Title: Watch me grow!., Author: Maureen O'Brien, ISBN: 8779200400
# Book title 'First 101 words.' has all the information. Saving and skipping API call.
# Updating - Title: Home sweet Sugarcreek, Author: Elizabeth Ludwig, ISBN: nan
# Updating - Title: Digging up doubts, Author: Olivia Newport, ISBN: nan
# Updating - Title: All abuzz at the Honey Bee, Author: Nancy Mehl, ISBN: nan
# Book title '50 Yale admission success stories : and the essays that made them happen' has all the information. Saving and skipping API call.
# Updating - Title: The global refugee crisis: how should we respond? / How Should We Respond?, Author: nan, ISBN: nan
# Book title 'Master the Dsst Ethics in America Exam.' has all the information. Saving and skipping API call.
# Book title 'The cloud of unknowing' has all the information. Saving and skipping API call.
# Updating - Title: My first colors book = Mi primer libro de colores, Author: Cynthya Annette Pagan, ISBN: 9788430513987
# Updating - Title: Making time : the art of the Kentucky tall case clock, 1790-1850., Author: nan, ISBN: 9781941953792
# Book title 'Fodor's 25 best : Berlin' has all the information. Saving and skipping API call.
# Book title 'Amsterdam' has all the information. Saving and skipping API call.
# Book title 'Italy  2020' has all the information. Saving and skipping API call.
# Book title 'London 2020' has all the information. Saving and skipping API call.
# Updating - Title: Costa Rica, Author: United States. Bureau of the Census, ISBN: 9781487588670
# Book title 'Top 10 Cancún and the Yucatán.' has all the information. Saving and skipping API call.
# Book title 'Moon Amsterdam walks.' has all the information. Saving and skipping API call.
# Book title 'Moon Paris walks : see the city like a local.' has all the information. Saving and skipping API call.
# Book title 'London walks : see the city like a local.' has all the information. Saving and skipping API call.
# Book title 'Rome walks : see the city like a local.' has all the information. Saving and skipping API call.
# Book title 'Fodor's the best of Italy' has all the information. Saving and skipping API call.
# Book title 'Curious George' has all the information. Saving and skipping API call.
# Updating - Title: The Russian expeditions 1917-1920, Author: Daniel P Curzon, ISBN: 9781677967469
# Updating - Title: Statistics in Schools and the 2020 census., Author: nan, ISBN: nan
# Book title 'Applying for naturalization through military service.' has all the information. Saving and skipping API call.
# Updating - Title: Targeted violence program, Author: Robert A. Fein, ISBN: nan
# Updating - Title: School safety program, Author: Paul Timm, ISBN: 9780323853675
# Updating - Title: The Louisville Zoo, 1969-2019 : 50 years of hope, inspiration & dedication., Author: nan, ISBN: nan
# Book title 'Literature and film as modern mythology' has all the information. Saving and skipping API call.
# Book title 'The Foxfire book of Appalachian cookery' has all the information. Saving and skipping API call.
# Book title 'Return to Star Valley' has all the information. Saving and skipping API call.
# Updating - Title: The rise of populism : Stephen K. Bannon vs. David Frum, Author: Stephen K. Bannon, ISBN: 9781487006303
# Book title 'Wonder Woman, vol. 1 : the just war' has all the information. Saving and skipping API call.
# Updating - Title: A date with murder : a murder, she wrote mystery : a novel, Author: Jessica Fletcher, ISBN: 9781432854133
# Book title 'Ambush in the Ashes' has all the information. Saving and skipping API call.
# Updating - Title: Earning information for teens : tips for a successful financial life : including facts about child labor laws, teen jobs, résumé preparation, job search, workplace skills, workers' rights, workplace safety, and workplace stress., Author: James Chambers, ISBN: 9780780815766
# Updating - Title: Western Europe, Author: James Harvey Robinson, ISBN: 0710624913
# Updating - Title: The mail-order standoff : 4 historical stories, Author: Angela Breidenbach, ISBN: 9781643522463
# Book title 'The Dhammapada : a new translation of the Buddhist classic' has all the information. Saving and skipping API call.
# Updating - Title: China and the West : McMaster and Pillsbury vs. Mahbubani and Wang, Author: Rudyard Griffiths, ISBN: 9781487007195
# Updating - Title: Tracing your ancestors using DNA : a guide for family and local historians, Author: Anthony Adolph, ISBN: 9780007360956
# Book title 'Merton & Indigenous Wisdom' has all the information. Saving and skipping API call.
# Book title 'South America' has all the information. Saving and skipping API call.
# Updating - Title: The best American nonrequired reading 2019, Author: Edan Lepucki, ISBN: 9780358093169
# Book title 'The best American science and nature writing 2019' has all the information. Saving and skipping API call.
# Book title 'Man-made wonders of the world' has all the information. Saving and skipping API call.
# Book title 'Mayo clinic on digestive health' has all the information. Saving and skipping API call.
# Book title 'Star tales' has all the information. Saving and skipping API call.
# Book title 'Fighters of fear : occult detective stories' has all the information. Saving and skipping API call.
# Book title 'El libro de la ecologia.' has all the information. Saving and skipping API call.
# Book title 'Cómo funciona la ciencia' has all the information. Saving and skipping API call.
# Book title 'Moda : historia y estilos.' has all the information. Saving and skipping API call.
# Updating - Title: Marvel : la enciclopidia, Author: DK, ISBN: 9781465486721
# Updating - Title: El libro de los negocios, Author: Miquel Baixas Calafell, ISBN: 9788446043447
# Book title 'Injustice 2, vol. 6' has all the information. Saving and skipping API call.
# Book title 'Nairobi noir' has all the information. Saving and skipping API call.
# Updating - Title: Unprofitable schooling : examining causes of, and fixes for, America's broken ivory tower, Author: Todd J. Zywicki, ISBN: 9781948647052
# Book title 'Discover dinosaurs.' has all the information. Saving and skipping API call.
# Book title 'Dinosaurs.' has all the information. Saving and skipping API call.
# Updating - Title: Baby moves, Author: Marianne Hermsen-van Wanrooy, ISBN: 0749823534
# Updating - Title: Stranger Things and philosophy : thus spake the Demogorgon, Author: Jeffrey A. Ewing, ISBN: 9780812694741
# Updating - Title: Easter surprise : a scratch-and-sniff story!, Author: Krista Tucker, ISBN: 9780062843807
# Updating - Title: Qira'ah fi Sutooh al-Sama, Author: nan, ISBN: nan
# Updating - Title: Mabahij al-Fikar wa-Manahij al-'Ibar, Author: ʻAbd al-ʻĀl ʻAbd al-Munʻim Shāmī, ISBN: nan
# Updating - Title: Hub wa-Riyadiyat, Author: nan, ISBN: nan
# Updating - Title: Dalil al-Malik lil-Makh, Author: nan, ISBN: nan
# Updating - Title: Ajmal Tarikh lilkawn, Author: nan, ISBN: nan
# Updating - Title: Ajmal Tarikh li-al-Insan, Author: nan, ISBN: nan
# Updating - Title: South Africa, Author: Harm J. de Blij, ISBN: nan
# Book title 'The best of Uncanny' has all the information. Saving and skipping API call.
# Book title 'Top 10 Istanbul' has all the information. Saving and skipping API call.
# Book title 'Big Mamma cucina popolare : contemporary Italian recipes' has all the information. Saving and skipping API call.
# Book title 'The official United States Army illustrated guide to edible wild plants' has all the information. Saving and skipping API call.
# Book title 'Escritores : su vida y sus obras' has all the information. Saving and skipping API call.
# Book title 'El libro de la música clásica' has all the information. Saving and skipping API call.
# Book title 'The Mueller report illustrated : the obstruction investigation' has all the information. Saving and skipping API call.
# Book title 'Mujeres : nuestra historia' has all the information. Saving and skipping API call.
# Book title '2020 U.S. coin digest : the complete guide to current market values' has all the information. Saving and skipping API call.
# Book title 'Baby shark : doo doo doo doo doo doo' has all the information. Saving and skipping API call.
# Book title 'Rapunzel Loves Colors = Rapunzel Ama Los Colores' has all the information. Saving and skipping API call.
# Book title 'Baby reads' has all the information. Saving and skipping API call.
# Book title 'The Opulent interiors of the Gilded Age : all 203 photographs from "Artistic houses" : with new text' has all the information. Saving and skipping API call.
# Book title 'Shortcut to a miracle : how to change your consciousness and transform your life' has all the information. Saving and skipping API call.
# Book title 'El libro tibetano de los muertos / The Tibetan Book of the Dead' has all the information. Saving and skipping API call.
# Book title 'The Encircling Sea' has all the information. Saving and skipping API call.
# Book title 'Planet Earth.' has all the information. Saving and skipping API call.
# Updating - Title: Descendants of War of 1812 veterans : General Society of the War of 1812 : founders' register, commemoration, 1894-1994, Author: nan, ISBN: nan
# Book title 'A Jesse Stuart reader : stories and poems' has all the information. Saving and skipping API call.
# Book title 'Black Education' has all the information. Saving and skipping API call.
# Book title 'The first free women : poems of the early Buddhist nuns' has all the information. Saving and skipping API call.
# Book title 'Tales of heresy' has all the information. Saving and skipping API call.
# Book title 'A map is only one story : twenty writers on immigration, family, and the meaning of home' has all the information. Saving and skipping API call.
# Updating - Title: The comics journal. No. 305, Author: Gary Groth, ISBN: 9781683962779
# Book title 'Italy.' has all the information. Saving and skipping API call.
# Book title 'Madrid.' has all the information. Saving and skipping API call.
# Book title 'TOEFL iBT prep 2020' has all the information. Saving and skipping API call.
# Book title 'Big and little : things that go.' has all the information. Saving and skipping API call.
# Updating - Title: Keep scrolling till you feel something : twenty-one years of humor from McSweeney's Internet Tendency, Author: Chris Monks, ISBN: 9781944211721
# Book title 'Things that go! collection : readers that grow with you.' has all the information. Saving and skipping API call.
# Book title 'Marred for life! : defaced record covers from the collection of Greg Wooten' has all the information. Saving and skipping API call.
# Book title 'Great Britain.' has all the information. Saving and skipping API call.
# Book title 'Naples and the Amalfi Coast.' has all the information. Saving and skipping API call.
# Updating - Title: We count! a 2020 Census counting book., Author: nan, ISBN: nan
# Book title '100 great American short stories' has all the information. Saving and skipping API call.
# Book title 'Anglo-Saxon spirituality : selected writings' has all the information. Saving and skipping API call.
# Book title 'Scientocracy : the tangled web of public science and public policy' has all the information. Saving and skipping API call.
# Updating - Title: El Mexiconario : un diccionario estado por estado, Author: Algarabía, ISBN: 9786073186452
# Book title 'Cómo funciona la filosofia : guía gráfica de las teorias filosóficas' has all the information. Saving and skipping API call.
# Book title 'Tranquilas : historias para ir solas por la noche' has all the information. Saving and skipping API call.
# Book title 'Spider-Man.' has all the information. Saving and skipping API call.
# Book title 'Wildlife photographer of the year : unforgettable portraits' has all the information. Saving and skipping API call.
# Book title 'The Anthology of Scottish Folk Tales' has all the information. Saving and skipping API call.
# Book title 'The feminist porn book : the politics of producing pleasure' has all the information. Saving and skipping API call.
# Updating - Title: Tales of East Africa : folktales from Kenya, Uganda, and Tanzania, Author: Jamilla Okubo, ISBN: 9781452182582
# Book title 'El naufragio de México' has all the information. Saving and skipping API call.
# Updating - Title: Babies love números : lift-a-flap book, Author: Cottage Door Cottage Door Press, ISBN: 9781680529111
# Book title 'Empathy (English-Farsi).' has all the information. Saving and skipping API call.
# Updating - Title: Batman, Detective Comics. Volume 27, Author: DC Comics, ISBN: nan
# Book title 'My curious dreamer : a bedtime book' has all the information. Saving and skipping API call.
# Book title 'Thomas and the treasure and other stories' has all the information. Saving and skipping API call.
# Book title 'Animal alphabet' has all the information. Saving and skipping API call.
# Book title 'Animals attacking.' has all the information. Saving and skipping API call.
# Updating - Title: Pokémon. Tales of adventure : reader collection., Author: Hidenori Kusaka, ISBN: 9781421560434
# Updating - Title: Mouse Guard : Labyrinth and other stories : a Free Comic Book Day hardcover anthology, Author: nan, ISBN: 9781608864256
# Updating - Title: Eyelike shapes & patterns., Author: Play Bac Publishing, ISBN: 1602140200
# Updating - Title: Eyelike numbers : counting in the natural world., Author: nan, ISBN: nan
# Updating - Title: Eyelike colors : the rainbow of the natural world., Author: nan, ISBN: 9781602140189
# Book title 'The real Mother Goose : yellow husky book' has all the information. Saving and skipping API call.
# Book title 'Beginner's guide to fantasy drawing.' has all the information. Saving and skipping API call.
# Updating - Title: the girl who soared over fairlyland, Author: Catherynne M. Valente, ISBN: 9781466848535
# Book title 'Beginner's guide to digital painting in Photoshop.' has all the information. Saving and skipping API call.
# Book title 'Columbus noir' has all the information. Saving and skipping API call.
# Book title 'Santa Fe noir' has all the information. Saving and skipping API call.
# Book title 'How Yiddish changed America and how America changed Yiddish' has all the information. Saving and skipping API call.
# Book title 'Final Vinyl Days and other stories' has all the information. Saving and skipping API call.
# Updating - Title: Nikki Turner presents Street chronicles : tales from da hood., Author: nan, ISBN: nan
# Book title 'Girls from da hood 4' has all the information. Saving and skipping API call.
# Book title 'Menace : stories' has all the information. Saving and skipping API call.
# Book title 'Girls from da hood 11' has all the information. Saving and skipping API call.
# Book title 'Nikki Turner presents street chronicles : girls in the game.' has all the information. Saving and skipping API call.
# Book title 'Nikki Turner presents Street chronicles : Christmas in the hood.' has all the information. Saving and skipping API call.
# Book title 'Dirty tricks' has all the information. Saving and skipping API call.
# Book title 'Cursed' has all the information. Saving and skipping API call.
# Book title 'Poems and Prints' has all the information. Saving and skipping API call.
# Book title 'Paris, capital of fashion' has all the information. Saving and skipping API call.
# Book title 'A very DC Halloween' has all the information. Saving and skipping API call.
# Book title 'Dogs.' has all the information. Saving and skipping API call.
# Book title 'Man-Kzin wars XV' has all the information. Saving and skipping API call.
# Updating - Title: Oversight of the report on the investigation into Russian interference in the 2016 presidential election : former Special Counsel Robert S. Mueller, III : hearing before the Committee on the Judiciary, House of Representatives, One Hundred Sixteenth Congr, Author: United States. Congress. House. Committee on the Judiciary, ISBN: nan
# Book title 'America the beautiful cross stitch : stitch 30 patterns of America's most iconic national parks and monuments.' has all the information. Saving and skipping API call.
# Updating - Title: Masculinity and Sexuality ion Modern Mexico, Author: Víctor M. Macías-González, ISBN: 9780826329059
# Book title 'Easter parade peekaboo!' has all the information. Saving and skipping API call.
# Book title 'Nordic Europe phrase book & dictionary.' has all the information. Saving and skipping API call.
# Book title 'Webster's New World College Dictionary' has all the information. Saving and skipping API call.
# Book title 'True grit : American prints from 1900 to 1950' has all the information. Saving and skipping API call.
# Book title 'Dragon bike : fantastical stories of bicycling, feminism, and dragons' has all the information. Saving and skipping API call.
# Updating - Title: Korean English visual bilingual dictionary., Author: DK, ISBN: 0241421373
# Book title 'Polish English visual bilingual dictionary' has all the information. Saving and skipping API call.
# Updating - Title: Danish : guaranteed to get you talking, Author: Lonely Planet Publications Staff, ISBN: 9781787014718
# Book title 'Hungarian phrasebook & dictionary.' has all the information. Saving and skipping API call.
# Book title 'Africa : phrasebook & dictionary.' has all the information. Saving and skipping API call.
# Book title 'Hearts of courage' has all the information. Saving and skipping API call.
# Book title 'Den of Lions' has all the information. Saving and skipping API call.
# Book title 'Little America : incredible true stories of immigrants in America' has all the information. Saving and skipping API call.
# Updating - Title: Barcelona and Catalonia : inspire, plan, discover, experience, Author: DK. Eyewitness, ISBN: 9780744062700
# Book title 'Eyewitness. Top 10 Vancouver and Vancouver Island' has all the information. Saving and skipping API call.
# Updating - Title: We count! : a 2020 Census counting book for young children and the grownups who love them, Author: nan, ISBN: nan
# Book title 'Here : poems for the planet' has all the information. Saving and skipping API call.
# Book title 'Time Out Stockholm.' has all the information. Saving and skipping API call.
# Updating - Title: Epic adventures : 245 life-changing expeditions., Author: National Geographic, ISBN: 9781426220616
# Book title 'The dragon quintet' has all the information. Saving and skipping API call.
# Book title 'Living sober.' has all the information. Saving and skipping API call.
# Book title 'Tasty dessert : all the sweet you can eat.' has all the information. Saving and skipping API call.
# Book title 'American birds : a literary companion' has all the information. Saving and skipping API call.
# Book title 'How to tie a shoe & other big adventures' has all the information. Saving and skipping API call.
# Book title 'The green fairy book : complete and unabridged' has all the information. Saving and skipping API call.
# Book title 'Wildstorm : a celebration of 25 years.' has all the information. Saving and skipping API call.
# Book title 'The blue fairy book' has all the information. Saving and skipping API call.
# Updating - Title: Carmen Sandiego. The fishy treasure caper : a graphic novel, Author: Houghton Mifflin Harcourt Publishing Company, ISBN: 9781328495792
# Book title 'Adventure time. Marceline' has all the information. Saving and skipping API call.
# Book title 'The remedy : queer and trans voices on health and health care' has all the information. Saving and skipping API call.
# Updating - Title: The end of trust : McSweeney's 54, Author: James Frederick Smith, ISBN: nan
# Book title 'The yellow fairy book : complete and unabridged' has all the information. Saving and skipping API call.
# Updating - Title: Disney/Pixar Toy story adventures. Volume 2., Author: Alessandro Ferrari, ISBN: 9781506714523
# Updating - Title: Kentucky tax lists by the Kentucky Historical Society, Author: Kentucky Historical Society. Microfilm Dept., ISBN: 9780806310671
# Book title 'No ordinary family' has all the information. Saving and skipping API call.
# Book title 'Into the night : cabarets and clubs in modern art' has all the information. Saving and skipping API call.
# Book title 'Love jelly roll quilts : a baker's dozen of tasty projects for all skill levels' has all the information. Saving and skipping API call.
# Book title 'Costa Rican Spanish phrasebook & dictionary' has all the information. Saving and skipping API call.
# Updating - Title: That we may live : speculative Chinese fiction., Author: Ge Yan, ISBN: 9781949641004
# Book title 'The art of Death Stranding.' has all the information. Saving and skipping API call.
# Book title 'Grilling and campfire cooking.' has all the information. Saving and skipping API call.
# Book title 'Collins easy learning French dictionary.' has all the information. Saving and skipping API call.
# Book title 'Collins easy learning Italian dictionary.' has all the information. Saving and skipping API call.
# Book title 'Democracy unchained : how to rebuild government for the people' has all the information. Saving and skipping API call.
# Book title 'The silver spoon for children : favorite Italian recipes' has all the information. Saving and skipping API call.
# Book title 'Science encyclopedia : atom smashing, food chemistry, animals, space, and more!' has all the information. Saving and skipping API call.
# Book title 'Complete French all-in-one' has all the information. Saving and skipping API call.
# Updating - Title: Japanese myths & tales : an anthology of classic tales, Author: nan, ISBN: nan
# Book title 'Activists and the surveillance state : learning from repression' has all the information. Saving and skipping API call.
# Book title 'The best new true crime stories : serial killers' has all the information. Saving and skipping API call.
# Book title 'Budapest' has all the information. Saving and skipping API call.
# Book title 'Firsts : coming of age stories by people with disabilities' has all the information. Saving and skipping API call.
# Updating - Title: 5 Practice Exams for the GED Test : Extra Prep for a Higher Score, Author: The Princeton Review, ISBN: 9780525569251
# Book title 'Arabic picture dictionary.' has all the information. Saving and skipping API call.
# Book title 'NCLEX-PN content review guide : preparation for the NCLEX-PN examination' has all the information. Saving and skipping API call.
# Book title 'Top 10 Milan and the lakes.' has all the information. Saving and skipping API call.
# Updating - Title: Hebrew-Greek key word study Bible : key insights into God's word : NASB, New American Standard Bible, Author: Warren Patrick Baker, ISBN: 9780899579139
# Book title 'Top 10 Cornwall and Devon.' has all the information. Saving and skipping API call.
# Updating - Title: Disney comics and stories : friends forever., Author: Enrico Faccini, ISBN: 9781684055043
# Book title 'Top 10 Munich.' has all the information. Saving and skipping API call.
# Book title 'Dordogne, Bordeaux and the southwest coast.' has all the information. Saving and skipping API call.
# Book title 'Sweden' has all the information. Saving and skipping API call.
# Updating - Title: The Bloomsbury companion to Bertrand Russell, Author: Russell Wahl, ISBN: 9781474278065
# Book title 'Zondervan NASB study Bible' has all the information. Saving and skipping API call.
# Book title 'Messing about in quotes : a little Oxford dictionary of humorous quotations' has all the information. Saving and skipping API call.
# Book title 'Little Oxford dictionary of proverbs' has all the information. Saving and skipping API call.
# Book title 'Western Europe phrasebook & dictionary.' has all the information. Saving and skipping API call.
# Updating - Title: The green guide : short stays : London., Author: Greg Neale, ISBN: 9781853835964
# Book title 'God is good, y'all! : inspirations to bless your heart' has all the information. Saving and skipping API call.
# Book title 'Time Out Amsterdam.' has all the information. Saving and skipping API call.
# Book title 'Under my thumb : songs that hate women and the women who love them' has all the information. Saving and skipping API call.
# Book title 'Graphic reproduction : a comics anthology' has all the information. Saving and skipping API call.
# Book title 'Easy garden projects : 200+ simple ideas for your yard, garden & home.' has all the information. Saving and skipping API call.
# Book title 'Rotten movies we love : cult classics, underrated gems, and films so bad they're good' has all the information. Saving and skipping API call.
# Updating - Title: The complete dog breed book, Author: DK, ISBN: 146549104X
# Book title 'Mayo Clinic guide to self-care : answers for everyday health problems' has all the information. Saving and skipping API call.
# Updating - Title: The unofficial ultimate Harry Potter spellbook : a complete guide to every spell in the wizarding world., Author: nan, ISBN: nan
# Book title 'The philosophy of Deadpool.' has all the information. Saving and skipping API call.
# Book title 'Woke : a young poet's call to justice' has all the information. Saving and skipping API call.
# Book title 'Bloodshot' has all the information. Saving and skipping API call.
# Updating - Title: Rat queens, vol. 7 : the once and future king, Author: Ryan Ferrier, ISBN: 9781534316812
# Book title 'Xanathar's guide to everything.' has all the information. Saving and skipping API call.
# Book title 'Dinosaurs : a visual encyclopedia.' has all the information. Saving and skipping API call.
# Book title 'Discerning ethics : diverse Christian responses to divisive moral issues' has all the information. Saving and skipping API call.
# Book title 'Chinese picture dictionary.' has all the information. Saving and skipping API call.
# Book title 'Latin American Spanish phrase book & dictionary' has all the information. Saving and skipping API call.
# Updating - Title: Mi primer libro animales del bosque = My first book of forest animals, Author: Anna Lang, ISBN: 9788854038547
# Book title 'Mi Primer Libro Animales del mar =My First book of Sea Animals' has all the information. Saving and skipping API call.
# Book title 'Mi primer libro animals de la granja = My First Book of Farm Animals' has all the information. Saving and skipping API call.
# Book title 'Mi primer libro animales salvajes =My first book of wild animals' has all the information. Saving and skipping API call.
# Book title 'Piero della Francesca' has all the information. Saving and skipping API call.
# Book title 'Bearing witness : stories of the Holocaust' has all the information. Saving and skipping API call.
# Updating - Title: El libro del feminismo =: The Feminism Book., Author: Nawal El Saadawi, ISBN: 9781848139022
# Book title 'En pocas palabras : las recetas + sencillas del mundo.' has all the information. Saving and skipping API call.
# Book title 'Spanish-American poetry : a dual-language anthology' has all the information. Saving and skipping API call.
# Book title 'Collins Korean dictionary.' has all the information. Saving and skipping API call.
# Book title 'The Rise of Skywalker' has all the information. Saving and skipping API call.
# Book title 'Heralds of the siege' has all the information. Saving and skipping API call.
# Book title 'A teacher's heart : 4 historical stories' has all the information. Saving and skipping API call.
# Book title 'Genius loci : tales of the spirit of place' has all the information. Saving and skipping API call.
# Updating - Title: Carmen Sandiego : the sticky rice caper : a graphic novel, Author: Houghton Mifflin Harcourt, ISBN: 9781328495068
# Book title 'Choice words : writers on abortion' has all the information. Saving and skipping API call.
# Book title 'American struggle : teens respond to Jacob Lawrence' has all the information. Saving and skipping API call.
# Updating - Title: Drawing power : women's stories of sexual violence, harassment, and survival : a comics anthology, Author: Diane Noomin, ISBN: 9781683356738
# Book title 'Easy everyday keto : healthy kitchen-perfected recipes' has all the information. Saving and skipping API call.
# Book title 'The expositor's Bible commentary. New Testament' has all the information. Saving and skipping API call.
# Updating - Title: Edgar Allan Poe's snifter of terror, vol. 1, Author: nan, ISBN: nan
# Book title 'Crafting dissent : handicraft as protest from the American Revolution to the pussyhats' has all the information. Saving and skipping API call.
# Book title 'Freehold : resistance' has all the information. Saving and skipping API call.
# Updating - Title: Ingles para la ciudadana., Author: Antonio Carbajo, ISBN: nan
# Book title 'Beyond survival : strategies and stories from the transformative justice movement' has all the information. Saving and skipping API call.
# Book title 'The food we eat, the stories we tell : contemporary Appalachian tables' has all the information. Saving and skipping API call.
# Book title 'Gigantosaurus. The last dragonfly.' has all the information. Saving and skipping API call.
# Book title 'Acting on faith : stories of courage, activism, and hope across religions' has all the information. Saving and skipping API call.
# Book title 'Holy Bible : New King James Version.' has all the information. Saving and skipping API call.
# Book title 'New York City walks : see the city like a local.' has all the information. Saving and skipping API call.
# Book title 'Illusionism : as a theory of consciousness' has all the information. Saving and skipping API call.
# Book title 'Canciones con beso para las buenas noches' has all the information. Saving and skipping API call.
# Book title 'This woman's work : essays on music' has all the information. Saving and skipping API call.
# Book title 'ASVAB prep' has all the information. Saving and skipping API call.
# Book title 'El gran libro de las labores.' has all the information. Saving and skipping API call.
# Book title 'Descubriendo Japón : un viaje a través de la cultura Japonesa' has all the information. Saving and skipping API call.
# Updating - Title: Seville and Andalucia., Author: DK Travel, ISBN: 9780004357959
# Book title 'Sicily.' has all the information. Saving and skipping API call.
# Book title 'Brazil.' has all the information. Saving and skipping API call.
# Book title 'Europe.' has all the information. Saving and skipping API call.
# Book title 'Top 10 Greek Islands.' has all the information. Saving and skipping API call.
# Book title 'Top 10 Scotland.' has all the information. Saving and skipping API call.
# Book title 'Edible : an illustrated guide to the world's food plants.' has all the information. Saving and skipping API call.
# Book title 'The Little red book.' has all the information. Saving and skipping API call.
# Book title 'Pisces : February 20 - March 20' has all the information. Saving and skipping API call.
# Book title 'Ghostbusters : the original movie novelizations' has all the information. Saving and skipping API call.
# Book title 'Foxfire story : oral tradition in Southern Appalachia' has all the information. Saving and skipping API call.
# Book title 'ARIES : March 21-April 20' has all the information. Saving and skipping API call.
# Book title 'CANCER June 22-July 22' has all the information. Saving and skipping API call.
# Updating - Title: Valiant era, Author: Bob Hall, ISBN: nan
# Book title 'Signos y simbolos : guia ilustrada de su origen y significado' has all the information. Saving and skipping API call.
# Book title 'From Hannibal to Saint Augustine : ancient art of North Africa from the Musee du Louvre' has all the information. Saving and skipping API call.
# Book title 'Thomas and the castle' has all the information. Saving and skipping API call.
# Book title 'Thomas the really useful engine' has all the information. Saving and skipping API call.
# Book title 'A is for airplane' has all the information. Saving and skipping API call.
# Updating - Title: Namibia - Kunst einer jungen Generation : Sammlung Würth und Leihgaben in Kooperation mit National Art Gallery of Namibia = Art of a young generation : Würth Collection and loans in cooperation with National Art Gallery of Namibia, Author: nan, ISBN: nan
# Book title 'Alex Katz : prints' has all the information. Saving and skipping API call.
# Book title 'Äpfel und Birnen und anderes Gemüse : die Obstbilder von Korbinian Aigner im Dialog mit der Sammlung Würth' has all the information. Saving and skipping API call.
# Book title 'Moderne Zeiten : Die Nationalgalerie der Staatlichen Museen zu Berlin zu Gast in der Kunsthalle Würth in Schwäbisch Hall' has all the information. Saving and skipping API call.
# Updating - Title: 400-Calorie Instant Pot : 65+ easy & delicious recipes., Author: Susan Westmoreland, ISBN: 9781618373120
# Book title 'American conservatism : reclaiming an intellectual tradition' has all the information. Saving and skipping API call.
# Updating - Title: Toda Raba, Author: Nikos Kazantzakis, ISBN: nan
# Updating - Title: Star wars  [newspaper strips]. v. 01, Author: Various, ISBN: 9781302495794
# Updating - Title: Star wars  [newspaper strips]. v. 02, Author: Jonathan Wilkins, ISBN: 9781785855962
# Updating - Title: Star wars  [newspaper strips]. v. 3, Author: Various, ISBN: 9781302495794
# Updating - Title: The Army, Author: United States Army, ISBN: 9780359946884
# Book title 'Why do we say it? : the stories behind the words, expressions, and cliches we use.' has all the information. Saving and skipping API call.
# Book title 'English for everyone. English grammar guide' has all the information. Saving and skipping API call.
# Book title 'The makers of modern geography' has all the information. Saving and skipping API call.
# Updating - Title: Indiana's prehistoric past, Author: B. K. Swartz, ISBN: nan
# Book title 'More Mediterranean : 225+ new plant-forward recipes endless inspiration for eating well' has all the information. Saving and skipping API call.
# Book title 'Brave new meal' has all the information. Saving and skipping API call.
# Book title 'LSAT premium prep' has all the information. Saving and skipping API call.
# Book title 'Tales from la vida : a Latinx comics anthology' has all the information. Saving and skipping API call.
# Book title 'Gemini : May 22-June 21' has all the information. Saving and skipping API call.
# Book title 'Leo : July 23-August 23' has all the information. Saving and skipping API call.
# Book title 'LatiNext' has all the information. Saving and skipping API call.
# Book title 'Borrowed from your grandchildren : the evolution of 100-year family enterprises' has all the information. Saving and skipping API call.
# Book title 'Brown Bohemians : honoring the light and magic of our creative community' has all the information. Saving and skipping API call.
# Book title 'Scorpio : October 23-November 21' has all the information. Saving and skipping API call.
# Book title 'Michelin green guide Normandy.' has all the information. Saving and skipping API call.
# Book title 'Their Hot Hawaiian Fling' has all the information. Saving and skipping API call.
# Book title 'Deadly anniversaries : celebrating 75 years of Mystery Writers of America' has all the information. Saving and skipping API call.
# Book title '(Don't) call me crazy : 33 voices start the conversation about mental health' has all the information. Saving and skipping API call.
# Book title 'The Nag Hammadi scriptures' has all the information. Saving and skipping API call.
# Book title '#Notyourprincess : voices of Native American women' has all the information. Saving and skipping API call.
# Updating - Title: You too?, Author: Liz Driscoll, ISBN: 9788172542818
# Updating - Title: General Society of the War of 1812 : proceedings 1916-1920., Author: General Society of the War of 1812, ISBN: nan
# Updating - Title: Year book of the Society, Sons of the Revolution, in the Commonwealth of Kentucky, 1905, and Catalogue of military land warrants granted by the Commonwealth of Virginia to soldiers and sailors of the Revolution, Author: Sons of the Revolution. Kentucky Society, ISBN: nan
# Updating - Title: The buck starts here : a guide to assistive technology funding in Kentucky., Author: Kentucky Assistive Technology Service Network, ISBN: nan
# Updating - Title: Oneida Baptist Institute : celebrating 100 years 1899-1999., Author: Oneida Baptist Institute, ISBN: nan
# Updating - Title: Kentucky words and phrases., Author: W. B. Thomas, ISBN: nan
# Updating - Title: Report of the military board of Kentucky : made to the general assembly, september 10, 1861 ... (classic reprint)., Author: Military Board of Kentuky, ISBN: 9781332188048
# Book title 'The political process in Kentucky' has all the information. Saving and skipping API call.
# Updating - Title: Kentucky workmen's compensation law : Acts 1916, with amendments of General Assemblies 1918-20-22-24-26., Author: Kentucky. Workmen's Compensation Board, ISBN: nan
# Book title 'Black women in white America : a documentary history' has all the information. Saving and skipping API call.
# Updating - Title: The Presbyterian Church in the Old Southwest : 1778-1838, Author: Posey, Walter Brownlow, ISBN: nan
# Updating - Title: Legislative history and Capitol souvenir of Kentucky : Portaits and sketches of senators, representatives and officials and attaches of the various state departments., Author: William E. Bidwell, ISBN: 9781341387531
# Updating - Title: Campaign book of facts., Author: Populist Party (N.C.), ISBN: nan
# Updating - Title: Official souvenir book : Knights of Columbus, Louisville Council.., Author: Knights of Columbus. Louisville Council No. 390 (Louisville, Ky.), ISBN: nan
# Updating - Title: 1990 census of population. volume II. Characteristics of the population. Part 17 Kentucky., Author: nan, ISBN: nan
# Updating - Title: Comprehensive manpower plan, fiscal year, 1972., Author: Alabama. State Manpower Coordinating Committee, ISBN: nan
# Updating - Title: Democratic state central committee of Ky. : Democratic documents for the campaign, Author: Democratic Party (Ky.). State Central Committee, ISBN: nan
# Updating - Title: Association of state presidents, past and present, and charter members, of the National Society United States Daughters of 1812, Author: National Society, United States Daughters of 1812, ISBN: nan
# Updating - Title: Memorial to the honorable, the Legislature of Kentucky., Author: Shakers, ISBN: nan
# Updating - Title: New Columbus and the Baptist church in historical perspective, Author: James C. Bryant, ISBN: nan
# Updating - Title: Safer streets., Author: Deborah J. Sims, ISBN: 9781498751476
# Book title 'Nikki Turner presents Backstage : Street chronicles.' has all the information. Saving and skipping API call.
# Book title 'Head, shoulders, knees and toes--' has all the information. Saving and skipping API call.
# Book title 'Brush, brush, brush!' has all the information. Saving and skipping API call.
# Book title 'American Girl cooking : recipes for delicious snacks, meals & more' has all the information. Saving and skipping API call.
# Book title 'MasterChef junior bakes! : bold recipes and essential techniques to inspire young bakers' has all the information. Saving and skipping API call.
# Updating - Title: Another time, another place : novellas, Author: Zane, ISBN: 9781439100417
# Book title 'American Girl holiday baking' has all the information. Saving and skipping API call.
# Book title 'Complete children's cookbook' has all the information. Saving and skipping API call.
# Book title 'Peppa Pig story treasury.' has all the information. Saving and skipping API call.
# Book title 'Galway & the West of Ireland road trips.' has all the information. Saving and skipping API call.
# Book title 'Fodor's Montreal & Quebec City.' has all the information. Saving and skipping API call.
# Updating - Title: The cancer crisis in Appalachia : Kentucky students take action, Author: Nathan L. Vanderford, ISBN: 9781950690053
# Updating - Title: Reducing damage from localized flooding : a guide for communities, Author: United States. Federal Emergency Management Agency, ISBN: nan
# Updating - Title: Teacher shortages and supports for new teachers, Author: Aurelio M. Montemayor, ISBN: nan
# Updating - Title: Tuition, fees, and other costs at Kentucky public universities, Author: nan, ISBN: nan
# Updating - Title: Kentucky child fatality and near fatality external review panel 2018 update, Author: nan, ISBN: nan
# Book title 'Private investigations : mystery writers on the secrets, riddles, and wonders in their lives' has all the information. Saving and skipping API call.
# Updating - Title: The official guide to OET, Author: Gurleen Khaira, ISBN: 9781646789610
# Book title 'TOEFL iBT with 8 online practice tests.' has all the information. Saving and skipping API call.
# Book title '50 successful Harvard Medical School essays' has all the information. Saving and skipping API call.
# Book title 'Where's the unicorn?' has all the information. Saving and skipping API call.
# Updating - Title: A Victorian family Christmas, Author: Gray, Barbara., ISBN: 9780369711212
# Updating - Title: Brown-Forman : nothing better in the market., Author: William F. Lucas, ISBN: 9781614288718
# Updating - Title: The Qurʼān : a revised translation : origins : interpretations and analysis : sounds, sights, and remedies : the Qur'ān in America, Author: Jane Dammen McAuliffe, ISBN: 9780393927054
# Book title 'Round and round the garden' has all the information. Saving and skipping API call.
# Book title 'By the numbers 3.14' has all the information. Saving and skipping API call.
# Updating - Title: National Geographic illustrated guide to wildlife : from your back door to the great outdoors : mammals, birds, reptiles & amphibians, aquatic life, insects & spiders., Author: National Geographic Society (U.S.), ISBN: 9781426213724
# Updating - Title: Reptiles, amphibians & insects : field guide & drawing book : learn how to identify and draw reptiles, amphibians, and insects from the great outdoors!, Author: Walter Foster Creative Team, ISBN: 9781942875840
# Book title 'Middle management in academic and public libraries' has all the information. Saving and skipping API call.
# Book title 'Mulan's perfect present' has all the information. Saving and skipping API call.
# Book title 'The vegetarian silver spoon : classic & contemporary Italian recipes' has all the information. Saving and skipping API call.
# Book title 'TAURUS : April 21-May 21' has all the information. Saving and skipping API call.
# Updating - Title: Airship Genesis, legendary Bible adventure kids study Bible, Author: Dr. David Jeremiah, ISBN: 9780718093907
# Updating - Title: The Wikipedia encyclopedia of serial killers : an A-Z guide to history's most heinous murderers., Author: nan, ISBN: nan
# Book title 'Foolproof fish : modern recipes for everyone, everywhere' has all the information. Saving and skipping API call.
# Book title 'GRE prep 2021' has all the information. Saving and skipping API call.
# Updating - Title: Chicken soup for the soul : dreams and the unexplainable : 101 eye-opening stories about premonitions and miracles, Author: Amy Newmark, ISBN: 9781611592719
# Book title 'Everyday emotional intelligence : big ideas and practical advice on how to be human at work' has all the information. Saving and skipping API call.
# Updating - Title: Chicken soup for the soul : the power of yes! : 101 stories about adventure, change and positive thinking, Author: Amy Newmark, ISBN: 9781611599787
# Updating - Title: Chicken soup for the soul : the best advice I ever heard : 101 stories of epiphanies and wise words, Author: Amy Newmark, ISBN: 9781611592849
# Book title 'I'm a potty superhero : get ready for big-girl pants!' has all the information. Saving and skipping API call.
# Book title 'The rough guide to Provence & the Côte d'Azur' has all the information. Saving and skipping API call.
# Book title 'Egypt.' has all the information. Saving and skipping API call.
# Updating - Title: In her footsteps : where trailblazing women changed the world, Author: Lonely Planet, ISBN: 9781838690670
# Book title 'Alabama noir' has all the information. Saving and skipping API call.
# Updating - Title: The Oxford illustrated math dictionary., Author: Margarita Calderon, ISBN: 9780194071277
# Book title 'BirdNote : chirps, quirks, and stories of 100 birds from the popular public radio show' has all the information. Saving and skipping API call.
# Book title 'Why I like this story' has all the information. Saving and skipping API call.
# Book title 'Our women on the ground : essays by Arab women reporting from the Arab world' has all the information. Saving and skipping API call.
# Book title 'How to live a good life : a guide to choosing your personal philosophy' has all the information. Saving and skipping API call.
# Updating - Title: Philosophers : their lives and works, Author: DK, ISBN: 9780241301722
# Book title 'The best American sports writing. 2019' has all the information. Saving and skipping API call.
# Updating - Title: Livewire, vol. 1 : fugitive, Fugitive, Author: Vita Ayala, ISBN: 9781682153024
# Book title 'Hindi English visual bilingual dictionary.' has all the information. Saving and skipping API call.
# Book title 'Kids bake! : 100+ sweet and savory recipes.' has all the information. Saving and skipping API call.
# Updating - Title: The Goodful cookbook : simple and balanced recipes to live well., Author: Goodful, ISBN: 9780593135501
# Updating - Title: Forest animals : field guide & drawing book : learn how to identify and draw forest animals from the great outdoors!, Author: Walter Foster Creative Team, ISBN: 9781942875857
# Book title 'Elevated : the global rise of the N.B.A.' has all the information. Saving and skipping API call.
# Book title 'The Netherlands.' has all the information. Saving and skipping API call.
# Book title 'Scientists who changed history.' has all the information. Saving and skipping API call.
# Book title 'Fear : 13 stories of suspense and horror' has all the information. Saving and skipping API call.
# Updating - Title: The faking of the president : nineteen stories of White House noir, Author: Peter Carlaftes, ISBN: 9781941110898
# Updating - Title: Wild and free handcrafts : 32 activities from families around the world to build confidence, creativity, and skill, Author: nan, ISBN: nan
# Book title '5 language visual dictionary.' has all the information. Saving and skipping API call.
# Updating - Title: Excel insights : a Microsoft MVP guide to the best parts of Excel : 24 Excel MVPs., Author: 24 Excel Mvps, ISBN: 9781615470679
# Book title 'Welcome to Ponyville.' has all the information. Saving and skipping API call.
# ...
# Book title 'Storms of the inland sea : poems of Alzheimer's and dementia caregiving' has all the information. Saving and skipping API call.
# Book title 'TL;DR Shakespeare : dynamically illustrated plot and character summaries for 12 of shakespeare's greatest plays.' has all the information. Saving and skipping API call.
# Book title 'The World as we knew it : dispatches from a changing climate' has all the information. Saving and skipping API call.
# Updating - Title: Kid astronomer: the space explorer's guide to the galaxy (outer space, astronomy, planets, space books for kids), Author: Applesauce Press, ISBN: 9781646432851
# Updating - Title: Lonely planet kids the amazing night sky atlas, Author: Lonely Planet Kids, ISBN: 9781838695132
# Book title 'Wilderness tales : forty stories of the North American wild' has all the information. Saving and skipping API call.
# Book title 'Dangerous mountain escape.' has all the information. Saving and skipping API call.
# Updating - Title: The Collected Works of Langston Hughes Vol. 2, Author: Langston Hughes, ISBN: 9780826213402
# Book title 'Fever spores : the queer reclamation of William S. Burroughs' has all the information. Saving and skipping API call.
# Book title 'Freedom moves : hip hop knowledges, pedagogies, and futures' has all the information. Saving and skipping API call.
# Book title 'Select Committee to Investigate the January 6th Attack on the United States Capitol : introductory material to the final report of the Select Committee.' has all the information. Saving and skipping API call.
# Updating - Title: Civil rights : hearings before the Committee on Rules, House of Representatives, Eighty-fourth Congress, second session, on H.R. 627, a bill to provide means of further securing and protecting the civil rights of persons within the jurisdiction of the Uni, Author: nan, ISBN: nan
# Updating - Title: Civil rights : hearings before the Committee on Rules, House of Representatives, Eighty-eighth Congress, second session, on H.R. 7152, to enforce the constitutional right to vote, to confer jurisdiction upon the district courts of the United States, to pr, Author: United States. Congress. House. Committee on Rules, ISBN: nan
# Updating - Title: Civil rights : hearings before the Committee on Rules, House of Representatives, Eighty-fifth Congress, first session, on H. R. 6127, a bill to provide means of further securing and protecting the civil rights of persons within the jurisdiction of the Uni, Author: United States. Congress. House. Committee on Rules, ISBN: nan
# Updating - Title: To Prohibit Discrimination in Employment Because of Race, Creed, Color, National Origin or Ancestry hearings before the United States House Committee on Rules, Seventy-Ninth Congress, first session, on Mar. 8, Apr. 19, 20, 25, 26, 1945., Author: United States. Congress. House. Committee on Rules, ISBN: nan
# Updating - Title: The Army Science Board: a history of Army - civilian collaboration in science, Author: Joel Hebert, ISBN: nan
# Updating - Title: Civil rights : Hearing before the Committee on Rules, House of Representatives, Eighty-eighth Congress, second session, on H. Res. 789, a resolution providing that H.R. 7152, the Civil rights bill, shall be taken from the Speaker's table and the Senate am, Author: United States. Congress. House. Committee on Rules, ISBN: nan
# Book title 'Beginner's Guide to Knitting in the Round' has all the information. Saving and skipping API call.
# Book title 'Eudora Welty and mystery : hidden in plain sight' has all the information. Saving and skipping API call.
# Book title '25 ready-to-use sustainable living programs for libraries' has all the information. Saving and skipping API call.
# Book title 'Batter up, Charlie Brown!' has all the information. Saving and skipping API call.
# Updating - Title: Talespin. Flight of the sky-raker and other stories, Author: Bobbi Jg Weiss, ISBN: 9781683965701
# Book title 'Andrei Sakharov and peace' has all the information. Saving and skipping API call.
# Book title 'Fashion in the fairy tale tradition: what Cinderella wore' has all the information. Saving and skipping API call.
# Book title 'Home to the wilderness: a personal journey' has all the information. Saving and skipping API call.
# Book title 'Chicks in tank tops' has all the information. Saving and skipping API call.
# Book title 'Batman : urban legends. Vol. 2.' has all the information. Saving and skipping API call.
# Book title 'Batman : urban legends. Vol. 4' has all the information. Saving and skipping API call.
# Book title 'Nursing school entrance exams prep [2023]' has all the information. Saving and skipping API call.
# Book title 'Encanto: we don't talk about bruno' has all the information. Saving and skipping API call.
# Updating - Title: Tracking trilobites : adventures in paleontology, Author: Judy Lundquist, ISBN: nan
# Book title 'Silly Sally' has all the information. Saving and skipping API call.
# Book title 'Handbook of game-based learning' has all the information. Saving and skipping API call.
# Book title 'Handbook of research on gaming trends in P-12 education' has all the information. Saving and skipping API call.
# Book title 'Happy birthday' has all the information. Saving and skipping API call.
# Updating - Title: The complete guide to healthy drinks : powerhouse ingredients, endless combinations : smoothies, juices, teas, kombucha, infused waters, broths, and more., Author: America's Test Kitchen, ISBN: 9781954210202
# Book title 'Lonely planet wine trails' has all the information. Saving and skipping API call.
# Updating - Title: The lizard prince and other south american stories, Author: Kate Ashwin, ISBN: 9781638991212
# Book title 'The affair.' has all the information. Saving and skipping API call.
# Updating - Title: Why we laugh., Author: Cox, Samuel Sullivan, ISBN: 9780756561765
# Book title 'My child told me they're trans ... what do I do? : a Q&A guide for parents of trans children' has all the information. Saving and skipping API call.
# Book title 'The Math book.' has all the information. Saving and skipping API call.
# Book title 'The Alliance of art and industry : Toledo designs for a modern America.' has all the information. Saving and skipping API call.
# Book title 'Repairing furniture' has all the information. Saving and skipping API call.
# Updating - Title: Pretty pretty Peggy Moffitt, Author: William Pène Du Bois, ISBN: nan
# Book title 'High noon on proxima b' has all the information. Saving and skipping API call.
# Updating - Title: Of wizards and wolves : tales of transformation, Author: David Farland, ISBN: 9781680574197
# Updating - Title: Merriam-Webster's word of the day : 366 elevating utterances to stretch your cranium and tickle your humerus., Author: Merriam-Webster, Inc., ISBN: 9780877791232
# Book title 'Plenty' has all the information. Saving and skipping API call.
# Book title '1917 : stories and poems from the Russian revolution' has all the information. Saving and skipping API call.
# Updating - Title: Ancestors and descendants of Garrett Peterson and Nancy Smock, Author: William L. Peterson, ISBN: nan
# Book title 'Redressing the balance : American women's literary humor from Colonial times to the 1980s' has all the information. Saving and skipping API call.
# Book title 'ACT math prep [2022]' has all the information. Saving and skipping API call.
# Book title 'ACT science prep [2022]' has all the information. Saving and skipping API call.
# Book title 'Twinkle, twinkle, little star' has all the information. Saving and skipping API call.
# Book title 'Grow your own way' has all the information. Saving and skipping API call.
# Updating - Title: Tummy time : a high-contrast sensory book to share with your baby., Author: nan, ISBN: nan
# Updating - Title: Nat Geo Kids Sep 22, Author: nan, ISBN: nan
# Book title 'The loud house super special' has all the information. Saving and skipping API call.
# Updating - Title: My little pony. Volume 1, Big horseshoes to fill., Author: Celeste Bronfman, ISBN: 9798890330437
# Book title 'Headcase : LGBTQ writers and artists on mental health and wellness' has all the information. Saving and skipping API call.
# Updating - Title: The New Yorker encyclopedia of cartoons. Volume 1, A-K, Author: Sara Duke, ISBN: 9781304858887
# Updating - Title: The New Yorker encyclopedia of cartoons. Volume 2, L-Z, Author: nan, ISBN: nan
# Book title 'A 6th bowl of chicken soup for the soul : more stories to open the heart and rekindle the spirit' has all the information. Saving and skipping API call.
# Book title 'The Spice Alphabet Book' has all the information. Saving and skipping API call.
# Book title 'Little elephant's big heart.' has all the information. Saving and skipping API call.
# Updating - Title: Little tortoise's starry night, Author: nan, ISBN: 9781640380165
# Book title 'Lonely planet florence & tuscany' has all the information. Saving and skipping API call.
# Book title 'Superman red and blue' has all the information. Saving and skipping API call.
# Book title 'The Associated Press stylebook, 2022-2024' has all the information. Saving and skipping API call.
# Book title 'Where's the Hen' has all the information. Saving and skipping API call.
# Updating - Title: A history of New Sweden., Author: I. Acrelius, ISBN: nan
# Updating - Title: The St. Johns, a parade of diversities, Author: James Branch Cabell, ISBN: nan
# Book title 'The Savannah' has all the information. Saving and skipping API call.
# Book title 'In the Shaker style : building furniture inspired by the Shaker tradition.' has all the information. Saving and skipping API call.
# Book title 'The yellow house mystery' has all the information. Saving and skipping API call.
# Updating - Title: Quest for the lost powers : four untold tales., Author: Random House, ISBN: 9780593648506
# Book title 'Hulk vs. thor. banner of war' has all the information. Saving and skipping API call.
# Updating - Title: Star Wars. Han Solo & Chewbacca. Vol. 1, The crystal run. Part one., Author: Marc Guggenheim, ISBN: 9781302944186
# Book title 'Stranger things omnibus, volume 1' has all the information. Saving and skipping API call.
# Book title 'Slavery and freedom in the Bluegrass State : revisiting My Old Kentucky Home' has all the information. Saving and skipping API call.
# Book title 'The Life and Crimes of Agatha Christie' has all the information. Saving and skipping API call.
# Book title 'Engaging Appalachia : a guidebook for building capacity and sustainability' has all the information. Saving and skipping API call.
# Book title 'Living well in a down economy' has all the information. Saving and skipping API call.
# Book title 'Vic and Blood: the continuing adventures of a boy and his dog' has all the information. Saving and skipping API call.
# Updating - Title: Freedom of the press from Zenger to Jefferson; early American libertarian theories., Author: Leonard Williams Levy, ISBN: nan
# Book title 'Edward Weston : a legacy' has all the information. Saving and skipping API call.
# Book title 'Unknown masterpieces : writers rediscover literature's hidden classics' has all the information. Saving and skipping API call.
# Book title 'Shamans through time' has all the information. Saving and skipping API call.
# Updating - Title: Anthony Boucher: a biobliography, Author: Jeffrey Marks, ISBN: 9780786483884
# Updating - Title: Le conte de Monte-Cristo (in french) - TWO VOLUMES, Author: Alexandre Dumas, ISBN: 9781293484784
# Updating - Title: Birnbaum's Walt Disney World for kids 2023 : the official guide, Author: Birnbaum Guides, ISBN: 9781368083546
# Book title 'Vehicles' has all the information. Saving and skipping API call.
# Updating - Title: Southwest USA and National Parks [2023], Author: DK Eyewitness, ISBN: 9780744083279
# Book title 'Tokyo [2023]' has all the information. Saving and skipping API call.
# Book title 'My mommy.' has all the information. Saving and skipping API call.
# Book title 'All about Bluey.' has all the information. Saving and skipping API call.
# Updating - Title: Mirabel and the family Madrigal., Author: RH Disney, ISBN: 9780736442831
# Book title 'Rails across America : a history of railroads in North America' has all the information. Saving and skipping API call.
# Book title 'Tistou les pouces verts' has all the information. Saving and skipping API call.
# Book title 'Why the Dutch are Different' has all the information. Saving and skipping API call.
# Book title 'Thomas & friends' has all the information. Saving and skipping API call.
# Updating - Title: Speakin of equality: an analysis of the rhetorical force of yada yada...discourse, Author: nan, ISBN: nan
# Book title 'New suns. 2 : original speculative fiction by people of color' has all the information. Saving and skipping API call.
# Book title 'Stories of bravery!' has all the information. Saving and skipping API call.
# Book title 'Princeton review gre prep, 2024: 5 practice tests + review & techniques + online features' has all the information. Saving and skipping API call.
# Book title 'Wanting: women writing about desire' has all the information. Saving and skipping API call.
# Book title 'Carnage, vol. 1. in the court of crimson' has all the information. Saving and skipping API call.
# Book title 'Princess collection.' has all the information. Saving and skipping API call.
# Book title '5-Minute Avengers stories.' has all the information. Saving and skipping API call.
# Book title 'The explanation of ideology: family structures and social systems' has all the information. Saving and skipping API call.
# Book title 'Policies for an aging society' has all the information. Saving and skipping API call.
# Book title 'Simone Manuel Swimming Star' has all the information. Saving and skipping API call.
# Book title 'Louisville coloring book' has all the information. Saving and skipping API call.
# Book title 'BRIDE BY ROYAL DECREE' has all the information. Saving and skipping API call.
# Book title 'The edinburgh mystery: and other tales of scottish crime' has all the information. Saving and skipping API call.
# Book title 'Austin noir' has all the information. Saving and skipping API call.
# Updating - Title: Persian myths & legends: tales of heroes, gods & monsters, Author: J.K. Jackson, ISBN: 9781804173251
# Book title 'The book of strange but true science.' has all the information. Saving and skipping API call.
# Updating - Title: The essential Gnostic Gospels : including the Gospel of Thomas and the Gospel of Mary Magdalene, Author: Alan Jacobs, ISBN: 9781842932032
# Updating - Title: The Negro leagues are major leagues : essays and research for overdue recognition, Author: Bob Kendrick, ISBN: 9781970159639
# Updating - Title: The life and times of Seargent Smith Prenties, Author: nan, ISBN: nan
# Book title 'Survivor' has all the information. Saving and skipping API call.
# Book title 'Stitch crashes disney' has all the information. Saving and skipping API call.
# Book title 'Why can't we be friends?' has all the information. Saving and skipping API call.
# Book title 'Stamps & Stamps: style & sensibility' has all the information. Saving and skipping API call.
# Updating - Title: The guise of exceptionalism: unmasking the national narratives of Haiti and the U.S., Author: Robert Fatton, ISBN: 9781978821316
# Book title 'Vincent van Gogh: the lost Arles sketchbook' has all the information. Saving and skipping API call.
# Book title 'highlights into the future' has all the information. Saving and skipping API call.
# Updating - Title: KOREA the land the people the culture, Author: Karen L. Gatz, ISBN: nan
# Book title 'The Saracen's mark' has all the information. Saving and skipping API call.
# Book title 'The hedge fund edge: maximum profit/minimum risk global trend trading' has all the information. Saving and skipping API call.
# Book title 'The monstrous-feminine: film, feminism, psychoanalysis' has all the information. Saving and skipping API call.
# Updating - Title: Common snese religion: a guide for renewing your Christian values, Author: Gerald Mann, ISBN: 9780964727205

# %%
# Before Google Books API calls
ol.isna().sum()
# Out:
# Title         0
# Author    10801
# ISBN      23166
# dtype: int64

# %%
# After
book_info_updated.isna().sum()
# Out:
# Title         0
# Author     2554
# ISBN      18012
# dtype: int64

# %% [markdown]
# It's not perfect but got better. Now let's merge the dataframes

# %%
# Merge lfpl_books and book_info_updated based on the 'Title' column
merged_df = pd.merge(lfpl_books, book_info_updated, on='Title', how='left', suffixes=('_lfpl', '_updated'))
merged_df
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1183919  2654213                                 The Saracen's mark
# 1183920  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1183921  2654215  The maid, the man, and the fans: Elivis is the...
# 1183922  2654216  The monstrous-feminine: film, feminism, psycho...
# 1183923  2654217  Common snese religion: a guide for renewing yo...
#
#                        Author_lfpl      ISBN_lfpl  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878             2009     Book
# 1             Miller, Robin, 1964-  9780307451408             2009     Book
# 2             Miller, Robin, 1964-  9780307451408             2009     Book
# 3             Miller, Robin, 1964-  9780307451408             2009     Book
# 4             Miller, Robin, 1964-  9780307451408             2009     Book
# ...                            ...            ...              ...      ...
# 1183919                  Perry, SW                               0     Book
# 1183920              Boucher, Mark                               0     Book
# 1183921  Rooks, Nancy; Gutter, Mae                               0     Book
# 1183922             Creed, Barbara                               0     Book
# 1183923               Mann, Gerald                               0     Book
#
#             ItemCollection            ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                    Main      25.95
# 1        Adult Non-Fiction               Southwest      19.99
# 2        Adult Non-Fiction               Southwest      19.99
# 3        Adult Non-Fiction  Remote Shelving - Main      19.99
# 4        Adult Non-Fiction  Remote Shelving - Main      19.99
# ...                    ...                     ...        ...
# 1183919  Interlibrary Loan                    Main       0.00
# 1183920  Interlibrary Loan                    Main       0.00
# 1183921  Interlibrary Loan                    Main       0.00
# 1183922  Interlibrary Loan                    Main       0.00
# 1183923  Interlibrary Loan                    Main       0.00
#
#                   ReportDate Author_updated   ISBN_updated
# 0        06/01/2023 00:00:00            NaN            NaN
# 1        06/01/2023 00:00:00            NaN            NaN
# 2        06/01/2023 00:00:00            NaN            NaN
# 3        06/01/2023 00:00:00            NaN            NaN
# 4        06/01/2023 00:00:00            NaN            NaN
# ...                      ...            ...            ...
# 1183919  06/01/2023 00:00:00     S.W. Perry     0655663452
# 1183920  06/01/2023 00:00:00   Mark Boucher  9780471185383
# 1183921  06/01/2023 00:00:00    Nancy Rooks  9780533060535
# 1183922  06/01/2023 00:00:00  Barbara Creed  9781136750755
# 1183923  06/01/2023 00:00:00    Gerald Mann  9780964727205
#
# [1183924 rows x 12 columns]

# %%
# These are the rows where the author is missing
rows_missing_author_before = merged_df['Author_lfpl'].isna().sum()
print(rows_missing_author_before)
merged_df[merged_df['Author_lfpl'].isna()]
# Out:
# 65188
#           BibNum                                              Title  \
# 16        813858              Betty Crocker Bisquick to the rescue.
# 17        813858              Betty Crocker Bisquick to the rescue.
# 22           938  The Oxford business Spanish dictionary. Spanis...
# 26           943                                         New houses
# 27           943                                         New houses
# ...          ...                                                ...
# 1183860  2649998                              Stitch crashes disney
# 1183861  2649998                              Stitch crashes disney
# 1183862  2649998                              Stitch crashes disney
# 1183883  2650013                         highlights into the future
# 1183884  2650014              KOREA the land the people the culture
#
#         Author_lfpl      ISBN_lfpl  PublicationYear ItemType  \
# 16              NaN  9780470916575             2011     Book
# 17              NaN  9780470916575             2011     Book
# 22              NaN  9780198604815             2002     Book
# 26              NaN  9780060779993             2005     Book
# 27              NaN  9780060779993             2005     Book
# ...             ...            ...              ...      ...
# 1183860         NaN  9781368080118             2023     Book
# 1183861         NaN  9781368080118             2023     Book
# 1183862         NaN  9781368080118             2023     Book
# 1183883         NaN                               0     Book
# 1183884         NaN                               0     Book
#
#                   ItemCollection            ItemLocation  ItemPrice  \
# 16             Adult Non-Fiction  Remote Shelving - Main      25.00
# 17             Adult Non-Fiction           South Central      19.95
# 22             Adult Non-Fiction                    Main      21.50
# 26             Adult Non-Fiction  Remote Shelving - Main      50.00
# 27             Adult Non-Fiction                 Bon Air      50.00
# ...                          ...                     ...        ...
# 1183860  Children's Picture Book                 Shawnee      13.41
# 1183861  Children's Picture Book             St Matthews      13.41
# 1183862  Children's Picture Book               Southwest      13.41
# 1183883                      NaN           Crescent Hill       0.00
# 1183884                      NaN                 Shively       0.00
#
#                   ReportDate  \
# 16       06/01/2023 00:00:00
# 17       06/01/2023 00:00:00
# 22       06/01/2023 00:00:00
# 26       06/01/2023 00:00:00
# 27       06/01/2023 00:00:00
# ...                      ...
# 1183860  06/01/2023 00:00:00
# 1183861  06/01/2023 00:00:00
# 1183862  06/01/2023 00:00:00
# 1183883  06/01/2023 00:00:00
# 1183884  06/01/2023 00:00:00
#
#                                             Author_updated   ISBN_updated
# 16                                           Betty Crocker     0470916575
# 17                                           Betty Crocker     0470916575
# 22                                             Sinda Lopez     0198604815
# 26       United States. Bureau of the Census. Housing D...            NaN
# 27       United States. Bureau of the Census. Housing D...            NaN
# ...                                                    ...            ...
# 1183860                                       Disney Books  9781368080118
# 1183861                                       Disney Books  9781368080118
# 1183862                                       Disney Books  9781368080118
# 1183883                                    Heather Bingham  9780906421093
# 1183884                                      Karen L. Gatz            NaN
#
# [65188 rows x 12 columns]

# %%
# Update 'Author' column in lfpl_books if missing
merged_df['Author_lfpl'].fillna(merged_df['Author_updated'], inplace=True)
rows_missing_author_after = merged_df['Author_lfpl'].isna().sum()
print('{:,}'.format(rows_missing_author_before-rows_missing_author_after), "were updated with the author name")
merged_df[merged_df['Author_lfpl'].isna()]
# Out:
# 61,726 were updated with the author name
#           BibNum                                              Title  \
# 587      1342105  World War II : the definitive visual history :...
# 588      1342105  World War II : the definitive visual history :...
# 589      1342105  World War II : the definitive visual history :...
# 590      1342105  World War II : the definitive visual history :...
# 591      1342105  World War II : the definitive visual history :...
# ...          ...                                                ...
# 1181174  2643360  Tummy time : a high-contrast sensory book to s...
# 1181175  2643360  Tummy time : a high-contrast sensory book to s...
# 1181304  2641343                                Nat Geo Kids Sep 22
# 1181379  2645006  The New Yorker encyclopedia of cartoons. Volum...
# 1182049  2647143                     Little tortoise's starry night
#
#         Author_lfpl      ISBN_lfpl  PublicationYear ItemType  \
# 587             NaN  9781465436023             2015     Book
# 588             NaN  9781465436023             2015     Book
# 589             NaN  9781465436023             2015     Book
# 590             NaN  9781465436023             2015     Book
# 591             NaN  9781465436023             2015     Book
# ...             ...            ...              ...      ...
# 1181174         NaN  9781684492664             2023     Book
# 1181175         NaN  9781684492664             2023     Book
# 1181304         NaN                               0     Book
# 1181379         NaN   978031643667             2018     Book
# 1182049         NaN  9781640380165             2017     Book
#
#                 ItemCollection            ItemLocation  ItemPrice  \
# 587          Adult Non-Fiction                    Main      40.00
# 588          Adult Non-Fiction           Crescent Hill      40.00
# 589                   Oversize                Fairdale      40.00
# 590                   Oversize                 Bon Air      40.00
# 591          Adult Non-Fiction                 Shawnee      40.00
# ...                        ...                     ...        ...
# 1181174  Children's Board Book           South Central      10.71
# 1181175  Children's Board Book                 Shively      10.71
# 1181304                    NaN  Childrens Main Library       0.00
# 1181379      Adult Non-Fiction                    Main      50.00
# 1182049  Children's Board Book           Jeffersontown       5.99
#
#                   ReportDate Author_updated   ISBN_updated
# 587      06/01/2023 00:00:00            NaN  9780756642785
# 588      06/01/2023 00:00:00            NaN  9780756642785
# 589      06/01/2023 00:00:00            NaN  9780756642785
# 590      06/01/2023 00:00:00            NaN  9780756642785
# 591      06/01/2023 00:00:00            NaN  9780756642785
# ...                      ...            ...            ...
# 1181174  06/01/2023 00:00:00            NaN            NaN
# 1181175  06/01/2023 00:00:00            NaN            NaN
# 1181304  06/01/2023 00:00:00            NaN            NaN
# 1181379  06/01/2023 00:00:00            NaN            NaN
# 1182049  06/01/2023 00:00:00            NaN  9781640380165
#
# [3462 rows x 12 columns]

# %% [markdown]
# Still rows without Author name, but that will be for a future project.
# Let's check the ISBN

# %%
# These are the rows where the ISBN is missing
rows_missing_isbn_before = (merged_df['ISBN_lfpl'] == '').sum()
print(rows_missing_isbn_before)
#merged_df[merged_df['ISBN_lfpl'].isna()]
merged_df[merged_df['ISBN_lfpl'] == '' ]
# Out:
# 35874
#           BibNum                                              Title  \
# 4337     1348353  Stolen legacy: the Egyptian origins of western...
# 5438     1353427  A symposium in public librarianship; three add...
# 5565     1353740                     WWI : the Great War, 1914-1918
# 5566     1353780                                     LANKIE MANTITA
# 6294     1362079                                         Act of War
# ...          ...                                                ...
# 1183919  2654213                                 The Saracen's mark
# 1183920  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1183921  2654215  The maid, the man, and the fans: Elivis is the...
# 1183922  2654216  The monstrous-feminine: film, feminism, psycho...
# 1183923  2654217  Common snese religion: a guide for renewing yo...
#
#                                                Author_lfpl ISBN_lfpl  \
# 4337                                    James, George G. M
# 5438     University of California, Berkeley. School of ...
# 5565         Brown, Hilary (Author of Two-liners for kids)
# 5566                                     LESLIE PATRICELLI
# 6294                                           Brown, Dale
# ...                                                    ...       ...
# 1183919                                          Perry, SW
# 1183920                                      Boucher, Mark
# 1183921                          Rooks, Nancy; Gutter, Mae
# 1183922                                     Creed, Barbara
# 1183923                                       Mann, Gerald
#
#          PublicationYear ItemType     ItemCollection ItemLocation  ItemPrice  \
# 4337                   0     Book  Interlibrary Loan         Main        0.0
# 5438                1952     Book   Kentucky History         Main       25.0
# 5565                2014     Book  Adult Non-Fiction         Main       15.0
# 5566                   0     Book                NaN      Shively        0.0
# 6294                   0     Book                NaN      Bon Air        0.0
# ...                  ...      ...                ...          ...        ...
# 1183919                0     Book  Interlibrary Loan         Main        0.0
# 1183920                0     Book  Interlibrary Loan         Main        0.0
# 1183921                0     Book  Interlibrary Loan         Main        0.0
# 1183922                0     Book  Interlibrary Loan         Main        0.0
# 1183923                0     Book  Interlibrary Loan         Main        0.0
#
#                   ReportDate  \
# 4337     06/01/2023 00:00:00
# 5438     06/01/2023 00:00:00
# 5565     06/01/2023 00:00:00
# 5566     06/01/2023 00:00:00
# 6294     06/01/2023 00:00:00
# ...                      ...
# 1183919  06/01/2023 00:00:00
# 1183920  06/01/2023 00:00:00
# 1183921  06/01/2023 00:00:00
# 1183922  06/01/2023 00:00:00
# 1183923  06/01/2023 00:00:00
#
#                                             Author_updated   ISBN_updated
# 4337                                      George G M James     1494861992
# 5438     University of California, Berkeley. School of ...            NaN
# 5565                                   Stevan Eldred-Grigg     1869792637
# 5566                                                   NaN            NaN
# 6294                 Canada. Parliament. House of Commons.     0659021676
# ...                                                    ...            ...
# 1183919                                         S.W. Perry     0655663452
# 1183920                                       Mark Boucher  9780471185383
# 1183921                                        Nancy Rooks  9780533060535
# 1183922                                      Barbara Creed  9781136750755
# 1183923                                        Gerald Mann  9780964727205
#
# [35874 rows x 12 columns]

# %%
# Update 'Author' column in lfpl_books if missing
#merged_df['Author_lfpl'].fillna(merged_df['Author_updated'], inplace=True)
#rows_missing_author_after = merged_df['Author_lfpl'].isna().sum()
#print('{:,}'.format(rows_missing_author_before-rows_missing_author_after), "were updated with the author name")
#merged_df[merged_df['Author_lfpl'].isna()]

# Update 'ISBN' column in lfpl_books if missing or empty string
#merged_df['ISBN_lfpl'] = merged_df.apply(lambda row: row['ISBN_updated'] if pd.isna(row['ISBN_lfpl']) or row['ISBN_lfpl'] == '' else row['ISBN_lfpl'], axis=1)
merged_df['ISBN_lfpl'] = merged_df.apply(lambda row: row['ISBN_updated'] if row['ISBN_lfpl'] == '' else row['ISBN_lfpl'], axis=1)
rows_missing_isbn_after = (merged_df['ISBN_lfpl'] == '').sum()
print(rows_missing_isbn_after)
# Out:
# 0

# %%
print('{:,}'.format(rows_missing_isbn_before-rows_missing_isbn_after), "were updated with the ISBN number")

#merged_df[merged_df['ISBN_lfpl'].isna()]
merged_df[merged_df['ISBN_lfpl'].isna()]
# Out:
# 35,874 were updated with the ISBN number
#           BibNum                                              Title  \
# 5438     1353427  A symposium in public librarianship; three add...
# 5566     1353780                                     LANKIE MANTITA
# 6329     1364527                            Double strand deception
# 6330     1364528                               Murder simply played
# 6331     1364529                         Secrets of the Amish diary
# ...          ...                                                ...
# 1182277   482233             The St. Johns, a parade of diversities
# 1182453   463308  Freedom of the press from Zenger to Jefferson;...
# 1182862  2647629  Speakin of equality: an analysis of the rhetor...
# 1183818  2649990      The life and times of Seargent Smith Prenties
# 1183884  2650014              KOREA the land the people the culture
#
#                                                Author_lfpl ISBN_lfpl  \
# 5438     University of California, Berkeley. School of ...       NaN
# 5566                                     LESLIE PATRICELLI       NaN
# 6329                     McCrite, K. D. (Kathaleen Deiser)       NaN
# 6330                                  Phillips, Rachael O.       NaN
# 6331                                  Phillips, Rachael O.       NaN
# ...                                                    ...       ...
# 1182277                   Cabell, James Branch, 1879-1958.       NaN
# 1182453     Levy, Leonard W. (Leonard Williams), 1923-2006       NaN
# 1182862                                      Westen, Peter       NaN
# 1183818                              Shields, Joseph et al       NaN
# 1183884                                      Karen L. Gatz       NaN
#
#          PublicationYear ItemType     ItemCollection            ItemLocation  \
# 5438                1952     Book   Kentucky History                    Main
# 5566                   0     Book                NaN                 Shively
# 6329                2015     Book            Mystery           South Central
# 6330                2016     Book            Mystery           South Central
# 6331                2016     Book            Mystery           South Central
# ...                  ...      ...                ...                     ...
# 1182277             1943     Book  Adult Non-Fiction                Iroquois
# 1182453             1966     Book  Adult Non-Fiction  Remote Shelving - Main
# 1182862                0     Book  Interlibrary Loan                    Main
# 1183818                0     Book  Interlibrary Loan                    Main
# 1183884                0     Book                NaN                 Shively
#
#          ItemPrice           ReportDate  \
# 5438         25.00  06/01/2023 00:00:00
# 5566          0.00  06/01/2023 00:00:00
# 6329         19.99  06/01/2023 00:00:00
# 6330         19.99  06/01/2023 00:00:00
# 6331         19.99  06/01/2023 00:00:00
# ...            ...                  ...
# 1182277      25.00  06/01/2023 00:00:00
# 1182453      25.00  06/01/2023 00:00:00
# 1182862       0.00  06/01/2023 00:00:00
# 1183818       0.00  06/01/2023 00:00:00
# 1183884       0.00  06/01/2023 00:00:00
#
#                                             Author_updated ISBN_updated
# 5438     University of California, Berkeley. School of ...          NaN
# 5566                                                   NaN          NaN
# 6329                                          K.D. McCrite          NaN
# 6330                                      Rachael Phillips          NaN
# 6331                                       Rachel phillips          NaN
# ...                                                    ...          ...
# 1182277                                James Branch Cabell          NaN
# 1182453                              Leonard Williams Levy          NaN
# 1182862                                                NaN          NaN
# 1183818                                                NaN          NaN
# 1183884                                      Karen L. Gatz          NaN
#
# [21710 rows x 12 columns]

# %%
# Drop unnecessary columns
merged_df.drop(['Author_updated', 'ISBN_updated'], axis=1, inplace=True)

# Rename the updated columns
merged_df.rename(columns={'Author_lfpl': 'Author', 'ISBN_lfpl': 'ISBN'}, inplace=True)

# Display the resulting DataFrame
merged_df
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1183919  2654213                                 The Saracen's mark
# 1183920  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1183921  2654215  The maid, the man, and the fans: Elivis is the...
# 1183922  2654216  The monstrous-feminine: film, feminism, psycho...
# 1183923  2654217  Common snese religion: a guide for renewing yo...
#
#                             Author           ISBN  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878             2009     Book
# 1             Miller, Robin, 1964-  9780307451408             2009     Book
# 2             Miller, Robin, 1964-  9780307451408             2009     Book
# 3             Miller, Robin, 1964-  9780307451408             2009     Book
# 4             Miller, Robin, 1964-  9780307451408             2009     Book
# ...                            ...            ...              ...      ...
# 1183919                  Perry, SW     0655663452                0     Book
# 1183920              Boucher, Mark  9780471185383                0     Book
# 1183921  Rooks, Nancy; Gutter, Mae  9780533060535                0     Book
# 1183922             Creed, Barbara  9781136750755                0     Book
# 1183923               Mann, Gerald  9780964727205                0     Book
#
#             ItemCollection            ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                    Main      25.95
# 1        Adult Non-Fiction               Southwest      19.99
# 2        Adult Non-Fiction               Southwest      19.99
# 3        Adult Non-Fiction  Remote Shelving - Main      19.99
# 4        Adult Non-Fiction  Remote Shelving - Main      19.99
# ...                    ...                     ...        ...
# 1183919  Interlibrary Loan                    Main       0.00
# 1183920  Interlibrary Loan                    Main       0.00
# 1183921  Interlibrary Loan                    Main       0.00
# 1183922  Interlibrary Loan                    Main       0.00
# 1183923  Interlibrary Loan                    Main       0.00
#
#                   ReportDate
# 0        06/01/2023 00:00:00
# 1        06/01/2023 00:00:00
# 2        06/01/2023 00:00:00
# 3        06/01/2023 00:00:00
# 4        06/01/2023 00:00:00
# ...                      ...
# 1183919  06/01/2023 00:00:00
# 1183920  06/01/2023 00:00:00
# 1183921  06/01/2023 00:00:00
# 1183922  06/01/2023 00:00:00
# 1183923  06/01/2023 00:00:00
#
# [1183924 rows x 10 columns]

# %%
merged_df.dtypes
# Out:
# BibNum               int64
# Title               object
# Author              object
# ISBN                object
# PublicationYear      int64
# ItemType            object
# ItemCollection      object
# ItemLocation        object
# ItemPrice          float64
# ReportDate          object
# dtype: object

# %%
import pandas.api.types as pd_types

inferred_dtype = pd_types.infer_dtype(merged_df['ISBN'])
inferred_dtype
# Out:
# 'string'

# %%
# Specify the file path
data_folder = 'data'
csv_file_path = os.path.join(data_folder, 'lfpl_new.csv.gz')

# Save merged_df to a compressed CSV file (gzip compression)
merged_df.to_csv(csv_file_path, index=False, compression='gzip')
