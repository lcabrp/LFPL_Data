# %%
import pandas as pd
import requests
import time
import json
import gzip
import csv
#from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# ## Analizing the books at the LFPL libraries

# %%
# Read the csv file
# LFPL's collection inventory. Updated on a monthly basis.
lfpl_books = pd.read_csv('https://www.arcgis.com/sharing/rest/content/items/372216992aea4b2cb5b02837d7a48eaf/data')
lfpl_books
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1674146  2654219                                Emma of 83rd Street
# 1674147  2654219                                Emma of 83rd Street
# 1674148  2654219                                Emma of 83rd Street
# 1674149  2654220                                      The Sea Witch
# 1674150  2654221                          Murder with Earl Grey Tea
#
#                        Author          ISBN  PublicationYear    ItemType  \
# 0         Magee, David, 1965-  9.780072e+12             2009        Book
# 1        Miller, Robin, 1964-  9.780307e+12             2009        Book
# 2        Miller, Robin, 1964-  9.780307e+12             2009        Book
# 3        Miller, Robin, 1964-  9.780307e+12             2009        Book
# 4        Miller, Robin, 1964-  9.780307e+12             2009        Book
# ...                       ...           ...              ...         ...
# 1674146        Harding, Emily  9.781797e+12             2023  Eaudiobook
# 1674147        Harding, Emily  9.781797e+12             2023  Eaudiobook
# 1674148        Harding, Emily  9.781797e+12             2023  Eaudiobook
# 1674149         Robert, Katee  9.781951e+12             2020  Eaudiobook
# 1674150     Smith, Karen Rose  9.781497e+12             2023       Ebook
#
#             ItemCollection            ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                    Main      25.95
# 1        Adult Non-Fiction               Southwest      19.99
# 2        Adult Non-Fiction               Southwest      19.99
# 3        Adult Non-Fiction  Remote Shelving - Main      19.99
# 4        Adult Non-Fiction  Remote Shelving - Main      19.99
# ...                    ...                     ...        ...
# 1674146         Electronic                    Main       0.00
# 1674147         Electronic                    Main       0.00
# 1674148         Electronic                    Main       0.00
# 1674149         Electronic                    Main       0.00
# 1674150         Electronic                    Main       0.00
#
#                   ReportDate
# 0        06/01/2023 00:00:00
# 1        06/01/2023 00:00:00
# 2        06/01/2023 00:00:00
# 3        06/01/2023 00:00:00
# 4        06/01/2023 00:00:00
# ...                      ...
# 1674146  06/01/2023 00:00:00
# 1674147  06/01/2023 00:00:00
# 1674148  06/01/2023 00:00:00
# 1674149  06/01/2023 00:00:00
# 1674150  06/01/2023 00:00:00
#
# [1674151 rows x 10 columns]

# %%
# Leaving only Books in the dataframe
lfpl_books = lfpl_books[lfpl_books['ItemType'] == 'Book']
lfpl_books
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1674140  2654213                                 The Saracen's mark
# 1674141  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1674142  2654215  The maid, the man, and the fans: Elivis is the...
# 1674143  2654216  The monstrous-feminine: film, feminism, psycho...
# 1674144  2654217  Common snese religion: a guide for renewing yo...
#
#                             Author          ISBN  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9.780072e+12             2009     Book
# 1             Miller, Robin, 1964-  9.780307e+12             2009     Book
# 2             Miller, Robin, 1964-  9.780307e+12             2009     Book
# 3             Miller, Robin, 1964-  9.780307e+12             2009     Book
# 4             Miller, Robin, 1964-  9.780307e+12             2009     Book
# ...                            ...           ...              ...      ...
# 1674140                  Perry, SW           NaN                0     Book
# 1674141              Boucher, Mark           NaN                0     Book
# 1674142  Rooks, Nancy; Gutter, Mae           NaN                0     Book
# 1674143             Creed, Barbara           NaN                0     Book
# 1674144               Mann, Gerald           NaN                0     Book
#
#             ItemCollection            ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                    Main      25.95
# 1        Adult Non-Fiction               Southwest      19.99
# 2        Adult Non-Fiction               Southwest      19.99
# 3        Adult Non-Fiction  Remote Shelving - Main      19.99
# 4        Adult Non-Fiction  Remote Shelving - Main      19.99
# ...                    ...                     ...        ...
# 1674140  Interlibrary Loan                    Main       0.00
# 1674141  Interlibrary Loan                    Main       0.00
# 1674142  Interlibrary Loan                    Main       0.00
# 1674143  Interlibrary Loan                    Main       0.00
# 1674144  Interlibrary Loan                    Main       0.00
#
#                   ReportDate
# 0        06/01/2023 00:00:00
# 1        06/01/2023 00:00:00
# 2        06/01/2023 00:00:00
# 3        06/01/2023 00:00:00
# 4        06/01/2023 00:00:00
# ...                      ...
# 1674140  06/01/2023 00:00:00
# 1674141  06/01/2023 00:00:00
# 1674142  06/01/2023 00:00:00
# 1674143  06/01/2023 00:00:00
# 1674144  06/01/2023 00:00:00
#
# [1184052 rows x 10 columns]

# %% [markdown]
# ## The plan is to enrich this dataset using the Google API. The ISBN will be used to pull the required information from the API. In order to achieve that, we need to check the non valid values in the ISBN column. let's do some cleaning first

# %%
# Check the types
lfpl_books.dtypes
# Out:
# BibNum               int64
# Title               object
# Author              object
# ISBN               float64
# PublicationYear      int64
# ItemType            object
# ItemCollection      object
# ItemLocation        object
# ItemPrice          float64
# ReportDate          object
# dtype: object

# %%
shape = lfpl_books.shape
print(f"Rows: {shape[0]:,}, Columns: {shape[1]}")
# Out:
# Rows: 1,184,052, Columns: 10

# %%
# Finding how many NaN values per column
lfpl_books.isna().sum()
# Out:
# BibNum                 0
# Title                  1
# Author             65644
# ISBN               36527
# PublicationYear        0
# ItemType               0
# ItemCollection       202
# ItemLocation           0
# ItemPrice              0
# ReportDate             0
# ObjectId               0
# dtype: int64

# %%
# Drop rows with missing values in the 'Title' column
lfpl_books = lfpl_books.dropna(subset=['Title'])
lfpl_books.loc[lfpl_books['Title'].isna() ]
# Out:
# Empty DataFrame
# Columns: [BibNum, Title, Author, ISBN, PublicationYear, ItemType, ItemCollection, ItemLocation, ItemPrice, ReportDate]
# Index: []

# %%
# Looking for missing author and ISBN
lfpl_books.loc[(lfpl_books['Author'].isna()) & (lfpl_books['ISBN'].isna())]
# Out:
#           BibNum                                  Title Author  ISBN  \
# 17100    1375916                                 Laptop    NaN   NaN
# 17101    1375916                                 Laptop    NaN   NaN
# 17102    1375916                                 Laptop    NaN   NaN
# 17103    1375916                                 Laptop    NaN   NaN
# 17104    1375916                                 Laptop    NaN   NaN
# ...          ...                                    ...    ...   ...
# 1669175  2647142           Little elephant's big heart.    NaN   NaN
# 1671387  2647603            Why the Dutch are Different    NaN   NaN
# 1672187  2646832              The Saga of Gosta Berling    NaN   NaN
# 1673882  2650013             highlights into the future    NaN   NaN
# 1673883  2650014  KOREA the land the people the culture    NaN   NaN
#
#          PublicationYear ItemType         ItemCollection   ItemLocation  \
# 17100                  0     Book                 Laptop  South Central
# 17101                  0     Book                 Laptop  South Central
# 17102                  0     Book                 Laptop           Main
# 17103                  0     Book                 Laptop           Main
# 17104                  0     Book                 Laptop           Main
# ...                  ...      ...                    ...            ...
# 1669175             2017     Book  Children's Board Book  Jeffersontown
# 1671387                0     Book                    NaN      Southwest
# 1672187             2006     Book              Adult DVD           Main
# 1673882                0     Book                    NaN  Crescent Hill
# 1673883                0     Book                    NaN        Shively
#
#          ItemPrice           ReportDate
# 17100      1077.00  06/01/2023 00:00:00
# 17101      1077.00  06/01/2023 00:00:00
# 17102       900.31  06/01/2023 00:00:00
# 17103       900.31  06/01/2023 00:00:00
# 17104       900.31  06/01/2023 00:00:00
# ...            ...                  ...
# 1669175       5.99  06/01/2023 00:00:00
# 1671387       0.00  06/01/2023 00:00:00
# 1672187      74.19  06/01/2023 00:00:00
# 1673882       0.00  06/01/2023 00:00:00
# 1673883       0.00  06/01/2023 00:00:00
#
# [6721 rows x 10 columns]

# %% [markdown]
# Apparently the Laptops are included as books in this dataset.

# %%
lfpl_books[lfpl_books['Title'] == 'Laptop']
# Out:
#         BibNum   Title Author  ISBN  PublicationYear ItemType ItemCollection  \
# 17100  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17101  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17102  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17103  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17104  1375916  Laptop    NaN   NaN                0     Book         Laptop
# ...        ...     ...    ...   ...              ...      ...            ...
# 17197  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17198  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17199  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17200  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 17201  1375916  Laptop    NaN   NaN                0     Book         Laptop
#
#         ItemLocation  ItemPrice           ReportDate
# 17100  South Central    1077.00  06/01/2023 00:00:00
# 17101  South Central    1077.00  06/01/2023 00:00:00
# 17102           Main     900.31  06/01/2023 00:00:00
# 17103           Main     900.31  06/01/2023 00:00:00
# 17104           Main     900.31  06/01/2023 00:00:00
# ...              ...        ...                  ...
# 17197  South Central    1077.00  06/01/2023 00:00:00
# 17198  South Central    1077.00  06/01/2023 00:00:00
# 17199  South Central    1077.00  06/01/2023 00:00:00
# 17200  South Central    1077.00  06/01/2023 00:00:00
# 17201  South Central    1077.00  06/01/2023 00:00:00
#
# [102 rows x 10 columns]

# %%
# Dropping all the laptops from the dataset
lfpl_books = lfpl_books.loc[lfpl_books['Title'] != 'Laptop']
lfpl_books[lfpl_books['Title'] == 'Laptop']
# Out:
# Empty DataFrame
# Columns: [BibNum, Title, Author, ISBN, PublicationYear, ItemType, ItemCollection, ItemLocation, ItemPrice, ReportDate]
# Index: []

# %% [markdown]
# The ISBN column has several values NaN. We need this value populated to use the Google API in order to obtain more information about the book.
# The easiest solution is to drop all these rows. Before doing that, we will attempt to obtain the ISBN number using the book's title.
# The main challenge is that API calls are pretty slow.
# For the records: I tried several methods to speed up the process using multithreading, but that made things worse: the API were returning errors.

# %% [markdown]
# ## First we will change the data type from float to string on the ISBN

# %%
lfpl_books['ISBN'] = lfpl_books['ISBN'].astype(str)
lfpl_books
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1674140  2654213                                 The Saracen's mark
# 1674141  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1674142  2654215  The maid, the man, and the fans: Elivis is the...
# 1674143  2654216  The monstrous-feminine: film, feminism, psycho...
# 1674144  2654217  Common snese religion: a guide for renewing yo...
#
#                             Author             ISBN  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878.0             2009     Book
# 1             Miller, Robin, 1964-  9780307451408.0             2009     Book
# 2             Miller, Robin, 1964-  9780307451408.0             2009     Book
# 3             Miller, Robin, 1964-  9780307451408.0             2009     Book
# 4             Miller, Robin, 1964-  9780307451408.0             2009     Book
# ...                            ...              ...              ...      ...
# 1674140                  Perry, SW              nan                0     Book
# 1674141              Boucher, Mark              nan                0     Book
# 1674142  Rooks, Nancy; Gutter, Mae              nan                0     Book
# 1674143             Creed, Barbara              nan                0     Book
# 1674144               Mann, Gerald              nan                0     Book
#
#             ItemCollection            ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                    Main      25.95
# 1        Adult Non-Fiction               Southwest      19.99
# 2        Adult Non-Fiction               Southwest      19.99
# 3        Adult Non-Fiction  Remote Shelving - Main      19.99
# 4        Adult Non-Fiction  Remote Shelving - Main      19.99
# ...                    ...                     ...        ...
# 1674140  Interlibrary Loan                    Main       0.00
# 1674141  Interlibrary Loan                    Main       0.00
# 1674142  Interlibrary Loan                    Main       0.00
# 1674143  Interlibrary Loan                    Main       0.00
# 1674144  Interlibrary Loan                    Main       0.00
#
#                   ReportDate
# 0        06/01/2023 00:00:00
# 1        06/01/2023 00:00:00
# 2        06/01/2023 00:00:00
# 3        06/01/2023 00:00:00
# 4        06/01/2023 00:00:00
# ...                      ...
# 1674140  06/01/2023 00:00:00
# 1674141  06/01/2023 00:00:00
# 1674142  06/01/2023 00:00:00
# 1674143  06/01/2023 00:00:00
# 1674144  06/01/2023 00:00:00
#
# [1183949 rows x 10 columns]

# %% [markdown]
# ## There is an extra '.0' on the string. Let's remove it

# %%
lfpl_books['ISBN'] = lfpl_books['ISBN'].astype(str).str.rstrip('.0')
lfpl_books
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1674140  2654213                                 The Saracen's mark
# 1674141  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1674142  2654215  The maid, the man, and the fans: Elivis is the...
# 1674143  2654216  The monstrous-feminine: film, feminism, psycho...
# 1674144  2654217  Common snese religion: a guide for renewing yo...
#
#                             Author           ISBN  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878             2009     Book
# 1             Miller, Robin, 1964-  9780307451408             2009     Book
# 2             Miller, Robin, 1964-  9780307451408             2009     Book
# 3             Miller, Robin, 1964-  9780307451408             2009     Book
# 4             Miller, Robin, 1964-  9780307451408             2009     Book
# ...                            ...            ...              ...      ...
# 1674140                  Perry, SW            nan                0     Book
# 1674141              Boucher, Mark            nan                0     Book
# 1674142  Rooks, Nancy; Gutter, Mae            nan                0     Book
# 1674143             Creed, Barbara            nan                0     Book
# 1674144               Mann, Gerald            nan                0     Book
#
#             ItemCollection            ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                    Main      25.95
# 1        Adult Non-Fiction               Southwest      19.99
# 2        Adult Non-Fiction               Southwest      19.99
# 3        Adult Non-Fiction  Remote Shelving - Main      19.99
# 4        Adult Non-Fiction  Remote Shelving - Main      19.99
# ...                    ...                     ...        ...
# 1674140  Interlibrary Loan                    Main       0.00
# 1674141  Interlibrary Loan                    Main       0.00
# 1674142  Interlibrary Loan                    Main       0.00
# 1674143  Interlibrary Loan                    Main       0.00
# 1674144  Interlibrary Loan                    Main       0.00
#
#                   ReportDate
# 0        06/01/2023 00:00:00
# 1        06/01/2023 00:00:00
# 2        06/01/2023 00:00:00
# 3        06/01/2023 00:00:00
# 4        06/01/2023 00:00:00
# ...                      ...
# 1674140  06/01/2023 00:00:00
# 1674141  06/01/2023 00:00:00
# 1674142  06/01/2023 00:00:00
# 1674143  06/01/2023 00:00:00
# 1674144  06/01/2023 00:00:00
#
# [1183949 rows x 10 columns]

# %%
# ISBN is an string now
lfpl_books.dtypes
# Out:
# BibNum               int64
# Title               object
# Author              object
# ISBN                object
# PublicationYear      int64
# ItemType            object
# ItemCollection      object
# ItemLocation        object
# ItemPrice          float64
# ReportDate          object
# dtype: object

# %%
# Nothing is NaN after the conversion, it's the string 'nan' instead
lfpl_books[lfpl_books['ISBN'] == 'nan']
# Out:
#           BibNum                                              Title  \
# 4968     1348353  Stolen legacy: the Egyptian origins of western...
# 7938     1353427  A symposium in public librarianship; three add...
# 8150     1353740                     WWI : the Great War, 1914-1918
# 8165     1353780                                     LANKIE MANTITA
# 10449    1362079                                         Act of War
# ...          ...                                                ...
# 1674140  2654213                                 The Saracen's mark
# 1674141  2654214  The hedge fund edge: maximum profit/minimum ri...
# 1674142  2654215  The maid, the man, and the fans: Elivis is the...
# 1674143  2654216  The monstrous-feminine: film, feminism, psycho...
# 1674144  2654217  Common snese religion: a guide for renewing yo...
#
#                                                     Author ISBN  \
# 4968                                    James, George G. M  nan
# 7938     University of California, Berkeley. School of ...  nan
# 8150         Brown, Hilary (Author of Two-liners for kids)  nan
# 8165                                     LESLIE PATRICELLI  nan
# 10449                                          Brown, Dale  nan
# ...                                                    ...  ...
# 1674140                                          Perry, SW  nan
# 1674141                                      Boucher, Mark  nan
# 1674142                          Rooks, Nancy; Gutter, Mae  nan
# 1674143                                     Creed, Barbara  nan
# 1674144                                       Mann, Gerald  nan
#
#          PublicationYear ItemType     ItemCollection ItemLocation  ItemPrice  \
# 4968                   0     Book  Interlibrary Loan         Main        0.0
# 7938                1952     Book   Kentucky History         Main       25.0
# 8150                2014     Book  Adult Non-Fiction         Main       15.0
# 8165                   0     Book                NaN      Shively        0.0
# 10449                  0     Book                NaN      Bon Air        0.0
# ...                  ...      ...                ...          ...        ...
# 1674140                0     Book  Interlibrary Loan         Main        0.0
# 1674141                0     Book  Interlibrary Loan         Main        0.0
# 1674142                0     Book  Interlibrary Loan         Main        0.0
# 1674143                0     Book  Interlibrary Loan         Main        0.0
# 1674144                0     Book  Interlibrary Loan         Main        0.0
#
#                   ReportDate
# 4968     06/01/2023 00:00:00
# 7938     06/01/2023 00:00:00
# 8150     06/01/2023 00:00:00
# 8165     06/01/2023 00:00:00
# 10449    06/01/2023 00:00:00
# ...                      ...
# 1674140  06/01/2023 00:00:00
# 1674141  06/01/2023 00:00:00
# 1674142  06/01/2023 00:00:00
# 1674143  06/01/2023 00:00:00
# 1674144  06/01/2023 00:00:00
#
# [35899 rows x 10 columns]

# %%
# Changing 'nan' to an empty string
lfpl_books['ISBN'] = lfpl_books['ISBN'].replace('nan', '')

# %%
isbn_length = lfpl_books['ISBN'].str.len().value_counts()
isbn_length
# Out:
# ISBN
# 13    1034288
# 12     102386
# 0       35899
# 11      10083
# 10       1146
# 9         142
# 8           4
# 7           1
# Name: count, dtype: int64

# %%
# Open Books API test. Trying to use compression, if possible, to reduce the size of the data transfered over the network
# Exploring all the information available on the API
import requests
import gzip
from io import BytesIO

def get_book_info(book_name):
    base_url = "https://openlibrary.org/search.json"

    response = requests.get(base_url, params={'q': book_name})

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Check if the response is gzip compressed
        if 'Content-Encoding' in response.headers and response.headers['Content-Encoding'] == 'gzip':
            # Parse the JSON response from a gzip-compressed content
            with gzip.GzipFile(fileobj=BytesIO(response.content), mode='rb') as gz:
                data = gz.read().decode('iso-8859-1')
        else:
            # If not compressed, decode as utf-8
            data = response.content.decode('utf-8')

        # Display information from the JSON response
        data = response.json()

        if 'docs' in data and data['docs']:
            first_book = data['docs'][0]

            # Traverse and display information
            for key, value in first_book.items():
                print(f"{key}: {value}")
        else:
            print(f"No information found for the book: {book_name}")
    else:
        print(f"Error: Unable to fetch information for the book {book_name}")

# Example: Get information for the book "The Great Gatsby"
#get_book_info("The Great Gatsby")
get_book_info("Old Creole days")
# Out:
# key: /works/OL2178936W
# type: work
# seed: ['/books/OL13555446M', '/books/OL18604806M', '/books/OL6971233M', '/books/OL7091166M', '/books/OL6742373M', '/books/OL6979450M', '/books/OL7056325M', '/books/OL6941435M', '/books/OL22333180M', '/books/OL472097M', '/books/OL6971091M', '/books/OL24178541M', '/books/OL13537061M', '/books/OL23747649M', '/books/OL7113470M', '/books/OL7125200M', '/books/OL7036468M', '/books/OL24178424M', '/books/OL22347396M', '/books/OL15038444M', '/books/OL23765223M', '/books/OL6456144M', '/books/OL16249535M', '/books/OL16207376M', '/books/OL4433761M', '/books/OL5444026M', '/books/OL5302549M', '/books/OL3666101M', '/books/OL2204587M', '/books/OL9769056M', '/books/OL9818132M', '/books/OL9817453M', '/books/OL11976116M', '/works/OL2178936W', '/subjects/fiction', '/subjects/creoles_in_fiction', '/subjects/creoles', '/subjects/social_life_and_customs', '/subjects/louisiana_in_fiction', '/subjects/city_and_town_life', '/subjects/history', '/subjects/fiction_general', '/subjects/louisiana_fiction', '/subjects/new_orleans_(la.)_fiction', '/subjects/creoles_fiction', '/subjects/fiction_historical_general', '/subjects/manners_and_customs', '/subjects/place:louisiana', '/subjects/place:new_orleans_(la.)', '/authors/OL276008A']
# title: Old Creole days
# title_suggest: Old Creole days
# title_sort: Old Creole days
# subtitle: a story of Creole life
# edition_count: 33
# edition_key: ['OL13555446M', 'OL18604806M', 'OL6971233M', 'OL7091166M', 'OL6742373M', 'OL6979450M', 'OL7056325M', 'OL6941435M', 'OL22333180M', 'OL472097M', 'OL6971091M', 'OL24178541M', 'OL13537061M', 'OL23747649M', 'OL7113470M', 'OL7125200M', 'OL7036468M', 'OL24178424M', 'OL22347396M', 'OL15038444M', 'OL23765223M', 'OL6456144M', 'OL16249535M', 'OL16207376M', 'OL4433761M', 'OL5444026M', 'OL5302549M', 'OL3666101M', 'OL2204587M', 'OL9769056M', 'OL9818132M', 'OL9817453M', 'OL11976116M']
# publish_date: ['1892', '1898', '1937', '1879', '1906', '1943', '1969', 'November 3, 2006', '1944', '1907', '1989', '1970', '1883', 'June 2, 2007', '1918', '1974', '1890', '1897', '1961', '1884', '1991', '1921', '1902', 'March 1, 2007', '1900']
# publish_year: [1918, 1974, 1892, 1898, 2006, 1890, 1937, 1879, 1897, 1906, 1943, 2007, 1961, 1884, 1991, 1921, 1969, 1902, 1944, 1907, 1989, 1970, 1883, 1900]
# first_publish_year: 1879
# number_of_pages_median: 260
# lccn: ['37010499', '72084524', '06021886', '04015080', '43017083', '07004814', '79083932', '98195535', '89026517', '30012336', '73096486', '06022271', '2002559667', '07001237']
# publish_place: ['New York, N.Y', 'New York', 'St. Clair Shores, Mich', '[New York]', 'Miami, Fla', 'Edinburgh', 'Gretna, La']
# oclc: ['1426130', '9630676', '18454516', '10392442', '47515', '715531', '20010699', '180877646', '318220241', '625387', '1846685', '1954831', '715521', '4789835', '11200507', '6564930', '66789327']
# contributor: ['Biklé, Lucy Leffingwell Cable, 1875-', 'Rogers, Bruce, 1870-1957, former owner.', "Cosgrave, John O'Hara, 1908-1968, ill.", 'Limited Editions Club,', 'Herter, Albert.', 'Grau, Shirley Ann.', 'Pforzheimer Bruce Rogers Collection (Library of Congress)', 'Bikle, Lucy Leffingwell Cable, 1875-', 'Tinker, Edward Larocque, 1881-1968.', "Cosgrave, John O'Hara, 1908-1968", 'Copyright Paperback Collection (Library of Congress)', 'Herter, Albert, illus.', 'American Book-Stratford Press,', 'Hearn, Lafcadio, 1850-1904.']
# lcc: ['PS-1244.00000000 O5', 'PS-1244.00000000.O6 1892', 'PZ-0003.00000000.C11 O23', 'PS-1244.00000000.O4', 'E--0185.00000000.M57 v.82', 'PZ-0003.00000000.C11 O9', 'PZ-0003.00000000.C11 O5', 'PZ-0003.00000000.C11 O26', 'PS-1244.00000000 O6', 'PZ-0003.00000000.C11 O6', 'PS-1244.00000000.O6 1943', 'PZ-0003.00000000.C11 O18', 'PZ-0003.00000000.C11 O', 'PZ-0003.00000000.C11 O4', 'PS-1244.00000000.O6 1991', 'PZ-0003.00000000.C11 O3', 'PS-1244.00000000 O4', 'PZ-0003.00000000.C11 O21', 'PS-1244.00000000 O3', 'PS-1244.00000000 O23', 'PS-1244.00000000 O26', 'PS-1244.00000000 O', 'PS-1244.00000000 O21', 'PS-1244.00000000 O4 1884']
# ddc: ['-813.49', '813.49', '813.4']
# isbn: ['1434621154', '9781406841442', '143462143X', '9781406903607', '9781434621436', '0512000654', '9780882897806', '0403030560', '9780512000651', '0882897802', '1406903604', '9781434621153', '0451523490', '1406841447', '9780403030569', '9780451523495']
# last_modified_i: 1672302958
# ebook_count_i: 15
# ebook_access: public
# has_fulltext: True
# public_scan_b: True
# ia: ['oldcreoledays00cabliala', 'oldcreoledayscabl', 'oldcreoledays00cabluoft', 'oldcreoledaysbyg00cabl', 'cu31924022052181', 'oldcreoledays0000unse_c2y9', 'oldcreoledayssto00cablrich', 'oldcreoledays00cablrich', 'storycreolelife00cablrich', 'cu31924021995851', 'oldcreoledaysby00cablgoog', 'oldcreoledays0000cabl', 'oldcreoledays0001cabl', 'oldcreoledays00cabl', 'oldcreoledayssto00cabl']
# ia_collection: ['americana', 'binghamton-ol', 'cdl', 'china', 'cornell', 'docsouth', 'gwulibraries-ol', 'inlibrary', 'internetarchivebooks', 'library_of_congress', 'marygrovecollege', 'printdisabled', 'robarts', 'toronto', 'trent_university', 'unclibraries', 'universityofarizona-ol', 'universityofcoloradoboulder-ol']
# ia_collection_s: americana;binghamton-ol;cdl;china;cornell;docsouth;gwulibraries-ol;inlibrary;internetarchivebooks;library_of_congress;marygrovecollege;printdisabled;robarts;toronto;trent_university;unclibraries;universityofarizona-ol;universityofcoloradoboulder-ol
# lending_edition_s: OL7091166M
# lending_identifier_s: oldcreoledays00cabliala
# printdisabled_s: OL6456144M;OL4433761M;OL5444026M;OL2204587M
# readinglog_count: 9
# want_to_read_count: 9
# currently_reading_count: 0
# already_read_count: 0
# cover_edition_key: OL2204587M
# cover_i: 680648
# publisher: ['The Limited Editions Club', "Scribner's", 'Echo Library', "C. Scribner's sons", 'Scribner', 'Mnemosyne Pub. Co.', 'Hard Press', "Charles Scribner's Sons", 'D. Douglas', 'New American Library', 'Pelican Pub. Co.', "Charles Scribner's sons", 'Scholarly Press', 'Garrett Press', 'The Limited editions club', "C. Scribner's Sons", 'BiblioBazaar']
# language: ['eng']
# author_key: ['OL276008A']
# author_name: ['George Washington Cable']
# author_alternative_name: ['George Washington 1844-1925 Cable', 'W. George Cable', 'Washington George Cable', 'George W. Cable', 'Cable, George Washington, 1844-1925']
# place: ['Louisiana', 'New Orleans (La.)']
# subject: ['Fiction', 'Creoles in fiction', 'Creoles', 'Social life and customs', 'Louisiana in fiction', 'City and town life', 'History', 'Fiction, general', 'Louisiana, fiction', 'New orleans (la.), fiction', 'Creoles, fiction', 'Fiction, historical, general', 'Manners and customs']
# id_goodreads: ['1939321', '5137185', '4463533', '1719509', '165142']
# id_librarything: ['146405']
# ia_loaded_id: ['oldcreoledayssto00cabl']
# ia_box_id: ['IA109504', 'IA170901', 'IA1676504', 'IA1784318', '00009518344', 'IA40771018']
# publisher_facet: ['BiblioBazaar', "C. Scribner's Sons", "C. Scribner's sons", "Charles Scribner's Sons", "Charles Scribner's sons", 'D. Douglas', 'Echo Library', 'Garrett Press', 'Hard Press', 'Mnemosyne Pub. Co.', 'New American Library', 'Pelican Pub. Co.', 'Scholarly Press', 'Scribner', "Scribner's", 'The Limited Editions Club', 'The Limited editions club']
# place_key: ['louisiana', 'new_orleans_(la.)']
# subject_facet: ['City and town life', 'Creoles', 'Creoles in fiction', 'Creoles, fiction', 'Fiction', 'Fiction, general', 'Fiction, historical, general', 'History', 'Louisiana in fiction', 'Louisiana, fiction', 'Manners and customs', 'New orleans (la.), fiction', 'Social life and customs']
# _version_: 1767911175342784512
# place_facet: ['Louisiana', 'New Orleans (La.)']
# lcc_sort: PS-1244.00000000.O6 1892
# author_facet: ['OL276008A George Washington Cable']
# subject_key: ['city_and_town_life', 'creoles', 'creoles_fiction', 'creoles_in_fiction', 'fiction', 'fiction_general', 'fiction_historical_general', 'history', 'louisiana_fiction', 'louisiana_in_fiction', 'manners_and_customs', 'new_orleans_(la.)_fiction', 'social_life_and_customs']
# ddc_sort: 813.49

# %%
# Modifying the previous script to only return the ISBN number. Handling some exceptions.
import requests
import gzip
from io import BytesIO
import time

def get_book_isbn(book_title, max_retries=3):
    base_url = "https://openlibrary.org/search.json"
    
    for attempt in range(max_retries + 1):
        try:
            # Sending a request to the Open Books API with the book title
            response = requests.get(base_url, params={'q': book_title})

            # Check if the request was successful (status code 200)
            response.raise_for_status()

            # Check if the response is gzip compressed
            if 'Content-Encoding' in response.headers and response.headers['Content-Encoding'] == 'gzip':
                # Parse the JSON response from a gzip-compressed content
                with gzip.GzipFile(fileobj=BytesIO(response.content), mode='rb') as gz:
                    data = gz.read().decode('iso-8859-1')
            else:
                # If not compressed, decode as utf-8
                data = response.content.decode('utf-8')

            # Parse the JSON response
            data = response.json()

            if 'docs' in data and data['docs']:
                first_book = data['docs'][0]

                # Check if ISBN information is available
                if 'isbn' in first_book:
                    # Return the ISBN
                    return first_book['isbn'][0] if first_book['isbn'] else ""
                else:
                    print(f"ISBN information not found for the book: {book_title}")
                    return ""
            else:
                print(f"No information found for the book: {book_title}")
                return ""

        except requests.exceptions.HTTPError as e:
            if attempt < max_retries and e.response.status_code == 429:
                # Retry if the status code is 429 (Too Many Requests)
                retry_after = int(e.response.headers.get('Retry-After', 5))  # Default to 5 seconds if Retry-After is not present
                print(f"Retrying after {retry_after} seconds due to status code 429 (Too Many Requests)...")
                time.sleep(retry_after)
            else:
                print(f"Error: {e}")
                return ""

isbn = get_book_isbn("The Great Gatsby")
print(f"ISBN: {isbn}")
# Out:
# ISBN: 9788484504382

# %%
# Function to apply to the DataFrame
def fill_missing_isbn(row):
    if row["ISBN"] == '':
        return get_book_isbn(row["Title"])
    else:
        return row["ISBN"]

# %%
# Example DataFrame
data = {
    "Title": ["Cognitive Mapping : Past, Present, and Future","LANKIE MANTITA", "WWI : the Great War, 1914-1918", "the girl in the road", "Sharp Edges", "My First Pet"],
    "ISBN": ["", "", "", "", "",""]
}

df = pd.DataFrame(data)

# Apply the function using lambda only to rows with missing ISBN
df["ISBN"] = df.apply(lambda row: fill_missing_isbn(row), axis=1)

print(df)
# Out:
# No information found for the book: LANKIE MANTITA
#                                            Title           ISBN
# 0  Cognitive Mapping : Past, Present, and Future     1315812282
# 1                                 LANKIE MANTITA
# 2                 WWI : the Great War, 1914-1918     1869792637
# 3                           the girl in the road  9798791410146
# 4                                    Sharp Edges  9780671524098
# 5                                   My First Pet  9781405309035

# %%
# Testing with the Open Library Books API - v2

def get_isbn_from_openlibrary(title):
    base_url = "http://openlibrary.org/search.json"
    params = {"title": title}
    response = requests.get(base_url, params, headers={"Accept-Encoding": "gzip"})
    if response.status_code == 429:
        retry_after = int(response.headers.get("Retry-After"))
        print(f"API rate limit exceeded. Retrying after {retry_after} seconds.")
        time.sleep(retry_after)
        return get_isbn_from_openlibrary(title)
    if response.status_code != 200:
        print(f"Error retrieving ISBN for title '{title}': {response.status_code}")
        return None
    content_type = response.headers.get("Content-Type")
    if content_type == "application/gzip":
        with gzip.decompress(response.content) as decompressed_data:
            data = json.loads(decompressed_data.decode("utf-8"))
    else:
        data = json.loads(response.content.decode("utf-8"))
    isbn = data.get("docs")[0].get("isbn")[0] if data.get("docs") and data.get("docs")[0].get("isbn") else None
    return isbn

isbn = get_isbn_from_openlibrary("The Great Gatsby")
print(f"ISBN: {isbn}")
# Out:
# ISBN: 9788484504382

# %%
import pandas as pd

# read the original CSV file
df = pd.read_csv('data\openlib_isbn.csv')

# drop rows with missing ISBN values
df = df.dropna(subset=['ISBN'])
df = df.drop_duplicates()

# write the updated DataFrame to a new CSV file
df.to_csv('data\openlib_isbn_1.csv', index=False)

# %%
# Using the Open Library API. Saving to a csv because this will require multiple runs: API will block too many calls.
# Check if the CSV file exists
import os

# Check if the CSV file exists
csv_file = 'data\openlib_isbn.csv'
csv_exists = os.path.exists(csv_file)

# If the CSV file doesn't exist, create an empty DataFrame with headers
if not csv_exists:
    isbn_openlib = pd.DataFrame(columns=['Title', 'ISBN'], dtype='str')
    isbn_openlib.to_csv(csv_file, index=False)

# Identify the remaining rows that need processing
remaining_rows = lfpl_books.loc[lfpl_books['ISBN'] == '', 'Title'].drop_duplicates()

# Iterate over remaining rows
for title in remaining_rows:
    # Check if the title is already in isbn_openlib DataFrame
    if title not in isbn_openlib['Title'].values:
        try:
            # Obtain ISBN using the get_book_isbn function
            isbn = get_book_isbn(title)

            # Concatenate the result to the DataFrame
            #if isbn:
                # Concatenate the result to the DataFrame
            new_row = pd.DataFrame({'Title': [title], 'ISBN': [isbn]})
            isbn_openlib = pd.concat([isbn_openlib, new_row], ignore_index=True)
                
            # Append the new row to the CSV file
            new_row.to_csv(csv_file, index=False, header=not csv_exists, mode='a')

            # Update csv_exists flag
            csv_exists = True

        except Exception as e:
            print(f"Error processing title '{title}': {e}")
    # Remove rows with blank ISBNs from the CSV file
#isbn_openlib = pd.read_csv(csv_file)
#isbn_openlib = isbn_openlib[isbn_openlib['ISBN'] != '']
#isbn_openlib.to_csv(csv_file, index=False)        
      #isbn_openlib.drop_duplicates(subset='Title', inplace=True) # Just in case there are some duplicates(it shouldn't)
# Out:
# No information found for the book: 1850 U. S. census, Amelia County, Virginia
# No information found for the book: 1850 U. S. census, Oldham County, Kentucky
# No information found for the book: 1850 U. S. census, Owen County, Kentucky
# No information found for the book: 1850 U. S. census, Owsley County, Kentucky
# No information found for the book: 1850 U. S. census, Pendleton County, Kentucky
# No information found for the book: 1850 U. S. census, Scott County, Kentucky
# No information found for the book: 1850 U. S. census, Simpson County, Kentucky
# No information found for the book: 1850 U. S. census, Spencer County, Kentucky
# No information found for the book: 1850 U.S. census, Trigg County, Kentucky
# ISBN information not found for the book: Three Gloucester plays
# No information found for the book: 1850 U. S. census, Boyle County, Kentucky
# ISBN information not found for the book: Nelson County Kentucky records
# ISBN information not found for the book: The floods of 1913 in the rivers of the Ohio and lower Mississippi valleys
# No information found for the book: The New Madrid fault : living in earthquake country
# ISBN information not found for the book: 1990 census of population and housing. Summary social, economic, and housing characteristics. South Dakota.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Lafayette-West Lafayette, IN MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Fayetteville-Springdale, AR MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Jackson, MI MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Benton Harbor, MI MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Macon-Warner Robins, GA MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Casper, WY MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Iowa (outside metropolitan areas).
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Kansas (outside metropolitan areas).
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Tennessee (outside metropolitan areas).
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Idaho (outside metropolitan areas).
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Hickory-Morganton, NC MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Burlington, NC MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Charleston, SC MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Nashville, TN MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Fresno, CA MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Columbia, SC MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Salt Lake City-Ogden, UT MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Raleigh-Durham, NC MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. North Carolina (outside metropolitan areas).
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Mississippi (outside metropolitan areas).
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Illinois (outside metropolitan areas).
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Joplin, MO MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Lawrence, KS MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Wichita, KS MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Des Moines, IA MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Stockton, CA MSA.
# ISBN information not found for the book: English art, 1100-1216.
# ISBN information not found for the book: English art, 1216-1307
# No information found for the book: Louisville's greatest flood : Jeffersonville and New Albany, Indiana.
# ISBN information not found for the book: The flood: the great 1937 disaster.
# ISBN information not found for the book: Directory of Kentucky Librarians
# No information found for the book: History of the Church of the Annunciation of Paris, Kentucky : on the occasion of the centenary of the church
# No information found for the book: Reader's theatre from Kentucky
# ISBN information not found for the book: Louisville survey
# ISBN information not found for the book: Western cavaliers : embracing the history of the Methodist Episcopal Church in Kentucky from 1832 to 1844 / By A. H. Redford.
# No information found for the book: Kentucky's approach to economic growth
# ISBN information not found for the book: Final report of Commissioners of Sewerage of Louisville (Incorporated) : Work done upon the comprehensive system of sewers, from December 27, 1919, to November 30, 1942.
# ISBN information not found for the book: Belle of Louisville : Ohio River steamboat
# No information found for the book: Branches of our tree : Supper, Sippel, Schultz, Thompson, Birks, Mertens, Schuett, Kreer, Berger, Haun
# ISBN information not found for the book: Common synonyms for chemicals listed under Section 313 of the Emergency Planning and Community Right-to-Know Act.
# ISBN information not found for the book: Green River country from Bowling Green to Evansville, its traffic, its resources, its towns and its people ...
# ISBN information not found for the book: History of Anson County, North Carolina, 1750-1976
# ISBN information not found for the book: The Order of the Founders and Patriots of America register, lineages of associates, 1896-1993.
# ISBN information not found for the book: Records of colonial Gloucester County, Virginia a collection of abstracts from original documents concerning the lands and people of colonial Gloucester County
# No information found for the book: Resegregation worsens under new desegregation plan, 1984-85 : plan assigns highest numbers of black students, teachers, and administrators to west-area high schools ; highest numbers of whites to outer county high schools.
# No information found for the book: Food service desegregation : experience with nonsegregated service in Kentucky eating establishments, July 1961
# No information found for the book: Kentucky civil rights decisions 1972-1984 : courts uphold General Assembly's strengthening of state law.
# No information found for the book: Jefferson County school desegration unfinished : pupil desegration increases, but teacher gaps remain : report for 1978-79 and 1979-80.
# No information found for the book: Fayette County public schools maintain segregation, 1972-73 -- 1984-85 : almost two of three schools fail to meet student and faculty guidelines.
# No information found for the book: Jefferson County schools miss desegregation goals : 1977-78 figures show gains greatest in areas monitored by U. S. Court.
# No information found for the book: Jefferson County school resegregration increases, 1982-1983
# No information found for the book: Property values in Louisville's changing neighborhoods : analyzing the effect of minority entry on real estate values
# No information found for the book: The first year of Kentucky's fair housing act
# No information found for the book: Fair housing : myth vs fact.
# No information found for the book: School and housing desegregation are working together in Louisville and Jefferson County, 1975-1983 : the nine-year old county-wide desegregation plan has proven successful despite implementation problems.
# No information found for the book: Women miners : complaints of sex discrimination force coal industry to end "male-only" tradition.
# No information found for the book: School desegregation spurs first housing desegregation gain in forty years in Louisville and Jefferson County : three decades of increased segregation erased between 1970 and 1980.
# No information found for the book: Kentucky's universities made little progress in hiring more tenure-track women : ten year report, 1975-1985.
# No information found for the book: New elementary and middle school assignment plans creating dual school system, 1985-86.
# No information found for the book: Desegregation improves at housing authorities with plans, worsens at authorities without plans, 1986.
# ISBN information not found for the book: Your state highway system
# ISBN information not found for the book: Historic Kentucky highways.
# No information found for the book: Jefferson County and Louisville have most segregated public housing in Kentucky : desegration accelerates at most authorities between July 1984 and July 1985.
# No information found for the book: Aquatic biota and water quality survey of the Appalachian province, eastern Kentucky : technical report
# No information found for the book: Aquatic biota and water quality survey of the upper Cumberland River basin
# No information found for the book: Wild rivers : Kentucky wild rivers statewide management plan
# No information found for the book: Apartment discrimination in Fayette County declines to 6.9 percent : black and white team testing shows 43.6 per cent decline in discrimination between 1977 and 1985.
# ISBN information not found for the book: Kentucky descendants of Colonel Morgan Morgan
# No information found for the book: Current and projected socioeconomic conditions of the Levisa Fork of the Big Sandy River Basin of Kentucky and Virginia
# No information found for the book: Macroinvertebrates of the Big Sandy River Basin : with special emphasis on the Levisa Fork
# No information found for the book: Geologic structure and mine roof falls in selected coal beds within Appalachia
# ISBN information not found for the book: Mountain bumps in the coal fields of Harlan County, Kentucky
# No information found for the book: The National flood insurance program in Kentucky
# ISBN information not found for the book: Historical records needs assessment : final report
# ISBN information not found for the book: The Kentucky Department for Libraries and Archives.
# No information found for the book: The Ichthyofauna of the Big Sandy River Basin, with special emphasis on the Levisa Fork drainage
# No information found for the book: Reflections of the past : a guide to archival resources in Kentucky
# No information found for the book: Recommendations for Kentucky's outstanding resource water classifications with water quality criteria for protection : technical report prepared for and submitted to Division of Water, Department for Environmental Protection, Kentucky Natural Resources an
# No information found for the book: Fishes of the lower Green River drainage, Kentucky
# No information found for the book: Fishes of the Dix River, Kentucky
# No information found for the book: Environmental inventory : Little South Fork, Wild River, Kentucky
# No information found for the book: Trophic state and restoration assessments of Kentucky Lakes : final report.
# No information found for the book: The floods of April : a report on the April 1977 flood in southeastern Kentucky : staff study
# ISBN information not found for the book: Program review : Real Estate Education, Research and Recovery Fund
# No information found for the book: Motor vehicle licensing : a review of inventory and audit procedures
# No information found for the book: The Kentucky Export Resources Authority, Inc. (KERA)
# ISBN information not found for the book: Loss of farmland in Kentucky : a report
# ISBN information not found for the book: Handbook of Kentucky libraries
# No information found for the book: Floodplain management : the experiences of three Kentucky communities.
# ISBN information not found for the book: Interstate bridges and ferries
# ISBN information not found for the book: Kentucky's constitutional development.
# ISBN information not found for the book: Criminal procedure: new trial and arrest of judgment.
# No information found for the book: Criminal procedure: bail and recognizance.
# No information found for the book: Legislative report: National Education Association hearings : transcript of proceedings, Louisville, Kentucky, November 11-13, 1970.
# ISBN information not found for the book: Court of justice : a look at Kentucky's new judicial system
# No information found for the book: Sanitary sewer needs for Jefferson County
# ISBN information not found for the book: A report to the citizens of Kentucky ...
# No information found for the book: Memorandum book of John Todd : written during September 1774 on a march against the Indians from Camp Union, Virginia, to the Ohio River.
# No information found for the book: Henry Stites Barker: an address by Governor Simeon Willis.
# No information found for the book: The inauguration of Herman Lee Donovan as the sixth president of the University of Kentucky : May 6, 1942.
# ISBN information not found for the book: Split-log drag.
# No information found for the book: The personal income tax in Kentucky : a statistical analysis of returns for 1937
# No information found for the book: Distribution of the woody plants of Kentucky in relation to geologic regions.
# No information found for the book: Geology of the Big Clifty quadrangle
# No information found for the book: History of the Eager family, from the coming of the first immigrant, William Eager, in 1630 to date, 1952.
# ISBN information not found for the book: A history of the Henry family from its beginnings in this country to the present time; including a supplement
# ISBN information not found for the book: Michael Reasor and Anna Herbert descendants, and related families of Brown, Pectol, Galloway, Scott, Razor, and McCutcheon.
# ISBN information not found for the book: History and genealogy of the Jacob Turpin branch of the Turpin family, being a brief history and genealogy of the members of the first and second generations, and a genealogy of the members of all other generations down to the present time
# ISBN information not found for the book: An American saga; the story of the Snead family of Accomac County, Virginia, and of Kentucky.
# ISBN information not found for the book: The Rixey genealogy, with references to the Morehead, Hunton, Gibbs, Hall, Thomas, Jones, Lewis, Chancellor, Pendleton, Smith, and other allied families
# ISBN information not found for the book: Stories of the Foreign Legion
# ISBN information not found for the book: Lexington's first city directory, published by Joseph Charless for the year 1806.
# ISBN information not found for the book: Lexington's second city directory, published by William Worsley and Thomas Smith for the year 1818.
# ISBN information not found for the book: 1880 federal census, Hopkins County, Kentucky
# ISBN information not found for the book: Hopkins County, Kentucky minute book, 1816-1818
# ISBN information not found for the book: Our ancestral plots
# ISBN information not found for the book: Warren County, Kentucky, cemetery records

# %%
isbn_openlib
# Out:
#                                                   Title           ISBN
# 0     Stolen legacy: the Egyptian origins of western...     1494861992
# 1     A symposium in public librarianship; three add...
# 2                        WWI : the Great War, 1914-1918     1869792637
# 3                                        LANKIE MANTITA
# 4                                            Act of War     0659021676
# ...                                                 ...            ...
# 3205                                      First season.  9780333118702
# 3206  A mirror for England; British movies from aust...     0571095038
# 3207  The annals and scandals of Henderson County, K...
# 3208                                          Jerusalem     1379313074
# 3209        Two hundred poems from the Greek anthology.
#
# [3210 rows x 2 columns]

# %%
# Option 1
# Step 1: Create a new DataFrame with unique book titles and empty ISBNs
unique_titles = lfpl_books.loc[lfpl_books['ISBN'] == '', 'Title'].drop_duplicates().reset_index(drop=True)
isbn_openlib = pd.DataFrame({'Title': unique_titles})
isbn_openlib
# Out:
#                                                    Title
# 0      Stolen legacy: the Egyptian origins of western...
# 1      A symposium in public librarianship; three add...
# 2                         WWI : the Great War, 1914-1918
# 3                                         LANKIE MANTITA
# 4                                             Act of War
# ...                                                  ...
# 27980              KOREA the land the people the culture
# 27981                                 The Saracen's mark
# 27982  The hedge fund edge: maximum profit/minimum ri...
# 27983  The monstrous-feminine: film, feminism, psycho...
# 27984  Common snese religion: a guide for renewing yo...
#
# [27985 rows x 1 columns]

# %%
# Step 2 and 3: Use the get_book_isbn function to obtain ISBNs
isbn_openlib['ISBN'] = isbn_openlib['Title'].apply(get_book_isbn)
isbn_openlib
# Out:
# ISBN information not found for the book: A symposium in public librarianship; three addresses
# No information found for the book: LANKIE MANTITA
# ISBN information not found for the book: Pieces from the past
# ISBN information not found for the book: Double strand deception
# ISBN information not found for the book: Murder simply played
# ISBN information not found for the book: Secrets of the Amish diary
# ISBN information not found for the book: Proper tension
# ISBN information not found for the book: A dangerous tide
# ISBN information not found for the book: Plain deception
# ISBN information not found for the book: Celtic chains
# ISBN information not found for the book: Simple lies
# ISBN information not found for the book: Double cross crochet
# ISBN information not found for the book: Where hope dwells
# ISBN information not found for the book: A ring of deception
# ISBN information not found for the book: Humble pies and white lies
# ISBN information not found for the book: Law & old order
# ISBN information not found for the book: Minor works
# ISBN information not found for the book: Wagon Wheels
# No information found for the book: Chengdu : the real China
# ISBN information not found for the book: Bing ya
# No information found for the book: Cost and policy considerations for state-mandated local public notices.
# No information found for the book: State inmates housed in county jails in Kentucky
# ISBN information not found for the book: Women of Job Corps.
# No information found for the book: Program : Tenth-Anniversary Convention of the National League of Women Voters, 1920-1930, Brown Hotel, Louisville, Kentucky, April 28-May 3, 1930.
# No information found for the book: Transylvania bicentennial celebration, 1735, 1775, 1935 : in commemoration of the opening of the Trans-Allegheny West by the Transylvanians at Boonesborough, Kentucky, Oct. 12, 1935, under the presidency of Archibald Henderson.
# No information found for the book: West Main Street - 300 block. designation report expanding the West Main Street preservation district to include the 300 block
# No information found for the book: Xaverian Brothers' centennial in America : 1854-1954.
# ISBN information not found for the book: Cumulative index to publications of the Committee on Un-American Activities, 1938-1954
# ISBN information not found for the book: Night combat.
# No information found for the book: Kentucky child fatality and near fatality external review panel
# ISBN information not found for the book: Review of the safe schools program
# No information found for the book: Sate funding of the Bluegrass Water Supply Commission
# No information found for the book: Confederate Veteran Association of Kentucky : constitution, by-laws and list of membership, arranged by counties and camps : with name, rank, residence and command of every member in his own county camp, if one has been organized, or in the John C. Brecki
# No information found for the book: History of Okolona, Buechel, Hikes Point, and Wet Woods.
# ISBN information not found for the book: Simba and Nala at play : a book about opposites.
# ISBN information not found for the book: Baby Mickey's nap : a book about touch.
# ISBN information not found for the book: Farm friends : a book about animal sounds.
# ISBN information not found for the book: Bambi's big surprise : a book about action words.
# ISBN information not found for the book: Good night, baby Donald : a book about counting
# No information found for the book: The complete adventures of Peter Rabbit and friends : the 23 original Peter Rabbit books
# No information found for the book: Stories and strategies of America's military in action
# No information found for the book: Maryland to Kentucky and Beyond Inc. reunion, March 2014
# No information found for the book: Southard-Stokes genealogy and related families
# ISBN information not found for the book: The Ordnance Department : planning munitions for war
# No information found for the book: Nähen : das aktuelle Standardwerk; [alles über Techniken, Stoff- und Maschinenkunde]
# No information found for the book: The Holy Quran with English translation of its meanings, Roman transliterations, and full Arabic text
# ISBN information not found for the book: Prayer and Al-Islām
# ISBN information not found for the book: Pooh's flower garden
# ISBN information not found for the book: Piglet's April adventure
# ISBN information not found for the book: Pooh Bear's May poem
# No information found for the book: A cloudy day for Pooh
# No information found for the book: Mother's Day for Kanga
# No information found for the book: Standard pocket street directory of Louisville ; containing city and county officials, subdivisions, hotels, clubs, churches, charitable institutions, public buildings, bus and railroad stations, cemeteries, street railway amd bus routes, public parks, pl
# ISBN information not found for the book: Louisville and Jefferson County, Kentucky, census 1810-1820-1830 (indexed).
# No information found for the book: Lughz Sītafūrd : jarīmat Qatl fī manzil Hazelmūr
# ISBN information not found for the book: United States naval aviation 1910-1980
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Reno, NV MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Rockford, IL MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Pensacola, FL MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Cheyenne, WY MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Muncie, IN MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Portland, ME MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Baton Rouge, LA MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Florence, SC MSA.
# ISBN information not found for the book: 1990 census of population and housing. Population and housing characteristics for census tracts and block numbering areas. Charleston, WV MSA.
# ...
# ISBN information not found for the book: Improved eddy-current inspection for steam generator tubing progress report for period January 1985 to December 1987
# ISBN information not found for the book: Influence of fluence rate on radiation-induced mechanical property changes in reactor pressure vessel steels : final report on exploratory experiments
# No information found for the book: A methodology to assist in contingency planning for protection of nuclear power plants against land vehicle bombs
# ISBN information not found for the book: Numerical simulation of natural circulation phenomena in a PWR during TMLB' transients prior to core damage
# ISBN information not found for the book: QADS, a multidimensional point kernel analysis module
# ISBN information not found for the book: Development and use of risk-based inspection guides
# ISBN information not found for the book: Effects of mineralogy on sorption of strontium and cesium onto Calico Hills tuff
# ISBN information not found for the book: Evaluations of core melt frequency effects due to component aging and maintenance
# ISBN information not found for the book: Administrative Law Judge Corps Act : report (to accompany H.R. 3910).
# ISBN information not found for the book: The Register of Solihull, Co. Warwick
# ISBN information not found for the book: Reclamation Projects Authorization and Adjustment Act of 1992 : conference report (to accompany H.R. 429).
# No information found for the book: IRS' tax systems modernization : progress and prospects : twenty-fourth report
# ISBN information not found for the book: Fraud and abuse in the head injury rehabilitation industry : twenty-fifth report
# ISBN information not found for the book: The Woods-McAfee memorial : containing an account of John Woods and James McAfee of Ireland and their descendants in America
# ISBN information not found for the book: Genealogical sketch of certain of the American descendants of Mathew Talbot, gentleman.
# ISBN information not found for the book: The Tracy family ... The Winslow family ...
# ISBN information not found for the book: Marriage records, 1765-1810, Mecklenburg County, Virginia.
# ISBN information not found for the book: The registers of Farnham, Yorkshire. 1569-1812.
# No information found for the book: An outline index to Goodspeed's history of Knox and Daviess counties, Indiana
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\connectionpool.py:492, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     491         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 492     raise new_e
#     494 # conn.request() calls http.client.*.request, not the method in
#     495 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467 try:
# --> 468     self._validate_conn(conn)
#     469 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\connection.py:611, in HTTPSConnection.connect(self)
#     610 sock: socket.socket | ssl.SSLSocket
# --> 611 self.sock = sock = self._new_conn()
#     612 server_hostname: str = self.host
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\connection.py:212, in HTTPConnection._new_conn(self)
#     211 except SocketTimeout as e:
# --> 212     raise ConnectTimeoutError(
#     213         self,
#     214         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     215     ) from e
#     217 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x000001AAF520A750>, 'Connection to openlibrary.org timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\connectionpool.py:845, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     843     new_e = ProtocolError("Connection aborted.", new_e)
# --> 845 retries = retries.increment(
#     846     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847 )
#     848 retries.sleep()
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?q=Parish+registers+of+Horton+Kirbie%2C+Co.+Kent (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001AAF520A750>, 'Connection to openlibrary.org timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\01_Analysis.ipynb Cell 29 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL_Data/01_Analysis.ipynb#Y155sZmlsZQ%3D%3D?line=0'>1</a> # Step 2 and 3: Use the get_book_isbn function to obtain ISBNs
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL_Data/01_Analysis.ipynb#Y155sZmlsZQ%3D%3D?line=1'>2</a> isbn_openlib['ISBN'] = isbn_openlib['Title'].apply(get_book_isbn)
#       <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL_Data/01_Analysis.ipynb#Y155sZmlsZQ%3D%3D?line=2'>3</a> isbn_openlib
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\01_Analysis.ipynb Cell 29 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL_Data/01_Analysis.ipynb#Y155sZmlsZQ%3D%3D?line=9'>10</a> for attempt in range(max_retries + 1):
#      <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL_Data/01_Analysis.ipynb#Y155sZmlsZQ%3D%3D?line=10'>11</a>     try:
#      <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL_Data/01_Analysis.ipynb#Y155sZmlsZQ%3D%3D?line=11'>12</a>         # Sending a request to the Open Books API with the book title
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL_Data/01_Analysis.ipynb#Y155sZmlsZQ%3D%3D?line=12'>13</a>         response = requests.get(base_url, params={'q': book_title})
#      <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL_Data/01_Analysis.ipynb#Y155sZmlsZQ%3D%3D?line=14'>15</a>         # Check if the request was successful (status code 200)
#      <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL_Data/01_Analysis.ipynb#Y155sZmlsZQ%3D%3D?line=15'>16</a>         response.raise_for_status()
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL_Data\venv\Lib\site-packages\requests\adapters.py:507, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     504 if isinstance(e.reason, ConnectTimeoutError):
#     505     # TODO: Remove this in 3.0.0: see #2811
#     506     if not isinstance(e.reason, NewConnectionError):
# --> 507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
#     510     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?q=Parish+registers+of+Horton+Kirbie%2C+Co.+Kent (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001AAF520A750>, 'Connection to openlibrary.org timed out. (connect timeout=None)'))

# %%
isbn_openlib
# Out:
#                                                    Title
# 0      Stolen legacy: the Egyptian origins of western...
# 1      A symposium in public librarianship; three add...
# 2                         WWI : the Great War, 1914-1918
# 3                                         LANKIE MANTITA
# 4                                             Act of War
# ...                                                  ...
# 27980              KOREA the land the people the culture
# 27981                                 The Saracen's mark
# 27982  The hedge fund edge: maximum profit/minimum ri...
# 27983  The monstrous-feminine: film, feminism, psycho...
# 27984  Common snese religion: a guide for renewing yo...
#
# [27985 rows x 1 columns]

# %%
# Step 4: Remove duplicated book titles
#isbn_openlib = isbn_openlib.drop_duplicates(subset='Title').reset_index(drop=True)

# Step 5: Save the resulting DataFrame to a CSV file
isbn_openlib.to_csv('data\openlib_isbn.csv', index=False)

# Display the resulting DataFrame
isbn_openlib

# %%
# Creating a copy of the dataframe with the title columns
# Removing duplicates titles to reduce the number of API calls
isbn_openlib = lfpl_books[lfpl_books["ISBN"]==""][["Title"]].drop_duplicates()
#isbn_openlib = lfpl_books.loc[lfpl_books['ISBN'] == '', 'Title'].drop_duplicates().reset_index(drop=True)

shape_c = isbn_openlib.shape
print(f"Rows: {shape_c[0]:,}, Columns: {shape_c[1]}")
isbn_openlib["ISBN"] = isbn_openlib.apply(lambda row: fill_missing_isbn(row), axis=1)
# Out:
# Rows: 27,985, Columns: 1

# %%
temp_df['ISBN'].isna().value_counts()
# Out:
# ISBN
# True     21245
# False     7082
# Name: count, dtype: int64

# %%
temp_df[temp_df['ISBN'].notna()]
# Out:
#                                Title           ISBN
# 5931                    My First Pet     9354401066
# 6383     O little town of Sugarcreek     1961125498
# 6405                      Act of War  9780451466198
# 6417            The Christmas riddle  9798586294586
# 6434              Castle of whispers  9781609451929
# ...                              ...            ...
# 1181089      The New Mencken Letters  9780803713796
# 1181093          Eye of the Beholder     0671523066
# 1181101                  Sharp Edges  9780671524098
# 1181291         the girl in the road     0804138842
# 1181292                See Night Run     1930859171
#
# [7082 rows x 2 columns]

# %%
# We found 7082 ISBN's using this API
# Merge the result with the original dataframe using the title column
# Merge the two dataframes using the title column
merged_df = lfpl_books.merge(temp_df, on='Title', how='left')
merged_df
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1        1341361           McGraw-Hill's American idioms dictionary
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3        1341362  McGraw-Hill's essential ESL grammar : a handbo...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1181239  2527332     The afrominimalist's guide to living with less
# 1181240  2527332     The afrominimalist's guide to living with less
# 1181241  2527332     The afrominimalist's guide to living with less
# 1181242  2527332     The afrominimalist's guide to living with less
# 1181243  2520634  Abstract painting : the elements of visual lan...
#
#                             Author         ISBN_x  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878             2009     Book
# 1               Spears, Richard A.  9780071478939             2007     Book
# 2             Miller, Robin, 1964-  9780307451408             2009     Book
# 3                    Lester, Mark.  9780071496421             2008     Book
# 4             Miller, Robin, 1964-  9780307451408             2009     Book
# ...                            ...            ...              ...      ...
# 1181239           Platt, Christine  9781982168056             2022     Book
# 1181240           Platt, Christine  9781982168056             2022     Book
# 1181241           Platt, Christine  9781982168056             2022     Book
# 1181242           Platt, Christine  9781982168056             2022     Book
# 1181243  Davies, Jane (Ceramicist)  9780692619803             2017     Book
#
#             ItemCollection             ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                     Main      25.95
# 1           ELL Collection            South Central      20.00
# 2        Adult Non-Fiction                Southwest      19.99
# 3           ELL Collection            South Central      20.00
# 4        Adult Non-Fiction                Southwest      19.99
# ...                    ...                      ...        ...
# 1181239  Adult Non-Fiction                     Main      10.02
# 1181240  Adult Non-Fiction                  Newburg      10.02
# 1181241  Adult Non-Fiction            South Central      10.02
# 1181242  Adult Non-Fiction                  Western      10.02
# 1181243  Adult Non-Fiction  Highlands - Shelby Park      24.95
#
#                      ReportDate  ObjectId ISBN_y
# 0        2022/07/01 04:00:00+00         1    NaN
# 1        2022/07/01 04:00:00+00         2    NaN
# 2        2022/07/01 04:00:00+00         3    NaN
# 3        2022/07/01 04:00:00+00         4    NaN
# 4        2022/07/01 04:00:00+00         5    NaN
# ...                         ...       ...    ...
# 1181239  2022/07/01 04:00:00+00   1657551    NaN
# 1181240  2022/07/01 04:00:00+00   1657552    NaN
# 1181241  2022/07/01 04:00:00+00   1657553    NaN
# 1181242  2022/07/01 04:00:00+00   1657554    NaN
# 1181243  2022/07/01 04:00:00+00   1657555    NaN
#
# [1181244 rows x 12 columns]

# %%
lfpl_books[lfpl_books['ISBN']=='nan']
# Out:
#           BibNum                                              Title  \
# 4429     1348353  Stolen legacy: the Egyptian origins of western...
# 5336     1353427  A symposium in public librarianship; three add...
# 5510     1353740                     WWI : the Great War, 1914-1918
# 5511     1353780                                     LANKIE MANTITA
# 5931     2511351                                       My First Pet
# ...          ...                                                ...
# 1181091  2528085      Cognitive Mapping : Past, Present, and Future
# 1181093  2528087                                Eye of the Beholder
# 1181101  2528088                                        Sharp Edges
# 1181291  2527399                               the girl in the road
# 1181292  2527400                                      See Night Run
#
#                                                     Author ISBN  \
# 4429                                    James, George G. M  nan
# 5336     University of California, Berkeley. School of ...  nan
# 5510         Brown, Hilary (Author of Two-liners for kids)  nan
# 5511                                     LESLIE PATRICELLI  nan
# 5931                                                   NaN  nan
# ...                                                    ...  ...
# 1181091                                       Kitchin, Rob  nan
# 1181093                                      Krentz, Jayne  nan
# 1181101                                      Krentz, Jayne  nan
# 1181291                                       MONICA BYRNE  nan
# 1181292                                                NaN  nan
#
#          PublicationYear ItemType     ItemCollection            ItemLocation  \
# 4429                   0     Book  Interlibrary Loan                    Main
# 5336                1952     Book   Kentucky History                    Main
# 5510                2014     Book  Adult Non-Fiction                    Main
# 5511                   0     Book                NaN                 Shively
# 5931                   0     Book                NaN                 Newburg
# ...                  ...      ...                ...                     ...
# 1181091                0     Book  Interlibrary Loan                    Main
# 1181093                0     Book  Interlibrary Loan                    Main
# 1181101                0     Book  Interlibrary Loan                    Main
# 1181291                0     Book                NaN                    Main
# 1181292                0     Book                NaN  Childrens Main Library
#
#          ItemPrice              ReportDate  ObjectId
# 4429           0.0  2022/07/01 04:00:00+00      5055
# 5336          25.0  2022/07/01 04:00:00+00      7761
# 5510          15.0  2022/07/01 04:00:00+00      8010
# 5511           0.0  2022/07/01 04:00:00+00      8027
# 5931           0.0  2022/07/01 04:00:00+00      8588
# ...            ...                     ...       ...
# 1181091        0.0  2022/07/01 04:00:00+00   1657144
# 1181093        0.0  2022/07/01 04:00:00+00   1657147
# 1181101        0.0  2022/07/01 04:00:00+00   1657176
# 1181291        0.0  2022/07/01 04:00:00+00   1657506
# 1181292        0.0  2022/07/01 04:00:00+00   1657507
#
# [36430 rows x 11 columns]

# %%
lfpl_books_1 = lfpl_books.merge(temp_df, on='Title', how='left', suffixes=('', '_temp'))

# %%
lfpl_books_1[lfpl_books_1['ISBN']=='nan'].value_counts()
# Out:
# BibNum   Title                                             Author                                         ISBN  PublicationYear  ItemType  ItemCollection     ItemLocation            ItemPrice  ReportDate              ObjectId  ISBN_temp
# 2313     Roughing it                                       Twain, Mark, 1835-1910.                        nan   1992             Book      Adult Non-Fiction  Jeffersontown           22.95      2022/07/01 04:00:00+00  82652     9798465049788    1
# 476060   The Orangeburg massacre                           Nelson, Jack, 1929 Oct. 11-                    nan   1970             Book      Adult Reference    Western                 55.00      2022/07/01 04:00:00+00  344282    9780865541207    1
# 476294   The Negro in the American Revolution              Aptheker, Herbert, 1915-                       nan   1940             Book      Adult Non-Fiction  Remote Shelving - Main  25.00      2022/07/01 04:00:00+00  344549    9780807838334    1
#                                                                                                                                                               Main                    25.00      2022/07/01 04:00:00+00  344548    9780807838334    1
# 476284   Story of the Negro                                Bontemps, Arna, 1902-1973.                     nan   1948             Book      Adult Reference    Western                 45.00      2022/07/01 04:00:00+00  344491    0812219368       1
#                                                                                                                                                                                                                                                    ..
# 434741   A Scots quair : a trilogy of novels               Mitchell, James Leslie, 1901-1935.             nan   1974             Book      Adult Fiction      Remote Shelving - Main  25.00      2022/07/01 04:00:00+00  319191    9781904598824    1
# 434721   Irish poetry : from the English invasion to 1798  Alspach, Russell K. (Russell King), 1901-1980  nan   1959             Book      Adult Non-Fiction  Crescent Hill           4.00       2022/07/01 04:00:00+00  319125    9781512800166    1
# 434695   Children's treasure box                           Svoboda, Tomas.                                nan   1977             Book      Adult Non-Fiction  Remote Shelving - Main  25.00      2022/07/01 04:00:00+00  319058    0895555646       1
#                                                                                                                                                                                                                          319017    0895555646       1
# 2529351  Theory of Religious Cycles                        Sergeev, Mikhail                               nan   0                Book      Interlibrary Loan  Main                    0.00       2022/07/01 04:00:00+00  1611871   9789004300033    1
# Name: count, Length: 8268, dtype: int64

# %%
# Update the missing values in the isbn column of lfpl_books using the values from temp_df
lfpl_books_1['ISBN'] = lfpl_books_1.apply(lambda row: row['ISBN_temp'] if row['ISBN']=='nan' else row['ISBN'], axis=1)
lfpl_books_1.drop('ISBN_temp', axis=1, inplace=True)

# %%
# 'nan' are now None
lfpl_books_1['ISBN'].isna().value_counts()
# Out:
# ISBN
# False    1154047
# True       27197
# Name: count, dtype: int64

# %%
# Still 27197 'nan' values
lfpl_books_1.to_csv('data\lfpl_books_1.csv',index=False)

# %%
lfpl_books_1
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1        1341361           McGraw-Hill's American idioms dictionary
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3        1341362  McGraw-Hill's essential ESL grammar : a handbo...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1181239  2527332     The afrominimalist's guide to living with less
# 1181240  2527332     The afrominimalist's guide to living with less
# 1181241  2527332     The afrominimalist's guide to living with less
# 1181242  2527332     The afrominimalist's guide to living with less
# 1181243  2520634  Abstract painting : the elements of visual lan...
#
#                             Author         ISBN_x  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878             2009     Book
# 1               Spears, Richard A.  9780071478939             2007     Book
# 2             Miller, Robin, 1964-  9780307451408             2009     Book
# 3                    Lester, Mark.  9780071496421             2008     Book
# 4             Miller, Robin, 1964-  9780307451408             2009     Book
# ...                            ...            ...              ...      ...
# 1181239           Platt, Christine  9781982168056             2022     Book
# 1181240           Platt, Christine  9781982168056             2022     Book
# 1181241           Platt, Christine  9781982168056             2022     Book
# 1181242           Platt, Christine  9781982168056             2022     Book
# 1181243  Davies, Jane (Ceramicist)  9780692619803             2017     Book
#
#             ItemCollection             ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                     Main      25.95
# 1           ELL Collection            South Central      20.00
# 2        Adult Non-Fiction                Southwest      19.99
# 3           ELL Collection            South Central      20.00
# 4        Adult Non-Fiction                Southwest      19.99
# ...                    ...                      ...        ...
# 1181239  Adult Non-Fiction                     Main      10.02
# 1181240  Adult Non-Fiction                  Newburg      10.02
# 1181241  Adult Non-Fiction            South Central      10.02
# 1181242  Adult Non-Fiction                  Western      10.02
# 1181243  Adult Non-Fiction  Highlands - Shelby Park      24.95
#
#                      ReportDate  ObjectId           ISBN
# 0        2022/07/01 04:00:00+00         1  9780071605878
# 1        2022/07/01 04:00:00+00         2  9780071478939
# 2        2022/07/01 04:00:00+00         3  9780307451408
# 3        2022/07/01 04:00:00+00         4  9780071496421
# 4        2022/07/01 04:00:00+00         5  9780307451408
# ...                         ...       ...            ...
# 1181239  2022/07/01 04:00:00+00   1657551  9780399544354
# 1181240  2022/07/01 04:00:00+00   1657552  9781787737372
# 1181241  2022/07/01 04:00:00+00   1657553  9780063055254
# 1181242  2022/07/01 04:00:00+00   1657554  9781974712533
# 1181243  2022/07/01 04:00:00+00   1657555  9781974712533
#
# [1181244 rows x 12 columns]

# %%
lfpl_books_1['ISBN'].isna().value_counts()
# Out:
# ISBN
# False    1154047
# True       27197
# Name: count, dtype: int64

# %% [markdown]
# ## Google API. It should be noted that the API respond with errors in too many calls are generated from the same IP address

# %%
# I used this method on the first phase but it was returning the response 429(too many requests). It had to be modified.
import requests

def find_isbn_by_book_name(book_name):
    # Define the API endpoint to search for ISBN using book names
    api_url = f"https://www.googleapis.com/books/v1/volumes?q={book_name}"
    # Using "intitle" find less ISBN numbers on the test
    #api_url = f"https://www.googleapis.com/books/v1/volumes?q=intitle:{book_name}"
    try:
        response = requests.get(api_url)
        if response.status_code == 200:
            data = response.json()
            book_response = data.get('totalItems', '')
            if book_response in (0, ""):
                return ""
            else:
                isbn = data.get('items','')[0].get('volumeInfo','').get('industryIdentifiers','')[0].get('identifier','')
                #return isbn if len(isbn) in {10, 13} else ""
                if len(isbn) in (10, 13): # Only acceptable ISBN length
                    return isbn
                else:
                    return ""
        
    except Exception as e:
        return ""
        #print(f"API request error: {str(e)}")

    return ''

# %%
# Function to apply to the DataFrame
def fill_missing_isbn(row):
    if row["ISBN"] == "nan":
        return find_isbn_by_book_name(row["Title"])
    else:
        return row["ISBN"]

# %%
# Example DataFrame
data = {
    "Title": ["Cognitive Mapping : Past, Present, and Future","LANKIE MANTITA", "WWI : the Great War, 1914-1918", "the girl in the road", "Sharp Edges", "My First Pet"],
    "ISBN": ["nan", "nan", "nan", "nan", "nan","nan"]
}

df = pd.DataFrame(data)



# Apply the function using lambda only to rows with missing ISBN
df["ISBN"] = df.apply(lambda row: fill_missing_isbn(row), axis=1)

print(df)
# Out:
#                                            Title           ISBN
# 0  Cognitive Mapping : Past, Present, and Future  9781317798071
# 1                                 LANKIE MANTITA
# 2                 WWI : the Great War, 1914-1918
# 3                           the girl in the road  9780804138864
# 4                                    Sharp Edges  9781439120118
# 5                                   My First Pet  9781465452955

# %% [markdown]
# The Google API appears to have more information than the previous one.
# The returned will be accepted if it has 10(ISBN-10) or 13(ISBN-13) characters.

# %%
# Experimenting with timing

print(f"My First Pet - ISBN: {find_isbn_by_book_name('My First Pet')}")
# Out:
# My First Pet - ISBN: 1620315491

# %%
# The following line of code might take a lot to process

#lfpl_books["ISBN"] = lfpl_books.apply(lambda row: fill_missing_isbn(row), axis=1)

# %% [markdown]
# ## Trying to use concurrent features

# %%
isbn_length
# Out:
# ISBN
# 13    1031252
# 12     102249
# 3       36430
# 11      10031
# 10       1137
# 9         140
# 8           4
# 7           1
# Name: count, dtype: int64

# %%
# Creating a copy of the dataframe with only the isbn and title columns
missing_isbn_df = lfpl_books_1[lfpl_books_1["ISBN"].isna()][["Title"]].drop_duplicates()
shape_c = missing_isbn_df.shape
print(f"Rows: {shape_c[0]:,}, Columns: {shape_c[1]}")
# Out:
# Rows: 21,245, Columns: 1

# %%
missing_isbn_df
# Out:
#                                                      Title
# 4429     Stolen legacy: the Egyptian origins of western...
# 5336     A symposium in public librarianship; three add...
# 5510                        WWI : the Great War, 1914-1918
# 5511                                        LANKIE MANTITA
# 6414                                  Pieces from the past
# ...                                                    ...
# 1180968  Never Surrender : A Soldier's Journey to the C...
# 1180971  The Secret of the Universe = Mysterium Cosmogr...
# 1180976            Mathematics : a Very Short Introduction
# 1180988                  ILL KDLA BOOK KIT - Hidden Places
# 1180994      Cognitive Mapping : Past, Present, and Future
#
# [21245 rows x 1 columns]

# %% [markdown]
# We saved a few thousands API calls removing the duplicates

# %%
# Trying to select the appropiate number of cores, depending on the CPU
import multiprocessing

def get_cpu_count():
  return multiprocessing.cpu_count()

def select_max_workers(cpu_count):
  if cpu_count <= 4:
    return cpu_count
  else:
    return int(cpu_count * 0.75)

# %%
print(select_max_workers(get_cpu_count()))
# Out:
# 18

# %%
import time

def get_isbn_from_api_with_retry(book_title, max_retries=3):
    
    #base_url = "https://www.googleapis.com/books/v1/volumes"
    #params = {"q": f"intitle:{book_title}", "maxResults": 1}

    api_url = f"https://www.googleapis.com/books/v1/volumes?q={book_title}"

    for retry in range(max_retries):
        try:
            #response = requests.get(api_url, params=params)
            response = requests.get(api_url)
            response.raise_for_status()  # Raise an HTTPError for bad responses
            data = response.json()

            # Check if any items were found
            if "items" in data and data["items"]:
                volume_info = data["items"][0]["volumeInfo"]
                isbn = volume_info.get("industryIdentifiers", [])

                # Validate ISBN length
                for identifier in isbn:
                    if identifier["type"] == "ISBN_10" and len(identifier["identifier"]) == 10:
                        return identifier["identifier"]
                    elif identifier["type"] == "ISBN_13" and len(identifier["identifier"]) == 13:
                        return identifier["identifier"]

            return ""
        except requests.exceptions.HTTPError as e:
            if e.response.status_code == 429:
                # Extract the 'Retry-After' header value
                retry_after = int(e.response.headers.get("Retry-After", 1))
                print(f"Rate limit exceeded. Retrying in {retry_after} seconds...")
                time.sleep(retry_after)
                return ""
            else:
                print(f"Error in API request: {e}")
                return ""
        except requests.exceptions.RequestException as e:
            print(f"Error in API request: {e}")
            return ""

    print(f"Exceeded maximum retries for {book_title}. Skipping...")
    return ""

# %%
def get_isbn(book_title, csvfile):
    isbn = get_isbn_from_api_with_retry(book_title)

    if isbn:
        with open(csvfile, "a", encoding="utf-8", newline="") as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow([isbn, book_title])
            print(f'Saving: {book_title}')
    return isbn

# %%
from concurrent.futures import ThreadPoolExecutor

cpu_count = get_cpu_count()
max_workers = select_max_workers(cpu_count)

with open('data/lfpl_books_2', "a", encoding="utf-8", newline="") as csvfile:
            
    with ThreadPoolExecutor( max_workers ) as executor:
        #missing_isbn_df["ISBN"] = list(executor.map(fill_missing_isbn, missing_isbn_df.itertuples(index=False)))
        missing_isbn_df["ISBN"] = list(executor.map(get_isbn_from_api_with_retry, missing_isbn_df['Title']))
        writer = csv.writer(csvfile)
        writer.writerow(missing_isbn_df['ISBN'], missing_isbn_df['Title'])
        print(f"Saving: {missing_isbn_df['Title']}")
# Out:
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL\01_Analysis.ipynb Cell 61 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=5'>6</a> with open('data/lfpl_books_2', "a", encoding="utf-8", newline="") as csvfile:
#       <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=7'>8</a>     with ThreadPoolExecutor( max_workers ) as executor:
#       <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=8'>9</a>         #missing_isbn_df["ISBN"] = list(executor.map(fill_missing_isbn, missing_isbn_df.itertuples(index=False)))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=9'>10</a>         missing_isbn_df["ISBN"] = list(executor.map(get_isbn_from_api_with_retry, missing_isbn_df['Title']))
#      <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=10'>11</a>         writer = csv.writer(csvfile)
#      <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=11'>12</a>         writer.writerow(missing_isbn_df['ISBN'], missing_isbn_df['Title'])
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %%
missing_isbn_df
# Out:
#                                                      Title
# 4429     Stolen legacy: the Egyptian origins of western...
# 5336     A symposium in public librarianship; three add...
# 5510                        WWI : the Great War, 1914-1918
# 5511                                        LANKIE MANTITA
# 6414                                  Pieces from the past
# ...                                                    ...
# 1180968  Never Surrender : A Soldier's Journey to the C...
# 1180971  The Secret of the Universe = Mysterium Cosmogr...
# 1180976            Mathematics : a Very Short Introduction
# 1180988                  ILL KDLA BOOK KIT - Hidden Places
# 1180994      Cognitive Mapping : Past, Present, and Future
#
# [21245 rows x 1 columns]

# %%
# Merge the result with the original dataframe using the title column
lfpl_books = pd.merge(lfpl_books, missing_isbn_df, on="Title", how="left", suffixes=("_old", ""))

#lfpl_books["ISBN"] = lfpl_books["ISBN_new"].combine_first(lfpl_books["ISBN"]).astype(str)  # Fill missing ISBN in the original dataframe

# Drop temporary columns
#lfpl_books = lfpl_books.drop(columns=["ISBN_new"])
lfpl_books = lfpl_books.drop(columns=["ISBN_old"])

# %%
lfpl_books['ISBN'].str.len().value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL\01_Analysis.ipynb Cell 46 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> lfpl_books['ISBN'].str.len().value_counts()
#
# NameError: name 'lfpl_books' is not defined

# %% [markdown]
# 47 minutes and 55 seconds in a cpu with 16 cores, 24 logical procesors

# %%
lfpl_books['ISBN'].str.len().value_counts()
# Out:
# ISBN
# 13    1031252
# 12     102249
# 3       36527
# 11      10031
# 10       1137
# 9         140
# 8           4
# 7           1
# Name: count, dtype: int64

# %%
def summ_length(strings):
  """
  Summarizes a list of strings by length.

  Args:
    strings: A list of strings.

  Returns:
    A dictionary that maps string lengths to the number of strings of that length.
  """

  summary = {}

  for string in strings:
    length = len(string)

    if length not in summary:
      summary[length] = 0

    summary[length] += 1

  return summary

strings = ['hello', 'world', 'this', 'is', 'a', 'test']
summary = summ_length(results)

for length, count in summary.items():
  print(f"There are {count} strings with length {length}")
# Out:
# There are 1032881 strings with length 13
# There are 102384 strings with length 12
# There are 10036 strings with length 11
# There are 1864 strings with length 10
# There are 228 strings with length 15
# There are 31565 strings with length 0
# There are 89 strings with length 22
# There are 863 strings with length 14
# There are 152 strings with length 16
# There are 633 strings with length 18
# There are 172 strings with length 19
# There are 266 strings with length 23
# There are 46 strings with length 20
# There are 17 strings with length 17
# There are 140 strings with length 9
# There are 4 strings with length 8
# There are 1 strings with length 7

# %%
new_isbn = pd.DataFrame(results, columns=['ISBN'])
new_isbn['ISBN'].str.len().value_counts()
# Out:
# ISBN
# 13    1032881
# 12     102384
# 0       31565
# 11      10036
# 10       1864
# 14        863
# 18        633
# 23        266
# 15        228
# 19        172
# 16        152
# 9         140
# 22         89
# 20         46
# 17         17
# 8           4
# 7           1
# Name: count, dtype: int64

# %%
lfpl_books['ISBN'].str.len().value_counts()
# Out:
# ISBN
# 13    1031252
# 12     102249
# 3       36527
# 11      10031
# 10       1137
# 9         140
# 8           4
# 7           1
# Name: count, dtype: int64

# %%
new_isbn[new_isbn['ISBN'].str.len() == 17]
# Out:
#                      ISBN
# 60695   EAN:8596547062158
# 96189   EAN:4064066431020
# 102906  EAN:4064066397913
# 245348  SRLF:AX0000165175
# 252219  EAN:8596547026808
# 254818  EAN:8596547408710
# 259217  EAN:8596547378266
# 261460  EAN:8596547192480
# 262910  EAN:8596547403005
# 264185  SRLF:AA0002591691
# 265030  EAN:8596547062653
# 265509  EAN:8596547186557
# 265886  GENT:900000016407
# 272037  EAN:8596547196174
# 272038  EAN:8596547196174
# 575197  EAN:4064066059439
# 575201  EAN:4064066059439

# %%
new_isbn.shape
# Out:
# (1181341, 1)

# %%
lfpl_books.shape
# Out:
# (1181341, 12)

# %%
type(results)
# Out:
# list

# %% [markdown]
# ## Let's check the results

# %%
lfpl_books['ISBN'].isna().value_counts()
# Out:
# ISBN
# False    1181341
# Name: count, dtype: int64

# %%
lfpl_books[lfpl_books['ISBN'] == 'nan']
# Out:
#           BibNum                                              Title  \
# 4429     1348353  Stolen legacy: the Egyptian origins of western...
# 5336     1353427  A symposium in public librarianship; three add...
# 5510     1353740                     WWI : the Great War, 1914-1918
# 5511     1353780                                     LANKIE MANTITA
# 5931     2511351                                       My First Pet
# ...          ...                                                ...
# 1181091  2528085      Cognitive Mapping : Past, Present, and Future
# 1181093  2528087                                Eye of the Beholder
# 1181101  2528088                                        Sharp Edges
# 1181291  2527399                               the girl in the road
# 1181292  2527400                                      See Night Run
#
#                                                     Author ISBN  \
# 4429                                    James, George G. M  nan
# 5336     University of California, Berkeley. School of ...  nan
# 5510         Brown, Hilary (Author of Two-liners for kids)  nan
# 5511                                     LESLIE PATRICELLI  nan
# 5931                                                   NaN  nan
# ...                                                    ...  ...
# 1181091                                       Kitchin, Rob  nan
# 1181093                                      Krentz, Jayne  nan
# 1181101                                      Krentz, Jayne  nan
# 1181291                                       MONICA BYRNE  nan
# 1181292                                                NaN  nan
#
#          PublicationYear ItemType     ItemCollection            ItemLocation  \
# 4429                   0     Book  Interlibrary Loan                    Main
# 5336                1952     Book   Kentucky History                    Main
# 5510                2014     Book  Adult Non-Fiction                    Main
# 5511                   0     Book                NaN                 Shively
# 5931                   0     Book                NaN                 Newburg
# ...                  ...      ...                ...                     ...
# 1181091                0     Book  Interlibrary Loan                    Main
# 1181093                0     Book  Interlibrary Loan                    Main
# 1181101                0     Book  Interlibrary Loan                    Main
# 1181291                0     Book                NaN                    Main
# 1181292                0     Book                NaN  Childrens Main Library
#
#          ItemPrice              ReportDate  ObjectId
# 4429           0.0  2022/07/01 04:00:00+00      5055
# 5336          25.0  2022/07/01 04:00:00+00      7761
# 5510          15.0  2022/07/01 04:00:00+00      8010
# 5511           0.0  2022/07/01 04:00:00+00      8027
# 5931           0.0  2022/07/01 04:00:00+00      8588
# ...            ...                     ...       ...
# 1181091        0.0  2022/07/01 04:00:00+00   1657144
# 1181093        0.0  2022/07/01 04:00:00+00   1657147
# 1181101        0.0  2022/07/01 04:00:00+00   1657176
# 1181291        0.0  2022/07/01 04:00:00+00   1657506
# 1181292        0.0  2022/07/01 04:00:00+00   1657507
#
# [36526 rows x 11 columns]

# %%
# Finding books with no title
lfpl_books[lfpl_books['Title'].isna()]
# Out:
#          BibNum Title Author ISBN  PublicationYear ItemType ItemCollection  \
# 198351  2239375   NaN    NaN  nan                0     Book            NaN
#
#          ItemLocation  ItemPrice              ReportDate  ObjectId
# 198351  Crescent Hill        0.0  2022/07/01 04:00:00+00    243966

# %%
lfpl_books[lfpl_books['ItemCollection'].isna()]
# Out:
#           BibNum                        Title             Author ISBN  \
# 5511     1353780               LANKIE MANTITA  LESLIE PATRICELLI  nan
# 5931     2511351                 My First Pet                NaN  nan
# 6405     1362079                   Act of War        Brown, Dale  nan
# 9061     2410700                         FOUR      VERONICA ROTH  nan
# 12678    2481658     designing your work life       bill burnett  nan
# ...          ...                          ...                ...  ...
# 1180968  2528221  The Khipu and the Final Key      Dee Garretson  nan
# 1180972  2528222              MOMMY'S DISEASE     CAROLYN HANNAN  nan
# 1181047  2527377                          use                NaN  nan
# 1181291  2527399         the girl in the road       MONICA BYRNE  nan
# 1181292  2527400                See Night Run                NaN  nan
#
#          PublicationYear ItemType ItemCollection            ItemLocation  \
# 5511                   0     Book            NaN                 Shively
# 5931                   0     Book            NaN                 Newburg
# 6405                   0     Book            NaN                 Bon Air
# 9061                   0     Book            NaN           Crescent Hill
# 12678                  0     Book            NaN             St Matthews
# ...                  ...      ...            ...                     ...
# 1180968                0     Book            NaN               Northeast
# 1180972                0     Book            NaN               Southwest
# 1181047                0     Book            NaN               Northeast
# 1181291                0     Book            NaN                    Main
# 1181292                0     Book            NaN  Childrens Main Library
#
#          ItemPrice              ReportDate  ObjectId
# 5511           0.0  2022/07/01 04:00:00+00      8027
# 5931           0.0  2022/07/01 04:00:00+00      8588
# 6405           0.0  2022/07/01 04:00:00+00     10502
# 9061           0.0  2022/07/01 04:00:00+00     16849
# 12678          0.0  2022/07/01 04:00:00+00     22166
# ...            ...                     ...       ...
# 1180968        0.0  2022/07/01 04:00:00+00   1656928
# 1180972        0.0  2022/07/01 04:00:00+00   1656934
# 1181047        0.0  2022/07/01 04:00:00+00   1657039
# 1181291        0.0  2022/07/01 04:00:00+00   1657506
# 1181292        0.0  2022/07/01 04:00:00+00   1657507
#
# [201 rows x 11 columns]

# %%
lfpl_books['ItemCollection'].unique()
# Out:
# array(['Adult Non-Fiction', 'ELL Collection', 'Adult Fiction', 'Mystery',
#        "Children's Picture Book", 'Science Fiction', 'Older Teen Fiction',
#        'Younger Teen  Fiction', 'Adult Paperback', "Children's Fiction",
#        'Western', "Children's Picture Paperback", "Children's Paperback",
#        'International Collection', 'Teen Non-Fiction',
#        "Children's Non-Fiction", 'Kentucky History', 'Natural Resources',
#        'Oversize', 'Holiday', 'Urban Fiction', 'Bestsellers',
#        "Children's Board Book", 'Storytime Collection',
#        'Preschool  Picture Book', "Children's Easy Reader",
#        'Adult Reference', 'Interlibrary Loan', nan,
#        'Adult Paperbacks Tall', "Children's Easy Reader Paperback",
#        'Caldecott/Newbery', 'Laptop', 'Younger Teen  Paperback',
#        'Government Documents', 'Large Print', 'Telereference',
#        "Children's Non-Fiction Paperback", 'Big Book',
#        "Children's Reference", 'Older Teen Paperback', 'Teen Reference',
#        'College Shop', 'Magazines and Newspaper',
#        'Younger Teen  Audiobook', 'Readalongs', 'Listening Device',
#        'Adult Audiobook', 'Electronic', "Children's Music", 'Adult DVD',
#        'Music', 'Book Discussion Kit'], dtype=object)

# %%
lfpl_books['ItemCollection'].value_counts()
# Out:
# ItemCollection
# Adult Non-Fiction                   370372
# Adult Fiction                       173472
# Children's Non-Fiction               86723
# Mystery                              60152
# Children's Picture Book              58609
# Preschool  Picture Book              50564
# Children's Fiction                   47829
# Adult Paperback                      45733
# Children's Paperback                 44649
# Teen Non-Fiction                     24045
# Children's Easy Reader               24037
# Older Teen Fiction                   23476
# Children's Board Book                20180
# Younger Teen  Fiction                17227
# Kentucky History                     16766
# Science Fiction                      15714
# Children's Easy Reader Paperback     15566
# Holiday                              15482
# International Collection             15439
# Adult Reference                      11233
# Children's Picture Paperback          9638
# Urban Fiction                         7556
# Caldecott/Newbery                     6959
# Storytime Collection                  4231
# Government Documents                  3349
# Oversize                              2264
# Western                               2136
# Bestsellers                           1782
# ELL Collection                        1762
# Natural Resources                     1513
# Adult Paperbacks Tall                  758
# Younger Teen  Paperback                647
# Children's Reference                   583
# Interlibrary Loan                      159
# Older Teen Paperback                   151
# Laptop                                  96
# Children's Non-Fiction Paperback        70
# Big Book                                56
# Large Print                             53
# Readalongs                              38
# College Shop                            18
# Listening Device                        16
# Telereference                           10
# Teen Reference                           8
# Younger Teen  Audiobook                  4
# Electronic                               4
# Adult Audiobook                          3
# Adult DVD                                3
# Magazines and Newspaper                  1
# Children's Music                         1
# Music                                    1
# Book Discussion Kit                      1
# Name: count, dtype: int64
