# %%
import pandas as pd
import requests
import time
import json
import gzip
import csv
from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# ## Analizing the books at the LFPL libraries

# %%
# Read the csv file
lfpl_books = pd.read_csv('data\LFPL_Books.csv')

# %% [markdown]
# ## The plan is to enrich this dataset using the Google API. The ISBN will be used to pull the required information from the API. In order to achieve that, we need to check the non valid values in the ISBN column. let's do some cleaning first

# %%
# Check the types
lfpl_books.dtypes
# Out:
# BibNum               int64
# Title               object
# Author              object
# ISBN               float64
# PublicationYear      int64
# ItemType            object
# ItemCollection      object
# ItemLocation        object
# ItemPrice          float64
# ReportDate          object
# ObjectId             int64
# dtype: object

# %%
shape = lfpl_books.shape
print(f"Rows: {shape[0]:,}, Columns: {shape[1]}")
# Out:
# Rows: 1,181,341, Columns: 11

# %%
# Finding how many NaN values per column
lfpl_books.isna().sum()
# Out:
# BibNum                 0
# Title                  1
# Author             65644
# ISBN               36527
# PublicationYear        0
# ItemType               0
# ItemCollection       202
# ItemLocation           0
# ItemPrice              0
# ReportDate             0
# ObjectId               0
# dtype: int64

# %%
lfpl_books.loc[lfpl_books['Title'].isna() ]
# Out:
#          BibNum Title Author  ISBN  PublicationYear ItemType ItemCollection  \
# 198351  2239375   NaN    NaN   NaN                0     Book            NaN
#
#          ItemLocation  ItemPrice              ReportDate  ObjectId
# 198351  Crescent Hill        0.0  2022/07/01 04:00:00+00    243966

# %% [markdown]
# There is no Title, or ISBN in this row. Dropping it.

# %%
lfpl_books.drop(198351, inplace=True)
lfpl_books.loc[lfpl_books['Title'].isna() ]
# Out:
# Empty DataFrame
# Columns: [BibNum, Title, Author, ISBN, PublicationYear, ItemType, ItemCollection, ItemLocation, ItemPrice, ReportDate, ObjectId]
# Index: []

# %% [markdown]
# The row with the empty title is gone now. Looking at the ones with missing author and ISBN

# %%
lfpl_books.loc[(lfpl_books['Author'].isna()) & (lfpl_books['ISBN'].isna())]
# Out:
#           BibNum                                              Title Author  \
# 5931     2511351                                       My First Pet    NaN
# 9402     1375916                                             Laptop    NaN
# 9403     1375916                                             Laptop    NaN
# 9446     1375916                                             Laptop    NaN
# 9451     1375916                                             Laptop    NaN
# ...          ...                                                ...    ...
# 1180912  2514077  Hidden history of the Kovno Ghetto : teacher g...    NaN
# 1180913  2514078  A Necessary fence-- : the Senate's first century.    NaN
# 1181047  2527377                                                use    NaN
# 1181089  2528084                            The New Mencken Letters    NaN
# 1181292  2527400                                      See Night Run    NaN
#
#          ISBN  PublicationYear ItemType        ItemCollection  \
# 5931      NaN                0     Book                   NaN
# 9402      NaN                0     Book                Laptop
# 9403      NaN                0     Book                Laptop
# 9446      NaN                0     Book                Laptop
# 9451      NaN                0     Book                Laptop
# ...       ...              ...      ...                   ...
# 1180912   NaN             1998     Book  Government Documents
# 1180913   NaN             1989     Book  Government Documents
# 1181047   NaN                0     Book                   NaN
# 1181089   NaN                0     Book     Interlibrary Loan
# 1181292   NaN                0     Book                   NaN
#
#                    ItemLocation  ItemPrice              ReportDate  ObjectId
# 5931                    Newburg       0.00  2022/07/01 04:00:00+00      8588
# 9402                St Matthews     900.31  2022/07/01 04:00:00+00     17216
# 9403              South Central    1077.00  2022/07/01 04:00:00+00     17217
# 9446                St Matthews     900.31  2022/07/01 04:00:00+00     17260
# 9451                St Matthews     900.31  2022/07/01 04:00:00+00     17265
# ...                         ...        ...                     ...       ...
# 1180912                    Main       0.00  2022/07/01 04:00:00+00   1656785
# 1180913                    Main       0.00  2022/07/01 04:00:00+00   1656786
# 1181047               Northeast       0.00  2022/07/01 04:00:00+00   1657039
# 1181089                    Main       0.00  2022/07/01 04:00:00+00   1657141
# 1181292  Childrens Main Library       0.00  2022/07/01 04:00:00+00   1657507
#
# [6886 rows x 11 columns]

# %% [markdown]
# Apparently the Laptops are included as books in this dataset.

# %%
lfpl_books[lfpl_books['Title'] == 'Laptop']
# Out:
#        BibNum   Title Author  ISBN  PublicationYear ItemType ItemCollection  \
# 9402  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 9403  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 9446  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 9451  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 9457  1375916  Laptop    NaN   NaN                0     Book         Laptop
# ...       ...     ...    ...   ...              ...      ...            ...
# 9684  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 9685  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 9686  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 9687  1375916  Laptop    NaN   NaN                0     Book         Laptop
# 9688  1375916  Laptop    NaN   NaN                0     Book         Laptop
#
#        ItemLocation  ItemPrice              ReportDate  ObjectId
# 9402    St Matthews     900.31  2022/07/01 04:00:00+00     17216
# 9403  South Central    1077.00  2022/07/01 04:00:00+00     17217
# 9446    St Matthews     900.31  2022/07/01 04:00:00+00     17260
# 9451    St Matthews     900.31  2022/07/01 04:00:00+00     17265
# 9457    St Matthews     900.31  2022/07/01 04:00:00+00     17271
# ...             ...        ...                     ...       ...
# 9684    St Matthews     900.31  2022/07/01 04:00:00+00     17501
# 9685    St Matthews     900.31  2022/07/01 04:00:00+00     17502
# 9686      Northeast     900.31  2022/07/01 04:00:00+00     17503
# 9687      Northeast     900.31  2022/07/01 04:00:00+00     17504
# 9688    St Matthews     900.31  2022/07/01 04:00:00+00     17505
#
# [96 rows x 11 columns]

# %%
lfpl_books.drop(lfpl_books[lfpl_books['Title'] == 'Laptop'].index, inplace=True)
lfpl_books[lfpl_books['Title'] == 'Laptop']
# Out:
# Empty DataFrame
# Columns: [BibNum, Title, Author, ISBN, PublicationYear, ItemType, ItemCollection, ItemLocation, ItemPrice, ReportDate, ObjectId]
# Index: []

# %% [markdown]
# Laptops were dropped.

# %% [markdown]
# The ISBN column has 36527 values NaN. We need this value populated to use the Google API in order to obtain more information about the book.
# The easiest solution is to drop all these rows. Before doing that, we will attempt to obtain the ISBN number using the book's title.
# The main challenge is that API calls are pretty slow.

# %% [markdown]
# ## First we will change the data type from float to string on the ISBN

# %%
lfpl_books['ISBN'] = lfpl_books['ISBN'].astype(str)
lfpl_books
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1        1341361           McGraw-Hill's American idioms dictionary
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3        1341362  McGraw-Hill's essential ESL grammar : a handbo...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1181336  2527332     The afrominimalist's guide to living with less
# 1181337  2527332     The afrominimalist's guide to living with less
# 1181338  2527332     The afrominimalist's guide to living with less
# 1181339  2527332     The afrominimalist's guide to living with less
# 1181340  2520634  Abstract painting : the elements of visual lan...
#
#                             Author             ISBN  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878.0             2009     Book
# 1               Spears, Richard A.  9780071478939.0             2007     Book
# 2             Miller, Robin, 1964-  9780307451408.0             2009     Book
# 3                    Lester, Mark.  9780071496421.0             2008     Book
# 4             Miller, Robin, 1964-  9780307451408.0             2009     Book
# ...                            ...              ...              ...      ...
# 1181336           Platt, Christine  9781982168056.0             2022     Book
# 1181337           Platt, Christine  9781982168056.0             2022     Book
# 1181338           Platt, Christine  9781982168056.0             2022     Book
# 1181339           Platt, Christine  9781982168056.0             2022     Book
# 1181340  Davies, Jane (Ceramicist)  9780692619803.0             2017     Book
#
#             ItemCollection             ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                     Main      25.95
# 1           ELL Collection            South Central      20.00
# 2        Adult Non-Fiction                Southwest      19.99
# 3           ELL Collection            South Central      20.00
# 4        Adult Non-Fiction                Southwest      19.99
# ...                    ...                      ...        ...
# 1181336  Adult Non-Fiction                     Main      10.02
# 1181337  Adult Non-Fiction                  Newburg      10.02
# 1181338  Adult Non-Fiction            South Central      10.02
# 1181339  Adult Non-Fiction                  Western      10.02
# 1181340  Adult Non-Fiction  Highlands - Shelby Park      24.95
#
#                      ReportDate  ObjectId
# 0        2022/07/01 04:00:00+00         1
# 1        2022/07/01 04:00:00+00         2
# 2        2022/07/01 04:00:00+00         3
# 3        2022/07/01 04:00:00+00         4
# 4        2022/07/01 04:00:00+00         5
# ...                         ...       ...
# 1181336  2022/07/01 04:00:00+00   1657551
# 1181337  2022/07/01 04:00:00+00   1657552
# 1181338  2022/07/01 04:00:00+00   1657553
# 1181339  2022/07/01 04:00:00+00   1657554
# 1181340  2022/07/01 04:00:00+00   1657555
#
# [1181244 rows x 11 columns]

# %% [markdown]
# ## There is an extra '.0' on the string. Let's remove it

# %%
lfpl_books['ISBN'] = lfpl_books['ISBN'].astype(str).str.rstrip('.0')
lfpl_books
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1        1341361           McGraw-Hill's American idioms dictionary
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3        1341362  McGraw-Hill's essential ESL grammar : a handbo...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1181336  2527332     The afrominimalist's guide to living with less
# 1181337  2527332     The afrominimalist's guide to living with less
# 1181338  2527332     The afrominimalist's guide to living with less
# 1181339  2527332     The afrominimalist's guide to living with less
# 1181340  2520634  Abstract painting : the elements of visual lan...
#
#                             Author           ISBN  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878             2009     Book
# 1               Spears, Richard A.  9780071478939             2007     Book
# 2             Miller, Robin, 1964-  9780307451408             2009     Book
# 3                    Lester, Mark.  9780071496421             2008     Book
# 4             Miller, Robin, 1964-  9780307451408             2009     Book
# ...                            ...            ...              ...      ...
# 1181336           Platt, Christine  9781982168056             2022     Book
# 1181337           Platt, Christine  9781982168056             2022     Book
# 1181338           Platt, Christine  9781982168056             2022     Book
# 1181339           Platt, Christine  9781982168056             2022     Book
# 1181340  Davies, Jane (Ceramicist)  9780692619803             2017     Book
#
#             ItemCollection             ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                     Main      25.95
# 1           ELL Collection            South Central      20.00
# 2        Adult Non-Fiction                Southwest      19.99
# 3           ELL Collection            South Central      20.00
# 4        Adult Non-Fiction                Southwest      19.99
# ...                    ...                      ...        ...
# 1181336  Adult Non-Fiction                     Main      10.02
# 1181337  Adult Non-Fiction                  Newburg      10.02
# 1181338  Adult Non-Fiction            South Central      10.02
# 1181339  Adult Non-Fiction                  Western      10.02
# 1181340  Adult Non-Fiction  Highlands - Shelby Park      24.95
#
#                      ReportDate  ObjectId
# 0        2022/07/01 04:00:00+00         1
# 1        2022/07/01 04:00:00+00         2
# 2        2022/07/01 04:00:00+00         3
# 3        2022/07/01 04:00:00+00         4
# 4        2022/07/01 04:00:00+00         5
# ...                         ...       ...
# 1181336  2022/07/01 04:00:00+00   1657551
# 1181337  2022/07/01 04:00:00+00   1657552
# 1181338  2022/07/01 04:00:00+00   1657553
# 1181339  2022/07/01 04:00:00+00   1657554
# 1181340  2022/07/01 04:00:00+00   1657555
#
# [1181244 rows x 11 columns]

# %%
# ISBN is an string now
lfpl_books.dtypes
# Out:
# BibNum               int64
# Title               object
# Author              object
# ISBN                object
# PublicationYear      int64
# ItemType            object
# ItemCollection      object
# ItemLocation        object
# ItemPrice          float64
# ReportDate          object
# ObjectId             int64
# dtype: object

# %%
# Nothing is NaN after the conversion, it's the string 'nan' instead
lfpl_books[lfpl_books['ISBN'] == 'nan']
# Out:
#           BibNum                                              Title  \
# 4429     1348353  Stolen legacy: the Egyptian origins of western...
# 5336     1353427  A symposium in public librarianship; three add...
# 5510     1353740                     WWI : the Great War, 1914-1918
# 5511     1353780                                     LANKIE MANTITA
# 5931     2511351                                       My First Pet
# ...          ...                                                ...
# 1181091  2528085      Cognitive Mapping : Past, Present, and Future
# 1181093  2528087                                Eye of the Beholder
# 1181101  2528088                                        Sharp Edges
# 1181291  2527399                               the girl in the road
# 1181292  2527400                                      See Night Run
#
#                                                     Author ISBN  \
# 4429                                    James, George G. M  nan
# 5336     University of California, Berkeley. School of ...  nan
# 5510         Brown, Hilary (Author of Two-liners for kids)  nan
# 5511                                     LESLIE PATRICELLI  nan
# 5931                                                   NaN  nan
# ...                                                    ...  ...
# 1181091                                       Kitchin, Rob  nan
# 1181093                                      Krentz, Jayne  nan
# 1181101                                      Krentz, Jayne  nan
# 1181291                                       MONICA BYRNE  nan
# 1181292                                                NaN  nan
#
#          PublicationYear ItemType     ItemCollection            ItemLocation  \
# 4429                   0     Book  Interlibrary Loan                    Main
# 5336                1952     Book   Kentucky History                    Main
# 5510                2014     Book  Adult Non-Fiction                    Main
# 5511                   0     Book                NaN                 Shively
# 5931                   0     Book                NaN                 Newburg
# ...                  ...      ...                ...                     ...
# 1181091                0     Book  Interlibrary Loan                    Main
# 1181093                0     Book  Interlibrary Loan                    Main
# 1181101                0     Book  Interlibrary Loan                    Main
# 1181291                0     Book                NaN                    Main
# 1181292                0     Book                NaN  Childrens Main Library
#
#          ItemPrice              ReportDate  ObjectId
# 4429           0.0  2022/07/01 04:00:00+00      5055
# 5336          25.0  2022/07/01 04:00:00+00      7761
# 5510          15.0  2022/07/01 04:00:00+00      8010
# 5511           0.0  2022/07/01 04:00:00+00      8027
# 5931           0.0  2022/07/01 04:00:00+00      8588
# ...            ...                     ...       ...
# 1181091        0.0  2022/07/01 04:00:00+00   1657144
# 1181093        0.0  2022/07/01 04:00:00+00   1657147
# 1181101        0.0  2022/07/01 04:00:00+00   1657176
# 1181291        0.0  2022/07/01 04:00:00+00   1657506
# 1181292        0.0  2022/07/01 04:00:00+00   1657507
#
# [36430 rows x 11 columns]

# %%
isbn_length = lfpl_books['ISBN'].str.len().value_counts()
isbn_length
# Out:
# ISBN
# 13    1031252
# 12     102249
# 3       36430
# 11      10031
# 10       1137
# 9         140
# 8           4
# 7           1
# Name: count, dtype: int64

# %% [markdown]
# ## Starting with len == 3

# %% [markdown]
# ## We'll try to fill the missing ISBN information using the open library API

# %%
# Testing with the Open Library Books API - v1
import pandas as pd
import requests

def get_isbn_from_api(book_title):
    base_url = "http://openlibrary.org/search.json"
    params = {"title": book_title}
    
    try:
        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        data = response.json()
        # Check if any documents were found
        if data.get("docs"):
            # Assuming the first result is the most relevant
            isbn = data["docs"][0].get("isbn")[3]            
            return str(isbn)
        else:
            return ""
    except requests.exceptions.RequestException as e:
        #print(f"Error in API request: {e}")
        return ""

# %%
# Function to apply to the DataFrame
def fill_missing_isbn(row):
    if row["ISBN"] == "nan":
        return get_isbn_from_api(row["Title"])
    else:
        return row["ISBN"]

# %%
# Example DataFrame
data = {
    "Title": ["Cognitive Mapping : Past, Present, and Future","LANKIE MANTITA", "WWI : the Great War, 1914-1918", "the girl in the road", "Sharp Edges", "My First Pet"],
    "ISBN": ["nan", "nan", "nan", "nan", "nan","nan"]
}

df = pd.DataFrame(data)

# Apply the function using lambda only to rows with missing ISBN
df["ISBN"] = df.apply(lambda row: fill_missing_isbn(row), axis=1)

print(df)
# Out:
#                                            Title           ISBN
# 0  Cognitive Mapping : Past, Present, and Future
# 1                                 LANKIE MANTITA
# 2                 WWI : the Great War, 1914-1918
# 3                           the girl in the road  9780349004372
# 4                                    Sharp Edges     1568955499
# 5                                   My First Pet  9789354400391

# %%
# Testing with the Open Library Books API - v2

def get_isbn_from_openlibrary(title):
    base_url = "http://openlibrary.org/search.json"
    params = {"title": title}
    response = requests.get(base_url, params, headers={"Accept-Encoding": "gzip"})
    if response.status_code == 429:
        retry_after = int(response.headers.get("Retry-After"))
        print(f"API rate limit exceeded. Retrying after {retry_after} seconds.")
        time.sleep(retry_after)
        return get_isbn_from_openlibrary(title)
    if response.status_code != 200:
        print(f"Error retrieving ISBN for title '{title}': {response.status_code}")
        return None
    content_type = response.headers.get("Content-Type")
    if content_type == "application/gzip":
        with gzip.decompress(response.content) as decompressed_data:
            data = json.loads(decompressed_data.decode("utf-8"))
    else:
        data = json.loads(response.content.decode("utf-8"))
    isbn = data.get("docs")[0].get("isbn")[0] if data.get("docs") and data.get("docs")[0].get("isbn") else None
    return isbn

# %%
def populate_isbn(book_title, csvfile):
    isbn = get_isbn_from_openlibrary(book_title)

    if isbn:
        with open(csvfile, "a", encoding="utf-8", newline="") as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow([isbn, book_title])
            print(f'Saving: {book_title}')
    return isbn

# %%
# Creating a copy of the dataframe with the title columns
temp_df = lfpl_books[lfpl_books["ISBN"]=="nan"][["Title"]].drop_duplicates()
shape_c = temp_df.shape
print(f"Rows: {shape_c[0]:,}, Columns: {shape_c[1]}")
# Out:
# Rows: 28,327, Columns: 1

# %%
# Optimize the code for speed by using ThreadPoolExecutor to increase the overall speed of the process
with ThreadPoolExecutor(max_workers=10) as executor:
  temp_df["ISBN"] = list(executor.map(populate_isbn, [temp_df['Title'], "data\lfpl_books_isbn.csv"]))

# Update the lfpl_books dataframe with the populated ISBNs
#lfpl_books.update(pd.DataFrame(results, columns=temp_df.columns))
temp_df
# Out:
# Saving: O little town of Sugarcreek
# Saving: The Christmas riddle
# Saving: Castle of whispers
# Saving: My First Pet
# Saving: Centaur aisle
# Saving: Simple lies
# Saving: A season of secrets
# Saving: The tenant of Wildfell Hall
# Saving: Deceptive hearts
# Saving: Stocks on the Move
# Saving: Act of War
# Saving: The Book of Liz
# Saving: designing your work life
# Saving: The secret letter
# Saving: FUNNY FARM
# Saving: Bing ya
# Saving: Wagon Wheels
# Saving: Baby Mickey's nap : a book about touch.
# Saving: Farm friends : a book about animal sounds.
# Saving: Watch and learn : a book about shapes.
# Saving: Confessions of a gym-class dropout
# Saving: McSweeney's no. 40
# Saving: Military Government in the Ryukyu Islands, 1945-1950
# Saving: Olivia and the Billionaire cattle king
# Saving: Migrating from the Kentucky Holy Lands to Owensboro, Kentucky in 2017
# Saving: The Yakima`
# Saving: Hunger
# Saving: The Powhatan Indians
# Saving: Hideaway
# Saving: ain't no valley
# Saving: The Corps of Engineers : the war against Japan
# Saving: HORSE ILLUSTRATED
# Saving: EQUUS
# Saving: speedhorse
# Saving: Happy Thanksgiving
# Saving: FOUR
# Saving: CODE OF THE FOREST
# Saving: How the Battleship Maine was destroyed
# Saving: The Women's Army Corps
# Saving: American military heritage
# Saving: Hurricanes and Tornadoes
# Saving: A Crack in the Clouds and Other Poems
# Saving: The Presidents.
# Saving: Korea, 1950
# Saving: My little organ book
# Saving: Benjamin Blümchen : als Feuerwehrmann
# Saving: Benjamin Blümchen : hat Geburtstag
# Saving: The book of American Negro poetry
# Saving: Fractured lands
# Saving: Rearming the French
# Saving: Vietnam from cease-fire to capitulation
# Saving: Seven firefights in Vietnam
# Saving: Cosette.
# Saving: History of military mobilization in the United States Army, 1775-1945
# Saving: Germs make me sick
# Saving: History of personnel demobilization in the United States Army
# Saving: dreams of the dark
# Saving: Abstract of land grant surveys : Augusta & Rockingham counties, 1761-1791
# Saving: one mitten
# Saving: The Passover Lamb
# Saving: A Fairy tale
# Saving: Pennsylvania births
# Saving: Attack of the Girlzillas
# Saving: Certain victory : the US Army in the Gulf War
# Saving: Sacred mysteries among the Mayas and the Quiches, 11,500 years ago. Their relation to the sacred mysteries of Egypt, Greece, Chaldea and India.
# Saving: Political reorientation of Japan : September 1945 to September 1948
# Saving: The campaign on New Britain
# Saving: Judith
# Saving: Building a strategic Air Force
# Saving: The United States Air Force in Korea 1950-1953.
# Saving: The Air Force integrates, 1945-1964
# Saving: The Supreme Command
# Saving: Marines and helicopters : 1946-1962
# Saving: Blacks in the Marine Corps
# Saving: U.S. Marines in Lebanon, 1982-1984
# Saving: This is reggae music.
# Saving: ABSENT IN THE SPRING
# Saving: Living American documents
# Saving: Eureka!
# Saving: Alice Neel
# Saving: The real cool killers
# Saving: This Changes Everything
# Saving: The innocents abroad
# Saving: The endangered species handbook
# Saving: The lizard in the cup
# Saving: Roughing it
# Saving: Life on the Mississippi
# Saving: 12 greatest hits
# Saving: Quartermaine's terms
# Saving: Other places : three plays
# Saving: I, the jury
# Saving: 51 lucky Irish classics.
# Saving: The spell of the Yukon
# Saving: The life and adventures of Nicholas Nickleby
# Saving: Eye for colour
# Saving: The life of Benvenuto Cellini
# Saving: Man in nature
# Saving: William Russell and his descendants
# Saving: City
# Saving: The floods of 1913 in the rivers of the Ohio and lower Mississippi valleys
# Saving: Our brothers' war
# Saving: Up from slavery : an autobiography
# Saving: Records of colonial Gloucester County, Virginia a collection of abstracts from original documents concerning the lands and people of colonial Gloucester County
# Saving: The apology, Phædo and Crito of Plato
# Saving: Historic Kentucky highways.
# Saving: English art, 1307-1461.
# Saving: George Inness.
# Saving: Final report : findings and recommendations.
# Saving: Negro employment opportunities
# Saving: Kentucky trails
# Saving: Capital punishment
# Saving: Criminal procedure: evidence.
# Saving: Famous American belles of the nineteenth century
# Saving: Beau ideal
# Saving: Who's who in Louisville
# Saving: The Irvines and their kin : a history of the Irvine family and their descendants
# Saving: The Kentucky Derby since 1875.
# Saving: Kentucky.
# Saving: Nurses on horseback
# Saving: French faience.
# Saving: Big Red.
# Saving: The 756th Tank Battalion in the Battle of Cassino 1944
# Saving: Historical sketches of Kentucky
# Saving: John Marshall Harlan, 1833-1911.
# Saving: History of Cumberland County
# Saving: Ten years among the newsboys
# Saving: Granny remembers
# Saving: Christmas in Kentucky, 1862.
# Saving: Kentucky votes
# Saving: Light in dark places
# Saving: Memoranda of the Preston family.
# Saving: A Treasury of famous waltzes
# Saving: Weaving is fun
# Saving: Abstract of early Kentucky wills and inventories, copied from original and recorded wills and inventories.
# Saving: Backward glance
# Saving: The drawings of Raphael
# Saving: Photography, a short critical history
# Saving: Seloc's Mercruiser stern drive tune-up and repair manual
# Saving: Rubens; selected drawings.
# Saving: Lectures on the history of philosophy
# Saving: German shorthaired pointers
# Saving: History of merchant shipping and ancient commerce.
# Saving: The girl in the red velvet swing
# Saving: Guide to lace and linens
# Saving: The researcher's guide to American genealogy
# Saving: Miss Daisy celebrates Tennessee
# Saving: What's your net worth?
# Saving: Jane's world armies
# Saving: Simple takes a wife
# Saving: Shadow and act
# Saving: Mourning glory
# Saving: Missouri, 2000. Summary population and housing characteristics : 2000 census of population and housing.
# Saving: Oklahoma, 2000. Summary population and housing characteristics : 2000 census of population and housing.
# Saving: The grammar of ornament
# Saving: The heroic adventure of Hercules Amsterdam
# Saving: Cedar Grove Cemetery
# Saving: Daylight
# Saving: DINAH WASHINGTON
# Saving: Line dance
# Saving: The prominent families of the United States of America
# Saving: A dictionary of art and artists
# Saving: Poems, new & collected
# Saving: Geography of Kentucky.
# Saving: The spirit of the mountains
# Saving: Rice family history.
# Saving: Climb your family tree
# Saving: Love in the South Seas
# Saving: The American star speaker and model elocutionist
# Saving: Lerner and Loewe's Gigi
# Saving: Testament of a liberal.
# Saving: A history of the hemp industry in Kentucky.
# Saving: Flowing South.
# Saving: The walking dead
# Saving: Corneille
# Saving: A concise dictionary of foreign expressions
# Saving: Hitchcock-- the murderous gaze
# Saving: The pasta-lover's diet book
# Saving: Introducing Kyoto
# Saving: Sketches of western adventure.
# Saving: Attorney General's Commission on Pornography : final report.
# Saving: Thy brother death
# Saving: A century of Negro migration
# Saving: Airborne trailblazer
# Saving: To market! To market!
# Saving: Plays
# Saving: Kentucky River, Kentucky.
# Saving: Can such things be?
# Saving: Stilwell's command problems
# Saving: The marriage license bonds of Northumberland County, Virginia, from 1783 to 1850
# Saving: Pharmacy law
# Saving: The Process of government
# Saving: Sandals and other fabrics from Kentucky caves
# Saving: Frank Duveneck
# Saving: European architecture in India, 1750-1850
# Saving: Archigram.
# Saving: Delineations of American scenery and character
# Saving: The Kentucky highlanders from a native mountaineer's viewpoint
# Saving: Tall tales of the Kentucky mountains
# Saving: Townscape
# Saving: Handbook of Kentucky.
# Saving: Bubbling waters
# Saving: Indian Knoll, site Oh 2, Ohio County, Kentucky
# Saving: Frederick County, Virginia, marriages, 1771-1825.
# Saving: The centurion
# Saving: Some of the descendants of Robert and Jane (       ) McCune, of Bourbon and Nicholas County, Kentucky.
# Saving: The story of Kentucky
# Saving: Ivories.Saving: The wilderness trail; or, The ventures and adventures of the Pennsylvania traders on the Allegheny path
#
# Saving: War memorials
# Saving: Cake, candy and culinary crinkles ; a companion to "What to cook and how to cook it."
# Saving: Business--a profession
# Saving: Pioneer women of the West.
# Saving: History and genealogy of the Jacob Turpin branch of the Turpin family, being a brief history and genealogy of the members of the first and second generations, and a genealogy of the members of all other generations down to the present time
# Saving: The story of my life
# Saving: On the Ohio
# Saving: The Thirty Years War
# Saving: Brick architecture of the colonial period in Maryland & Virginia
# Saving: Abraham Lincoln as attorney for the Illinois Central Railroad Company.
# Saving: Daniel Boone and the Wilderness Road
# Saving: Early Christian and Byzantine architecture
# Saving: Clipper ship prints, including other merchant sailing ships
# Saving: Memories.
# Saving: An anthology of light verse
# Saving: Catholicism and American freedom
# Saving: Zealots of Zion
# Saving: Orders and decorations
# Saving: Amelia takes command
# Saving: The professor of light
# Saving: Modes and manners
# Saving: Guadalcanal: the first offensive.
# Saving: Loot
# Saving: Animal Gospel
# Saving: The book of tree peonies
# Saving: Too close to the falls
# Saving: Toulouse-Lautrec; his complete lithographs and drypoints
# Saving: The lieder of Brahms.
# Saving: Songs of the cowboys
# Saving: Vocal selections from Mame
# Saving: Colored glassware of the Depression Era 2
# Saving: Lord Nelson mass mass no. 3 in D
# Saving: On the origin of species.
# Saving: Tannhauser
# Saving: Commodore Hornblower
# Saving: The complete works of Robert Burns.
# Saving: Modern Korean short stories
# Saving: Crewel embroidery
# Saving: Dinner at Deviant's Palace
# Saving: Shivaree
# Saving: Let's do fingerplays
# Saving: The complete poetical works of James Russell Lowell.
# Saving: The duties of man and other essays
# Saving: The Jewish wedding book
# Saving: Escape on Venus
# Saving: Romance language
# Saving: Pirates of Venus
# Saving: Weeden's history of the colored people of Louisville
# Saving: Twice loved
# Saving: Henry Fielding's theory of the comic prose epic
# Saving: A short history of women
# Saving: Aucassin and Nicolette, and other mediaeval romances and legends
# Saving: Certificate book of the Virginia Land Commission, 1779-1780.
# Saving: Kentucky county maps.
# Saving: Rouault
# Saving: One wide river
# Saving: The Hamburg passenger lists.
# Saving: The last hayride
# Saving: Thanatos : earth poems
# Saving: Parish maps of the counties of England and Wales
# Saving: A, my name is Alice
# Saving: The comedy of Neil Simon
# Saving: Pack of lies
# Saving: Locomotive cyclopedia of American practice.
# Saving: Behaviour and perception in strange environments
# Saving: The Wycliffe historical geography of Bible lands
# Saving: Transparencies
# Saving: Neither five nor three
# Saving: Sisley
# Saving: She stoops to conquer, or, The mistakes of a night
# Saving: Ingres
# Saving: Tristia ; Ex Ponto
# Saving: Toga! toga! toga!
# Saving: The German element of the Shenandoah Valley of Virginia
# Saving: Footnotes
# Saving: Snapshots
# Saving: Michigan in the World War : Military and Naval honors of Michigan men and women. Congressional Medal of Honor. Distinguished Service Cross. Distinguished Service Medal. Naval Decorations. Foreign Decorations
# Saving: The angelic alphabet
# Saving: The gods are athirst
# Saving: The case of the musical cow
# Saving: Poetical works
# Saving: The Cooking book.
# Saving: Bystander
# Saving: The Soviet Union since the fall of Khrushchev
# Saving: Humana Festival of New American Plays
# Saving: Dramatic myths and legends.
# Saving: Wit and wisecracks
# Saving: The Book of Mormon : an account written by the Hand of Mormon upon plates taken from the plates of Nephi
# Saving: The three principles of the people
# Saving: The storm, and other Russian plays
# Saving: The Goodwin families in America
# Saving: Admission record, Indianapolis Asylum for Friendless Colored Children, 1871-1900
# Saving: Holbein
# Saving: Hungarians in Ontario
# Saving: The face
# Saving: Constable
# Saving: Pins and needles
# Saving: The meaning of prayer
# Saving: Wedding music
# Saving: Anthology of contemporary Latin-American poetry
# Saving: Education and the brain
# Saving: Principles, dialogues, and philosophical correspondence
# Saving: Prose works other than Science and health : with key to the scriptures
# Saving: The Tatler
# Saving: The so-called Wends of Germany and their colonies in Texas and in Australia
# Saving: Anima poetæ : from the unpublished note-books of Samuel Taylor Coleridge
# Saving: Buccaneers and pirates of our coasts
# Saving: The mysterious rider
# Saving: Your history : from the beginning of time to the present
# Saving: The American tradition in literature
# Saving: Mallett's Index of artists : international-biographical, including painters, sculptors, illustrators, engravers and etchers of the past and the present.
# Saving: The rose garden
# Saving: In search of London.
# Saving: Selections from E.T. : (the Extra Terrestrial)
# Saving: Hank's Hank
# Saving: The book of musical knowledge; the history, technique, and appreciation of music, together with lives of the great composers, for music- lovers, students and teachers.
# Saving: Then and now
# Saving: Songs of a mountain plowman
# Saving: A narrative of the life & travels of John Robert Shaw, the well-digger : now resident in Lexington, Kentucky
# Saving: Ben Franklin's wit and wisdom.
# Saving: Collected poems
# Saving: Honore Daumier
# Saving: Dante and his Italy
# Saving: Death eat
# Saving: Autobiography ; Essay on liberty
# Saving: Shadowfires
# Saving: Grab bag
# Saving: Exploring the New Testament
# Saving: The emergence of the modern Middle East
# Saving: The Gallic War.
# Saving: A Quarter century of poetry from Belgium
# Saving: Pennsylvania 1860 Pittsburgh : (Allegheny and Butler counties)
# Saving: Louisiana 1860 census index
# Saving: The North American Indians; an account of the American Indians north of Mexico
# Saving: Stories
# Saving: Born to coach
# Saving: I remember
# Saving: The history, diagnosis, and treatment of the fevers of the United States.
# Saving: Public service guidelines
# Saving: Il barbiere di Siviglia
# Saving: Letters to the children
# Saving: The spirit of oriental poetry
# Saving: Hennepin County Library collection maintenance manual
# Saving: West Virginia 1890 veterans census
# Saving: Acoustic design
# Saving: Gifts.
# Saving: La Fontaine's fables
# Saving: Romance, Romance : two new musicals
# Saving: The world as will and idea
# Saving: The Heidi chronicles
# Saving: Physics research activities
# Saving: Israel Passover Haggadah
# Saving: A clearing in the woods: a play
# Saving: Strategic planning for coalition warfare, 1943-1944
# Saving: Learn Welsh for English speakers
# Saving: Remains to be seen
# Saving: Elegy written in a country church yard.
# Saving: Art in the western world
# Saving: Gallagher.
# Saving: Wood carving
# Saving: Northwest Africa : seizing the initiative in the west.
# Saving: The beatinest boy
# Saving: Accessibility to markets.
# Saving: My life.
# Saving: History of Marion County
# Saving: Songs of home
# Saving: The rightful owner
# Saving: A few good men
# Saving: Sketches of Kentucky
# Saving: Choosing and working with a conservator
# Saving: The cemetery club
# Saving: The speed of darkness
# Saving: Black flyers in World War II
# Saving: The Bill of Rights and beyond, 1791-1991.
# Saving: Truly, madly, deeply
# Saving: The Negro in Mississippi : 1865-1890
# Saving: The silent life.
# Saving: Four plays
# Saving: Pure & simple.
# Saving: The Cathedral
# Saving: Phone book.
# Saving: Charles Dickens' A christmas carol
# Saving: Monologues for men
# Saving: A balancing act
# Saving: Robin Hood
# Saving: The Baltimore Waltz
# Saving: Journey into yesterday
# Saving: Sight unseen
# Saving: Three plays
# Saving: History of the Office of the Secretary of Defense
# Saving: New crops, new uses, new markets : industrial and commercial products from U.S. agriculture.
# Saving: Horn
# Saving: Reproductive biology and early life history of fishes in the Ohio River drainage
# Saving: Thigmotropism
# Saving: 1900 census, Washington Co., Kentucky
# Saving: Narrative of Sojourner Truth.
# Saving: West Point and the Civil War
# Saving: The blue hills
# Saving: Kentucky handbook
# Saving: Riding the packet boats and other stories
# Saving: History of the Lander family of Virginia and Kentucky
# Saving: A treasury of Hans Christian Andersen
# Saving: Report on code of legal ethics
# Saving: Landmarks.
# Saving: Festive firsts
# Saving: Neighborhood bibliography series
# Saving: Martial law
# Saving: Essays and English traits
# Saving: Virgil's AEneid
# Saving: Directory
# Saving: Facts for the people.
# Saving: Constitution
# Saving: Briefs.
# Saving: Property description.
# Saving: Kentucke
# Saving: The war against Japan.
# Saving: Three poets : three plays
# Saving: Know your temple.
# Saving: [Letters]
# Saving: Study
# Saving: The Golden skylark and other stories
# Saving: Pamphlets.
# Saving: Miracles and other wonders
# Saving: The Acadian Breaux-s of Louisiana and the English Lockes of New Hampshire
# Saving: The way it is.
# Saving: Workmen's compensation law
# Saving: Davis
# Saving: On spiritualism : part one
# Saving: Renewing the United Nations system
# Saving: Gethsemani magnificat : centenary of Gethsemani Abbey
# Saving: There is an answer.
# Saving: Susan's kitchen
# Saving: Our flag
# Saving: Manual of procedures
# Saving: Report and recommendations
# Saving: Fort Boonesborough.
# Saving: Transportation facts and figures
# Saving: A journey to the Falls
# Saving: Love! Valour! Compassion!
# Saving: The Bowmans, a pioneering family in Virginia, Kentucky and the Northwest Territory
# Saving: Complete guide for horse business success
# Saving: Kentucky women.
# Saving: Selected tales and poems
# Saving: The American flag.
# Saving: The annals and history of Henrico Parish, Diocese of Virginia, and St. John's P.E. ChurchSaving: Martha, Martha!
#
# Saving: The life of Daniel Boone ; the founder of the state of Kentucky
# Saving: A practical and easy course of the German language
# Saving: The critical dimension.
# Saving: A political primer.
# Saving: Audubon bird prints
# Saving: Who's who in health care.
# Saving: Public health manual.
# Saving: The house that service built
# Saving: Building for the future.
# Saving: Song book
# Saving: End of the world : a play
# Saving: The beeches.
# Saving: Up to Standard.
# Saving: Kentucky at a glance.
# Saving: Salerno : American operations from the beaches to the Volturno, 9 September - 6 October 1943.
# Saving: US infantry, Vietnam
# Saving: The Frontier Nursing Service
# Saving: Ancient and accepted Scottish Rite.
# Saving: Let's quilt our Black heritage!
# Saving: The American saddle horse
# Saving: Southern Police Institute.
# Saving: Genealogical record of the Rice family
# Saving: Food and education.
# Saving: They will never forget.
# Saving: My mother's people
# Saving: The home front.
# Saving: System of education
# Saving: The Thomas family history
# Saving: Kentucky whiskey
# Saving: Maryland marriages, 1634-1777
# Saving: Developed with care.
# Saving: Much ado about nothing
# Saving: History of Jefferson County
# Saving: Doctor Who and the day of the Daleks
# Saving: Forty years of trust
# Saving: Bulfinch's mythology : the age of fable
# Saving: Old Louisville
# Saving: Major Robert Anderson and Fort Sumter, 1861
# Saving: Favorite recipes
# Saving: Homemade holidays
# Saving: Final recommendations
# Saving: Aunt Peggy : being a memoir of Mrs. Margaret Davidson Ewing, wife of the late Rev. Finis Ewing
# Saving: The misadventures of Jack Flack
# Saving: James Hall : literary pioneer of the Ohio valley
# Saving: The adventures of Daniel Boone
# Saving: Memoir of the life and character of Rev. Lewis Warner Green : with a selection from his sermons
# Saving: Letters of Rebecca Gratz
# Saving: The life of Gen. Albert Sidney Johnston : embracing his services in the armies of the United States, the Republic of Texas, and the Confederate States
# Saving: Audubon.
# Saving: Cliffs notes on Joyce's Portrait of the artist as a young man
# Saving: The millennium
# Saving: Memorial paper
# Saving: David Morton : a biography
# Saving: Life of Elder Walter Scott : with sketches of his fellow-laborers, William Hayden, Adamson Bentley, John Henry, and others
# Saving: Reminiscences of a long life
# Saving: The speeches of Charles Dickens
# Saving: Hotel Splendide
# Saving: The pilgrim's progress
# Saving: Centennial history of the Pennsylvania Railroad Company, 1846-1946
# Saving: A fire in the heart
# Saving: What are you?
# Saving: The slaughter of the Jews in the Ukraine in 1919
# Saving: Myth and legend of ancient Israel
# Saving: The history of the United States army.
# Saving: Tree care
# Saving: Snuff and snuff-boxes
# Saving: Romance without reservations
# Saving: Midway Cemetery interments, 1890-1997
# Saving: Mexico and Peru
# Saving: The I in my people
# Saving: Washington County marriages, 1792-1825
# Saving: High points in the history of Italian literature
# Saving: A dictionary of British sporting painters
# Saving: The Tudor, Stuart, and early Georgian pictures in the collection of Her Majesty the Queen
# Saving: Be!
# Saving: Aesthetical and philosophical essays
# Saving: The emerging South
# Saving: Comedies
# Saving: The road to the White House : the politics of presidential elections
# Saving: History of southwest Virginia, 1746-1786, Washington County, 1777-1870
# Saving: Index of Japanese painters.
# Saving: Blackboard blackmail
# Saving: Sculpture : Italian
# Saving: Cyclopedia of painters and paintings
# Saving: Japanese colour prints
# Saving: Iphigenia at Aulis ; and, Iphigenia in Tauris
# Saving: Honoré Daumier
# Saving: Burne-Jones
# Saving: Lighting and sound
# Saving: The permanence of Johann Gutenberg
# Saving: Historic Jefferson County
# Saving: Guardian bonds
# Saving: Back then
# Saving: The common sense of science
# Saving: The PRS guitar book
# Saving: A man of the courts
# Saving: The Randy Travis songbook.
# Saving: House of soul, house of blues
# Saving: Soccer rules
# Saving: African rifles & cartridges
# Saving: Shepherd moons
# Saving: Coningsby : or The new generation
# Saving: The tale of one bad rat
# Saving: The approved selections for supplementary reading and memorizing : in the schools of New York, Philadelphia, Chicago, New Orleans, and other cities
# Saving: Anthology of Swedish lyrics : from 1750 to 1915
# Saving: The art of reading poetry
# Saving: An anthology of Victorian poetry
# Saving: The Sheldon book of verse
# Saving: Doctor Dolittle's zoo
# Saving: Religion in the eighteenth century.
# Saving: American poetry
# Saving: A piece of the pie
# Saving: A compendium of the War of the Rebellion
# Saving: Dictionary English-Tagalog, Tagalog-English : (Pilipino)
# Saving: Reading group choices.
# Saving: Final report, December 2001.
# Saving: The Second Bank of the United States
# Saving: Cambodian-English English-Cambodian dictionary
# Saving: Living artists.
# Saving: Silent wings
# Saving: Memories of days gone by
# Saving: Catalogue of plaster reproductions from antique, medieval, and modern sculpture : subjects for art schools.
# Saving: The Federalist papers
# Saving: The pioneers
# Saving: Voice of the hills
# Saving: Linger, and be available
# Saving: The quest for Corvo
# Saving: Medardo Rosso
# Saving: Charles County, Maryland : 1800 census
# Saving: It's winter
# Saving: Guide for the preparation of patent drawings.
# Saving: Sarah's room
# Saving: The goddesses of Kitchen Avenue
# Saving: The last goodbye : a novel
# Saving: The King James study Bible : King James Version.
# Saving: 1968 : the year that rocked the world
# Saving: Departures & arrivals.
# Saving: A saga of the black child
# Saving: A saga of the black woman
# Saving: A saga of the black man
# Saving: Southern cooking for everyday living
# Saving: Essential Shakespeare handbook
# Saving: Heartburn & reflux for dummies
# Saving: Our American government.
# Saving: How we talked
# Saving: Fighting ships of World War II
# Saving: Down by the station
# Saving: Marwar Jodhpur
# Saving: The Black Death
# Saving: English-Russian phrasebook with useful wordlist
# Saving: Complete poetical works
# Saving: Kentucky Lake Reservoir cemeteries
# Saving: Red as blood : or, Tales from the Sisters Grimmer
# Saving: An apology for autumn
# Saving: 16 extraordinary Hispanic Americans
# Saving: The story of American golf : its champions and its championships
# Saving: Christmas from the heart.
# Saving: A concise Greek-English dictionary of the New Testament
# Saving: Jesus Christ superstar
# Saving: Lupin III
# Saving: Ultra maniac
# Saving: Science is--
# Saving: My Old House
# Saving: Dark of the moon
# Saving: Everyday things in ancient Greece
# Saving: The Devil and Daniel Webster
# Saving: John Dryden's imagery
# Saving: The derby
# Saving: The last days of Pompeii.
# Saving: Down drafts
# Saving: Celebrate Kentucky!
# Saving: Tiny chick
# Saving: Slavery in America.
# Saving: Introduction to the Talmud; historical and literary introduction, legal hermeneutics of the Talmud, Talmudical terminology and methodology, outlines of Talmudical ethics. Appendix: Key to the abbreviations used in the Talmud and its commentaries.
# Saving: Sam's sandwich.
# Saving: Genealogy
# Saving: The wonderful Wizard of Oz
# Saving: Little monsters.
# Saving: Disney's Aladdin Monkey Business
# Saving: Jesse Bear's tra la tub.
# Saving: I go to preschool.
# Saving: Jesse Bear's yum yum crumble.
# Saving: Tanya steps out.
# Saving: Tom's train.
# Saving: Charlie the chicken.
# Saving: Early Netherlandish painting.
# Saving: Wee Willie Winkie & other nursery rhymes
# Saving: Humpty dumpty.
# Saving: The snowstorm.
# Saving: Going baboony!
# Saving: For better or for worseSaving: My first pet.
#
# Saving: Threads of thought
# Saving: Secret codes & hidden messages.
# Saving: Melly's menorah.
# Saving: The new horizon ladder dictionary of the english language
# Saving: The Thanksgiving monster.
# Saving: Hanukkah fun.
# Saving: The Mutt in the iron muzzle.
# Saving: Big red fire truck.
# Saving: My hanukkah book.
# Saving: Bunny Isabel's Easter egg hunt.
# Saving: [Manuscripts]
# Saving: Pumpkin faces.
# Saving: Baby's Christmas.
# Saving: Skydive!
# Saving: Christmas mouse.
# Saving: Little mouse meets the Easter bunny.
# Saving: Christmas in snowy forest.
# Saving: Feely bugs.
# Saving: The great Santa surprise.
# Saving: Rojo.
# Saving: Shoot for the hoop.
# Saving: Mommy, would you love me if....?
# Saving: Charley's house
# Saving: Treasure in the royal tower.
# Saving: Eye spy a puppy!
# Saving: Report of examination of Ohio River : with a view to obtaining channel depths of 6 and 9, respectively
# Saving: Baby dance.
# Saving: Jingle bugs.
# Saving: Big blue engine.
# Saving: Who drives this?
# Saving: Matchmates
# Saving: Clifford's first halloween.
# Saving: Little critter's the night before Christmas.
# Saving: Slocum and the Nebraska swindle.
# Saving: Mystery of the black rhino.
# Saving: Talisman del amor.
# Saving: Only my Mom and me.
# Saving: Five little chicks.
# Saving: When love commands
# Saving: Peek-a-zoo!
# Saving: Noisy kisses.
# Saving: Blessings of the heart.
# Saving: What happens next? (Y ahora, que pasara?)
# Saving: Best thing about valentines.
# Saving: Beep beep.
# Saving: Otra mujer.
# Saving: Let's hop and skip!Saving: Biscuit loves Mother's day.
#
# Saving: Puppy love.
# Saving: The red-hot Cajun.
# Saving: Night-night, baby.Saving: Max's Christmas stocking.
#
# Saving: Boo! a halloween peek a boo! book.
# Saving: The Heritage
# Saving: Thanksgiving in the barn.
# Saving: Lola's trick or treat.
# Saving: Who am I? (English/Russian)
# Saving: Gaspard and Lisa's ready for school words.
# Saving: Halloween costume hunt.
# Saving: Slocum and the Teton temptress.
# Saving: Julius's candy corn.
# Saving: Brother Bear loves dinosaurs.
# Saving: What are you doing, Maisy?
# Saving: Santa's surprise.
# Saving: Sawyer's quest.
# Saving: Amazon and the warrior.
# Saving: Man in the maze.
# Saving: London blitz murders.
# Saving: Busy penguins.
# Saving: Ricky Ricotta y el poderoso robot.
# Saving: Louisville's first families; a series of genealogical sketches
# Saving: Jingle bells.
# Saving: This little piggy.
# Saving: Setting the pace.
# Saving: Dutch uncle.
# Saving: The Proustian vision
# Saving: The doctor and the devils
# Saving: The Lakeside story
# Saving: One red dot.
# Saving: Rogue River feud
# Saving: Dickens Christmas carol
# Saving: Robert Frost, a chronological survey
# Saving: South to the Naktong, north to the Yalu; June-November 1950.
# Saving: Flower arrangement art of Japan
# Saving: Winter's tale.Saving: Rubens
#
# Saving: Rebel women
# Saving: Two years before the mast : a personal narrative of life at sea
# Saving: Italian blown glass, from ancient Rome to Venice.
# Saving: The book of the thousand nights and one night
# Saving: Farther north
# Saving: Mammoth Cave of Kentucky : an illustrated manual
# Saving: King and Queen County, Virginia
# Saving: Colonel Theodore O'Hara, author of The Bivouac of the dead
# Saving: Experiences of the circuit rider
# Saving: The sun shines bright
# Saving: Across the fields of yesterday
# Saving: The Blood of champions
# Saving: Story of the Century.
# Saving: Mammoth Cave of Kentucky (Hovey and Call)
# Saving: Crime in Kentucky
# Saving: A syllabus of Kentucky folk-songs
# Saving: Hoosiers
# Saving: Negroes in the United States.
# Saving: Whose Tale Is This?
# Saving: Katy Cat and Beaky Boo.
# Saving: Spot Visits His Grandparents.
# Saving: Not so rotten ralph
# Saving: Disney's the Lion King.
# Saving: La Montana De Fuego.
# Saving: Roxie and Bo together.
# Saving: Everyone hide from Wibbly Pig.
# Saving: My "D" book
# Saving: Noodles
# Saving: Encuentro
# Saving: Kia Tanisha.
# Saving: Ten little dinosaurs.
# Saving: In the ocean.
# Saving: My first Thanksgiving
# Saving: Going to bed book
# Saving: The night before Christmas
# Saving: Spot's first walk
# Saving: Huracanes!
# Saving: Boats
# Saving: Nicky visits the airport.
# Saving: There was an old lady who swallowed a fly
# Saving: The Pocket Aristotle
# Saving: What's in the cave
# Saving: How many bugs in a box?
# Saving: Spot goes to the farm
# Saving: I want to be a clown
# Saving: The late romances
# Saving: Jack it's playtime.
# Saving: Happy Thanksgiving, Biscuit!
# Saving: Planes and other things that fly.
# Saving: My first Thanksgiving book.
# Saving: Dots! dots! dots! at the museum.
# Saving: Jack it's bedtime.
# Saving: Jack happy birthday.
# Saving: Jedi under siege
# Saving: Sherlock Holmes mysteries
# Saving: What is Thanksgiving?
# Saving: Bugs in space
# Saving: Bugs that go bump in the night
# Saving: Beowulf
# Saving: The long-nosed pig
# Saving: Little rabbit's bedtime
# Saving: Red-hot hightops
# Saving: Whose tail is that?
# Saving: Daddy, would you love me if...?
# Saving: Shh! (Don't tell Mr. Wolf!)
# Saving: Big machines.
# Saving: Stone soup
# Saving: Property of
# Saving: It's great to be two.
# Saving: Ken Wilson-Max's amazing circus performers.
# Saving: Jesse Bears wiggle jiggle jump up
# Saving: Good morning, Baby!
# Saving: Yankee doodle.
# Saving: What's on my head?
# Saving: La señora de los sueños
# Saving: Kit And Kat.
# Saving: Busy babies.
# Saving: Whose House Is This?
# Saving: Musica Para Todo El Mundo!
# Saving: Abandoned!
# Saving: Time for bed?
# Saving: Little Bo-Peep
# Saving: Monster's Lunch Box.
# Saving: Ken's Kitten.
# Saving: Meg's Monkey.
# Saving: Como crecen los gatitos
# Saving: More bugs in boxes
# Saving: Who's In The Sea?
# Saving: Al acuario
# Saving: The wide-mouthed frog
# Saving: My aunt came back.
# Saving: Skater stuntboys.
# Saving: Scare the moon.
# Saving: Who's hatching?
# Saving: Baby Says
# Saving: When the wild pirates go sailing.
# Saving: Story of the pilgrims
# Saving: I love my daddy because ...
# Saving: Show business is murder.
# Saving: The little engine that could and the snowy, blowy Christmas
# Saving: Where's my dreidel?
# Saving: Look who's talking! at the zoo.
# Saving: Jingle jokes
# Saving: Other wise man
# Saving: World of sports: winter sports.
# Saving: Happy Easter, Emily
# Saving: Slocum and the crooked sheriff.
# Saving: La sorpresa de Nandi
# Saving: Just like dad
# Saving: Sonny's beloved boots
# Saving: Story of Christmas
# Saving: Touch and feel wild animals.
# Saving: We love preschool.
# Saving: What can you do in the snow?
# Saving: Nuclear winter man.
# Saving: Baby animals.
# Saving: Jingle babies.
# Saving: Blue blood.
# Saving: Signet book of short plays.
# Saving: Traves del tiempo.
# Saving: The Greek News.
# Saving: Un fantasma con asma.
# Saving: Tap the tambourine!
# Saving: Bingo
# Saving: Says who?
# Saving: Las palabras que se lleva el viento.
# Saving: Yo puedo ayudar!
# Saving: Christmas Penguin.
# Saving: My fair lady; a musical play in two acts
# Saving: Berenstain bears catch the bus
# Saving: Sing praise : hymnal for the deaf.
# Saving: Saving Louisa.
# Saving: Alyx
# Saving: How to get rich.
# Saving: The Lincoln reader
# Saving: Curious George catches a train
# Saving: Lone star : a comedy in one act
# Saving: The mountains have come closer
# Saving: A genealogical handbook of German research
# Saving: Silent night.
# Saving: A portrait of the Irish in America
# Saving: The Jewish book of why
# Saving: Busy buzzing bumblebees and other tongue twisters
# Saving: I want to paint my bathroom blue
# Saving: Politics and the novel
# Saving: The miracle : a novel
# Saving: The Queen's sister
# Saving: 84, Charing Cross Road
# Saving: The Louisville & Nashville Railroad, 1850-1963
# Saving: Taps for Private Tussie.
# Saving: Mousekin's Christmas Eve.
# Saving: The refugees of 1776 from Long Island to Connecticut
# Saving: A modern comedy
# Saving: Ernest Renan
# Saving: Henner's Lydia
# Saving: The young unicorns.
# Saving: Indian and Eskimo artifacts of North America
# Saving: Collected stories.
# Saving: Gilbert and Sullivan : lost chords and discords
# Saving: Autumn harvest
# Saving: The dead bird.
# Saving: Kentucky governors
# Saving: Jesse Stuart's Kentucky.
# Saving: Glass of the world
# Saving: When Hitler stole pink rabbit
# Saving: The cocktail party : a comedy.
# Saving: Jefferson and his time.
# Saving: The adaptive corporation
# Saving: Studies in Jewish thought
# Saving: The convenient marriage
# Saving: The becomers
# Saving: Thornton Wilder.
# Saving: Re Joyce
# Saving: Black rage
# Saving: The World Book dictionary.
# Saving: I never walked alone
# Saving: Radio's "Kentucky mountain boy" Bradley Kincaid
# Saving: Bronzes : sculptors & founders, 1800-1930
# Saving: The history of world sculpture.
# Saving: Emily Dickinson : a collection of critical essays.
# Saving: Cicero and his influence
# Saving: Distinguished women writers
# Saving: Hagia Sophia
# Saving: Tell it like it is
# Saving: Come, go with me
# Saving: Watteau
# Saving: The existential pleasures of engineering
# Saving: Gallipoli
# Saving: Degas/Lautrec
# Saving: Finishing touches
# Saving: Weatherproofing
# Saving: Literature : an introduction to fiction, poetry, and drama
# Saving: The navigator.
# Saving: The outdoor cookbook.
# Saving: Our family
# Saving: The Partisan Rangers of the Confederate States Army
# Saving: Robert Dale Owen's travel journal, 1827
# Saving: The road
# Saving: History of United States naval operations in World War II.Saving: 1850 federal census, Mercer County, Kentucky
#
# Saving: 1850 federal census, Washington County, Kentucky
# Saving: Myths of life & death
# Saving: Letters to an American lady
# Saving: Confederate wizards of the saddle : being reminiscences and observations of one who rode with Morgan
# Saving: Turner
# Saving: Metamorphoses
# Saving: The plays of Oscar Wilde.
# Saving: Buckdancer's choice
# Saving: Incarnations : poems, 1966-1968.
# Saving: Songs of the theater
# Saving: Scott Joplin and the ragtime era
# Saving: Jean-Jacques Rousseau
# Saving: Carson McCullers.
# Saving: Thornton Wilder
# Saving: Dutch reader
# Saving: Hornblower goes to sea
# Saving: The high and the mighty.
# Saving: Strange mysteries of the sea
# Saving: The morning of the poem : poems
# Saving: Oriental rugs
# Saving: Books and collectors
# Saving: The three sisters
# Saving: If it had happened otherwise
# Saving: Relearning the alphabet.
# Saving: Killing with kindness
# Saving: The end of summer
# Saving: Culture and the Nigerian novel
# Saving: Cantonese; basic course
# Saving: What I'm going to do, I think
# Saving: Ernst Barlach
# Saving: The world of Gainsborough, 1727-1788
# Saving: Come, tell me how you live
# Saving: Golfing for cats
# Saving: In defense of women
# Saving: John Sloan
# Saving: Madselin
# Saving: Collected poems, 1943-1976
# Saving: Shakespeare: the histories; a collection of critical essays
# Saving: Stranger from the Tonto
# Saving: Jim Dine
# Saving: Manhood of humanity
# Saving: A joyful noise.
# Saving: In the hope of nibbana : an essay on Theravada Buddhist ethics
# Saving: The origins of angling
# Saving: Ammie, come home
# Saving: Giovanni Pisano, sculptor
# Saving: Toulouse-Lautrec : drawings
# Saving: The works of Christopher Marlowe
# Saving: Jefferson in power : the death struggle of the Federalists
# Saving: End of the chapter.
# Saving: The home book of Bible quotations
# Saving: The politics of unreason : right wing extremism in America, 1790-1970
# Saving: Modern Switzerland
# Saving: Directory of family research
# Saving: The fugitive trail
# Saving: Kensington
# Saving: The cabin faced west
# Saving: Plenty
# Saving: A life : a play
# Saving: Porcelain
# Saving: English antique furniture, 1450-1850
# Saving: The jewel of the Nile
# Saving: Code of the West
# Saving: Order
# Saving: Macmillan dictionary for children
# Saving: The dossier
# Saving: Eight tales
# Saving: The Black West
# Saving: Holy the firm
# Saving: Heritage dances of early America
# Saving: Virginia genealogies
# Saving: Philosophic classics.
# Saving: Georges Rouault
# Saving: The English squire and his sport
# Saving: Life on a little-known planet.
# Saving: Liberalism
# Saving: The birds of Seychelles and the outlying islands
# Saving: Classical sculpture
# Saving: Annals of Floyd County, Kentucky, 1800-1826
# Saving: The living sea.
# Saving: Occupied country
# Saving: Technology in the ancient world.
# Saving: Wallace Stevens : a collection of critical essays
# Saving: Tower of London
# Saving: Family associations, societies, and reunions : a comprehensive listing
# Saving: Pioneer ancestors of members of the Society of Indiana Pioneers
# Saving: History of Bourbon, Scott, Harrison, and Nicholas counties, Kentucky
# Saving: Thomas Mann : a collection of critical essays
# Saving: An open book
# Saving: International encyclopedia of violin-keyboard sonatas and composer biographies
# Saving: Encyclopedia of local history and genealogy, series 1
# Saving: O. Henry in North Carolina.
# Saving: In my father's court.
# Saving: The Sun King.
# Saving: An introduction to poetry
# Saving: Ambulance
# Saving: Oman: a history
# Saving: Dictionary of biographical reference
# Saving: Uncle Whiskers
# Saving: George S. Kaufman : an intimate portrait
# Saving: Walden, and other writings of Henry David Thoreau
# Saving: Thomas Hill and Rebecca Miles : ancestors and descendants
# Saving: The opera reader.
# Saving: An explanation of America
# Saving: The eco-spasm report
# Saving: Miss Bianca in the Orient
# Saving: Norman Mailer
# Saving: The workhouse
# Saving: Mr. Lincoln's Army
# Saving: African stories
# Saving: Poems, 1957-1967
# Saving: Passion
# Saving: Abe Lincoln in Illinois
# Saving: On reading
# Saving: The right stuff
# Saving: The southern side; or, Andersonville Prison.
# Saving: 21 stories.
# Saving: The complete plays of Gilbert and Sullivan.
# Saving: Three lives for Mississippi
# Saving: The battle of the Atlantic
# Saving: The collected drawings of Aubrey Beardsley.
# Saving: Rubaiyat of Omar Khayyam
# Saving: Art treasures of Eastern Europe
# Saving: Bernard Malamud
# Saving: Lewis & Clark, partners in discovery.
# Saving: Men at work
# Saving: The power of movement in plants.
# Saving: Ezra Pound : a close-up.
# Saving: Applause.
# Saving: Geology illustrated
# Saving: The Americans : the national experience
# Saving: Detroit, I do mind dying : a study in urban revolution
# Saving: Subject to change
# Saving: Handbook of mathematical functions with formulas, graphs, and mathematical tables
# Saving: Louis C. Tiffany, rebel in glass.
# Saving: Wild flowers
# Saving: Bellini
# Saving: The green wall
# Saving: Beyond sanctuary
# Saving: Drowning with others : poems
# Saving: Querelle
# Saving: Literary impressionism
# Saving: The Chatto book of modern poetry, 1915-1955
# Saving: Reading myself and others
# Saving: Frontier Kentucky
# Saving: Mozart.
# Saving: Census of Indiana Territory for 1807.
# Saving: Banana Bottom
# Saving: Masters of French painting, 1850-1950, with a selection of old masters.
# Saving: The world of ancient Israel.
# Saving: Whose life is it anyway?
# Saving: Prayers.
# Saving: Knowing your trees
# Saving: Hirschfeld
# Saving: Life in ancient Athens : the social and public life of a classical Athenian from day to day
# Saving: The family, sex and marriage in England : 1500-1800
# Saving: Man in prehistory
# Saving: General history of the things of New Spain
# Saving: The Indians of Connecticut
# Saving: China clipper
# Saving: Alfred de Vigny
# Saving: Song of the wind
# Saving: Wallpaper
# Saving: Rebellion or revolution?
# Saving: Stevens' poetry of thought
# Saving: New York head shop and museum
# Saving: France and Belgium, 1939-1940
# Saving: Denise Levertov
# Saving: The Turkish theatre
# Saving: Dynamo
# Saving: The nature of thermodynamics
# Saving: The theory of money and credit
# Saving: Essays on language and literature
# Saving: A tear and a smile
# Saving: The sound of mountain water
# Saving: Jacques Lipchitz: sketches in bronze
# Saving: Legends of our time
# Saving: All that glitters
# Saving: A calendar of Delaware wills, New Castle County, 1682-1800
# Saving: The sorrow dance
# Saving: Thoughts in solitude.
# Saving: Concise dictionary of American literature
# Saving: The American Indian
# Saving: Songs from Trinidad
# Saving: American Indian policy
# Saving: The intellectual design of John Dryden's heroic plays
# Saving: Early Kentucky
# Saving: Cold-blooded vertebrates: part I. Fishes
# Saving: A vision
# Saving: North America
# Saving: Twice brightly
# Saving: The techniques of working with the working press
# Saving: Great Britain and the American Civil War
# Saving: The unknown Chekhov : stories and other writings
# Saving: Lies
# Saving: The oblivion seekers, & other writings
# Saving: Strictly dishonorable and other lost American plays
# Saving: Broadway scrapbook
# Saving: Virginia 1840
# Saving: Russian-German settlements in the United States
# Saving: Holmes & Watson : a miscellany
# Saving: The man-made world; or, Our androcentric culture
# Saving: The merchant bankers
# Saving: Robert Frost, a biography
# Saving: The flowers of evil
# Saving: Alone together
# Saving: Pravda
# Saving: Walden
# Saving: Just lucky, I guess.
# Saving: Twenty poems
# Saving: The Mexican War.
# Saving: Montale and Dante
# Saving: Early Virginia
# Saving: My life
# Saving: The Vinland map : and the Tartar relation
# Saving: The high hills
# Saving: Three comedies
# Saving: Great inventions
# Saving: Jewelry
# Saving: Illinois 1850 census index
# Saving: The story of King Arthur and his knights
# Saving: The age of George III
# Saving: Helmets : poems
# Saving: The royal secret
# Saving: The 1826 journal of John James Audubon
# Saving: The confidential agent, an entertainment
# Saving: Early Missouri
# Saving: Glass
# Saving: Washington County, Kentucky, cemeteries
# Saving: Dante
# Saving: Renaissance in the north
# Saving: The poetry of Greek tragedy
# Saving: Songs of innocence and of experience, shewing the two contrary states of the human soul, 1789-1794
# Saving: To teach, to love
# Saving: Elements of chordate anatomy
# Saving: American AFVs of World War II
# Saving: The art of Paul Verlaine
# Saving: A history of technology & invention : progress through the ages
# Saving: Handbook of needlepoint stitches
# Saving: Art History Museum, Vienna. Picture Gallery.
# Saving: Studies in Elizabethan drama
# Saving: Four comedies.
# Saving: The Acts of the Apostles
# Saving: Tristan und Isolde : opera in three acts
# Saving: Der Rosenkavalier : (the rose-bearer) : comedy for music in three acts : op. 59
# Saving: National Gallery, London.
# Saving: Teenage depression and suicide
# Saving: Tracks
# Saving: 150 masterpieces of drawing.
# Saving: Uffizi, Florence
# Saving: It's easy to fix your bike
# Saving: Jefferson Davis, president of the South
# Saving: Judge tenderly of me : the poems of Emily Dickinson
# Saving: Fear by night
# Saving: Woman in science: with an introductory chapter on woman's long struggle for things of the mind
# Saving: Demon lord of Karanda
# Saving: Confederate engineers.
# Saving: You could look it up
# Saving: German drawings, from the 16th century to the expressionists
# Saving: Cave to Renaissance
# Saving: Marvellous Méliès
# Saving: Winds of evil
# Saving: The voices of silence
# Saving: Local light : photographs made in Kentucky
# Saving: The case of the silent partner
# Saving: 20th century drawings.
# Saving: Women and the revolution ?
# Saving: A shayna maidel
# Saving: America's fabrics; origin and history, manufacture, characteristics, and uses
# Saving: The bright-tobacco industry, 1860-1929.
# Saving: Topographical description of the western territory of North America
# Saving: The seventeenth-century background : studies in the thought of the age in relation to poetry and religion.
# Saving: "Sold American!" The first fifty years.
# Saving: Silver
# Saving: History of the national flag of the United States of America
# Saving: Transcaucasia : nationalism and social change : essays in the history of Armenia, Azerbaijan, and Georgia
# Saving: The Oxford dictionary of nursery rhymes
# Saving: Ghost railroads of Kentucky
# Saving: The shepherd of the ocean : an account of Sir Walter Ralegh and his times
# Saving: Maurice Ravel
# Saving: The beggar's opera : to which is added the music to each song
# Saving: A bibliography of William Dean Howells
# Saving: The A.B. Frost book
# Saving: Dámaso Alonso
# Saving: The literary manuscripts of Hart Crane
# Saving: That reminds me
# Saving: The journal of Eugène Delacroix
# Saving: Hummingbirds
# Saving: Impounded people : Japanese-Americans in the relocation centers
# Saving: Military architecture
# Saving: How to arrange flowers for all occasions
# Saving: Impact
# Saving: Out of Kentucky kitchens
# Saving: Lucio Fontana
# Saving: Lanterns & Lances
# Saving: Week-end painter.
# Saving: The human comedy
# Saving: Surrealism and the novel
# Saving: Antonio Buero Vallejo
# Saving: Carmen : opera in four acts
# Saving: The big book of knitting
# Saving: Pills, petticoats, and plows; the Southern country store
# Saving: Emilia Pardo Bazán
# Saving: Selected poetry and prose.
# Saving: History of a literary radical and other essays.
# Saving: Vegetables
# Saving: Shirley Valentine and One for the road
# Saving: The Oregon Trail
# Saving: Blackthink; my life as black man and white man
# Saving: Kentucky, a history of the state, embracing a concise account of the origin and development of the Virginia colony ...
# Saving: The Piltdown men
# Saving: History of Italian literature.
# Saving: The Army and economic mobilization
# Saving: Status and conformity
# Saving: Bad boy of music
# Saving: Old Creole days
# Saving: Visit to a small planet.
# Saving: Extra credits
# Saving: Man Ray
# Saving: Renoir.
# Saving: Time remembered
# Saving: A hole in the head.
# Saving: Gigi
# Saving: Auntie Mame
# Saving: The lark
# Saving: Castleview
# Saving: The cocktail hour
# Saving: Balakirev : a critical study of his life and music.
# Saving: The Russian artist; the creative person in Russian culture.
# Saving: Americans from Germany
# Saving: Pills, petticoats, and plows; the Southern country store.
# Saving: Great experiments in psychology.
# Saving: Negroes and medicine.
# Saving: Dear garbage man
# Saving: Kurt Vonnegut, Jr. ..., a checklist
# Saving: Michelangelo
# Saving: First season.
# Saving: The railroaders.
# Saving: Les dieux ont soif
# Saving: Death of a busybody
# Saving: A century of population growth, from the first census of the United States to the twelfth, 1790-1900.
# Saving: Sappho
# Saving: Jerusalem
# Saving: Herbaceous perennial plants : a treatise on their identification, culture, and garden attributes
# Saving: Children as individuals
# Saving: A checklist of the Hogarth Press, 1917-1938
# Saving: McGuffey's Eclectic spelling-book.
# Saving: Dawn of the gods
# Saving: Sweet talk
# Saving: The Sierra Madre
# Saving: Water in Kentucky
# Saving: The loggers
# Saving: Sagebrush country
# Saving: Caribbean isles
# Saving: The Alaskans
# Saving: The colonial craftsman
# Saving: The Spanish West
# Saving: The Canadians
# Saving: The great chiefs
# Saving: Some Americans abroad
# Saving: An awfully big adventure
# Saving: Baja California
# Saving: The chroniclers
# Saving: The route of the Three Notch'd Road : a preliminary report
# Saving: Technology in Western civilization.
# Saving: Investigation of the assassination of President John F. Kennedy : hearings before the Select Committee on Assassinations of the U.S. House of Representatives, Ninety-fifth Congress, second session.
# Saving: Investigation of the assassination of President John F. Kennedy : hearings before the President's Commission on the Assassination of President Kennedy.
# Saving: A hero of our time
# Saving: Pistols of the world
# ...
# Saving: American Negro slavery : a survey of the supply, employment and control of Negro labor as determined by the plantation régime
# Saving: History of the antislavery measures of the Thirty-seventh and Thirty-eighth United-States Congresses, 1861-64.
# Saving: Secrets of Russian cooking
# Saving: A little treasury of American poetry : the chief poets from colonial times to the present day
# Saving: A certain crossroad
# Saving: A poetry anthology
# Saving: Washington County 1920 census
# Saving: The church and slavery.
# Saving: A sailor's story
# Saving: Stalin and the Kirov murder
# Saving: The garden of dreams
# Saving: Secrets in the sand
# Saving: Rally 'round the flag
# Saving: Autumn tales
# Saving: The start of something big
# Saving: A mysterious history
# Saving: Mystery at the Inn
# Saving: New poems
# Saving: A long way home
# Saving: Out of the ashes
# Saving: Birds of a feather
# Saving: The unsuitable suitor
# Saving: Whispers through the trees
# Saving: The battle of al-Khafji
# Saving: Eastern Cherokee by blood, 1906-1910
# Saving: Saraband for two sisters
# Saving: Glenn Brown's History of the United States Capitol
# Saving: What is a thing?
# Saving: Censored : the news that didn't make the news--and why.
# Saving: Collecting Georgian and Victorian crafts.
# Saving: English domestic metalwork
# Saving: Rob
# Saving: The go-away bird : and other stories.
# Saving: Enforcing religious freedom in prison.
# Saving: The garden of the prophet
# Saving: The time of the trolley
# Saving: En el país del sol
# Saving: The watch repairer's manual.
# Saving: Enterprise, the first adventure
# Saving: Inventions of the Middle Ages
# Saving: Ghost walker
# Saving: The blues line; a collection of blues lyrics.
# Saving: South Fork Country
# Saving: The phantom of the Opera
# Saving: Southern road : poems
# Saving: As a peace-loving global citizen
# Saving: Jacob Lawrence
# Saving: Tragedies
# Saving: Story and verse for children
# Saving: Field artillery
# Saving: The Chemical Warfare Service : from laboratory to field
# Saving: Mel Bay's Fun with the banjo
# Saving: Engineers at war
# Saving: Victorian poetry
# Saving: Response
# Saving: The nature of science, and other lectures.
# Saving: Strength in numbers
# Saving: Farmington.
# Saving: Chasing the wind
# Saving: U. S. Marines in Iraq, 2004-2005 : into the fray
# Saving: Regimental losses in the American Civil War, 1861-1865 : a treatise on the extent and nature of the mortuary losses in the Union regiments, with full and exhaustive statistics compiled from the official records on file in the state military bureaus and at
# Saving: al-Manṭiq
# Saving: Reminiscences.
# Saving: The architecture of bridges
# Saving: Octopus
# Saving: Myth and legend in early Greek art.
# Saving: Circle of secrets
# Saving: Daily life in early Canada
# Saving: A pictorial history of the American Indian.
# Saving: Wake of the great sealers
# Saving: Chaplains with Marines in Vietnam, 1962-1971
# Saving: The U.S. Marine Corps Mountain Warfare Training Center, 1951-2001
# Saving: The American musical stage before 1800.
# Saving: Richard Wagner & the synthesis of the arts.
# Saving: Allied participation in Operation Iraqi Freedom
# Saving: The country blues.
# Saving: Choral music of the church
# Saving: Earth shine
# Saving: Poor man's guide to bottle collecting.
# Saving: Der Rosenkavalier = (The rose-bearer) : comedy for music in three acts
# Saving: The magnificence of Eszterháza.
# Saving: The Christmas rose
# Saving: Fashion in the forties
# Saving: Götterdämmerung = (The twilight of the gods)
# Saving: Italian violin makers.
# Saving: The history of the English puppet theatre.
# Saving: The story of the Original Dixieland Jazz Band.
# Saving: Cross-Channel attack
# Saving: The King's peace, 1637-1641
# Saving: The painted Romanesque ceiling of St. Martin in Zillis.
# Saving: The gesture language of the Hindu dance
# Saving: Magic moments
# Saving: A history of American acting
# Saving: New Voices Young Playwrights Festival
# Saving: World steam locomotives
# Saving: The man of property
# Saving: Wild pomegranate
# Saving: Northern cardinal
# Saving: Still Crazy
# Saving: Beast master team
# Saving: The Ziz and the Hanukkah Miracle
# Saving: I believe
# Saving: Pixie dust
# Saving: Cherry Hill
# Saving: Serendipity
# Saving: Vida de una geisha
# Saving: Virtues
# Saving: Memories of the 1940's
# Saving: Árboles de globos
# Saving: Dictionary of Medical Terms
# Saving: Oldham County, KY deed book C, 1832-1836
# Saving: Fundevogel Märchen
# Saving: History of the Haitian flag of independence
# Saving: The Karen.
# Saving: The prime of life
# Saving: Brahms orchestral music.
# Saving: The Origins of bowing and the development of bowed instruments up to the thirteenth century
# Saving: the journal of Jedediah Barstow
# Saving: Spanish drawings from the 10th to the 19th century
# Saving: We shall have music.
# Saving: Batouala
# Saving: Schubert songs
# Saving: Tristana.
# Saving: A children's book about being lazy
# Saving: A children's book about cheating
# Saving: The Trojan women.
# Saving: Le faiseur d'or
# Saving: The Pentagon reporters
# Saving: Up from handymen
# Saving: Confidence in battle, inspiration in peace
# Saving: Poulet aux amendes
# Saving: Struggling for recognition
# Saving: The best and worst of times
# Saving: Louisville sites to see by design
# Saving: Report of the congressional committees investigating the Iran-Contra Affair : with supplemental, minority, and additional views.
# Saving: The Alington inheritance
# Saving: None but the lonely heart.
# Saving: The glass virgin.
# Saving: Elle the Thumbelina Fairy
# Saving: PAUL MOVES OUT
# Saving: Curious George
# Saving: Marks of Genius
# Saving: Dearly departed
# Saving: The way of all flesh
# Saving: Dad by My Side
# Saving: Understanding the fundamentals of music
# Saving: The U.S. Army GHQ maneuvers of 1941
# Saving: Star trek / The last Roundup
# Saving: Leonardo da Vinci.
# Saving: Trail design, construction, and maintenance
# Saving: National Museum of the United States Air Force : aircraft brochure.
# Saving: Sheikh's Princess of Convenience
# Saving: Original Fire
# Saving: From the Volturno to the winter line, 6 October - 15 November 1943.
# Saving: THe innocent mage
# Saving: St. Mihiel 12-16 September 1918
# Saving: Wa-adraka Shahrazād . al-malal
# Saving: Different Bodies Different Diet
# Saving: Nerd do well
# Saving: The awakened mage
# Saving: A NURSE'S STORY AND OTHERS
# Saving: Night train to Memphis
# Saving: The emperor wears no clothes
# Saving: Slay Ride
# Saving: Let's Go to the Park
# Saving: Big Nate on a Roll
# Saving: A Wyoming Christmas to Remember
# Saving: Maiden voyage: fourteen easy-to play jazz tunes
# Saving: PIPE DREAM
# Saving: Squeak squeak
# Saving: SMALL WONDER
# Saving: Supporting allied offensives 8 August-11 November 1918
# Saving: Textbooks and instructional materials
# Saving: Ghosts! of Pennsylvania : Volume II
# Saving: Acadia: the complete guide
# Saving: Conversations With Nature : Oil Painting in the Tradition of Plein Air
# Saving: Grumpy Cat No-It-All
# Saving: Love's encore
# Saving: marked in flesh
# Saving: Jesse Livermore: Boy Plunger
# Saving: Another's treasure
# Saving: Sugar coated lies
# Saving: Trouble brewing
# Saving: Binding vows
# Saving: A flame in the night
# Saving: Never the twain shall meet
# Saving: Thicker than water
# Saving: Don't rock the boat
# Saving: Making waves
# Saving: Greater than gold
# Saving: The Everlasting Stream
# Saving: Disney Nutcracker Four Realms
# Saving: Safe harbor
# Saving: embrace me at dawn
# Saving: Second edition death
# Saving: All that remains
# Saving: The Ferguson rifle
# Saving: The Cambridge Companion to Malcolm X
# Saving: Swept away
# Saving: Harvest of youth.
# Saving: Exit, stage left
# Saving: The black hero
# Saving: one secret thing
# Saving: Jar of fools
# Saving: Anna & Eva
# Saving: HOLIDAY DEFENDERS
# Saving: Double happiness
# Saving: Christopher's Diary: Secrets of Foxworth
# Saving: Blueprints of Fashion
# Saving: Kamikaze. Volume 2
# Saving: Race Around the World
# Saving: United States code, 2018 edition.
# Saving: Time of hope.
# Saving: The Glory of Grace
# Saving: enemy unseen
# Saving: Water reuse and recycling
# Saving: Holiday Inn
# Saving: The More You Do the Better You Feel
# Saving: Squared away
# Saving: Gathering Moss
# Saving: The population challenge.
# Saving: Yesterday's secrets
# Saving: Tea Rose
# Saving: Time to share
# Saving: Burning secrets
# Saving: Bound in love
# Saving: Harlem Godfather
# Saving: Site planning and design handbook
# Saving: Forget-me-nots
# Saving: At face value
# Saving: To a tea
# Saving: The Memory Box
# Saving: Literature and film as modern mythology
# Saving: William Shakespeare's The Winter's Tale
# Saving: River of life
# Saving: Ambush in the Ashes
# Saving: It's not summer without you
# Saving: Saga, book 3
# Saving: School safety program
# Saving: A Jesse Stuart reader : stories and poems
# Saving: The Encircling Sea
# Saving: Final Vinyl Days and other stories
# Saving: Kindergarten Cat
# Saving: Discover dinosaurs.
# Saving: Den of Lions
# Saving: The makers of modern geography
# Saving: Animal alphabet
# Saving: Black Education
# Saving: Campaign book of facts.
# Saving: ¡Todos contamos!
# Saving: Everyone counts!
# Saving: Đấu trường sinh tử
# Saving: Thi tap
# Saving: Epitaphs from the old burying ground in Groton, Massachusetts.
# Saving: The Peters Colony of Texas
# Saving: Everlasting Quilts
# Saving: Minutes of the Provincial Council of Pennsylvania : from the organization to the termination of the proprietary government. [Mar. 10, 1683-Sept. 27, 1775].
# Saving: Pistols and Politics
# Saving: The visitations of the county of Sussex
# Saving: Irish pedigrees, or, The origin and stem of the Irish nation
# Saving: The Cecil family
# Saving: Free Black heads of households in the New York state federal census, 1790-1830
# Saving: Carpenter and allied families : genealogical and biographical
# Saving: Personal names in Hening's Statutes at large of Virginia, and Shepherd's continuation.
# Saving: The Cavendish family
# Saving: Packets
# Saving: Wild Animals Atlas
# Saving: Ryoanji : poems
# Saving: Genealogy of the Spotswood family in Scotland and Virginia
# Saving: English poetry : a short history.
# Saving: Crucified with Christ.
# Saving: The case of the cautious coquette ; The case of the crimson kiss ; The case of the crying swallow
# Saving: More work for the undertaker.
# Saving: Other Americas
# Saving: Collected verse.
# Saving: Voyages : poems
# Saving: The highly suspicious halo
# Saving: Cottage garden
# Saving: Jutland Cottage.
# Saving: Hornblower and the Atropos.
# Saving: The Manchurian candidate
# Saving: Memoirs of a midget.
# Saving: Ice Palace
# Saving: Puck of Pook's Hill
# Saving: Stages to Saturn : a technological history of the Apollo/Saturn launch vehicles
# Saving: Skylab : a chronology
# Saving: The Apollo spacecraft : a chronology.
# Saving: On the shoulders of Titans : a history of Project Gemini
# Saving: Westward ho!
# Saving: Vanguard : a history
# Saving: Ten years later.
# Saving: Twenty years after
# Saving: Snow Happy to be Here.
# Saving: Tagebücher, 1910-1923
# Saving: A Clinical Introduction to Lacanian Psychoanalysis
# Saving: Treaties and other international agreements of the United States of America, 1776-1949
# Saving: God, Mystery & Mystification
# Saving: A Kentucky cardinal & Aftermath
# Saving: The Garrick Year
# Saving: Irvin S. Cobb; his life and achievements
# Saving: Middlemarch
# Saving: Healing oils of the Bible
# Saving: Finding Perfect
# Saving: The House by the Sea
# Saving: A Comrade Lost and Found
# Saving: Betrayal
# Saving: Making Tough Decisions about End-of-Life Care in Dementia
# Saving: Eternity in Their Hearts
# Saving: Can't We Talk About Something More Pleasant?
# Saving: Speculation as a Fine Art and Thoughts on Life
# Saving: Aristotle's Politics
# Saving: christmas with southern living
# Saving: Shoot Don't Shoot
# Saving: LAST STAND RANCH
# Saving: [Un]common ground
# Saving: RACE CARS UP CLOSE
# Saving: el Dragon Simon
# Saving: The Quail Lady's Guide to Raising Coturnix on the Homestead
# Saving: the closing of the western mind
# Saving: The Last Place on Earth
# Saving: THE CLAIMING OF SLEEPING BEAUTY
# Saving: Psychology Basics
# Saving: Bitter Sweets
# Saving: Junie B Jones Loves Handsome Warren
# Saving: The Enemy Within
# Saving: The Mysterious Case of Nancy Drew and the Hardy Boys
# Saving: Motivational Interviewing
# Saving: READERS DIGEST
# Saving: Home Before Daylight
# Saving: Treaties and other international agreements of the United States of America
# Saving: the best of the appalachian trail day hikes
# Saving: CHOPPING SPREE
# Saving: English historical documents
# Saving: The Nazi Olympics, Berlin, 1936.
# Saving: Born in Ice
# Saving: We Set the Dark on Fire
# Saving: Statistics DeMystified
# Saving: So Far Away
# Saving: Moments in history
# Saving: Havana Blue
# Saving: Heavy Metal Movies
# Saving: why do the seasons change?
# Saving: Inquebrantables
# Saving: the cowboy's housekeeper
# Saving: rainmaker
# Saving: Chemistry for Every Kid
# Saving: #murdertrending
# Saving: Recollections of Lewis Bonnett, Jr.
# Saving: From bad to worse
# Saving: In the Rainforest
# Saving: Homosexuals.
# Saving: death do us part
# Saving: Feather on the Moon
# Saving: SHOOTING VIDEO TO MAKE LEARNING FUN
# Saving: TEXAS DADDY
# Saving: NYC Vegan
# Saving: MUSIC SHOP
# Saving: A Fighter Pilot in Buchenwald
# Saving: the once and future forest
# Saving: AP U.S. Government and Politics Crash Course: For the 2020 Exam
# Saving: Earth Science
# Saving: AN ABSOLUTELY REMARKABLE THING
# Saving: Jesus Calling
# Saving: HANDMADE ELECTRONIC MUSIC
# Saving: GOOD OMENS
# Saving: Creepy Things Are Scaring Me
# Saving: This Little Piggy
# Saving: The Audubon  Society Field Guide to North American Seashells
# Saving: The Candidate
# Saving: Higher Probability Commodity Trading
# Saving: The Beverly Hills Diet
# Saving: Pure Dead Wicked
# Saving: Italian Children's Literature and National Identity
# Saving: 28 Summers
# Saving: RAINBOW WEAVER
# Saving: WATERCOLOR BASICS PEOPLE
# Saving: The Target
# Saving: The Myth of American Diplomacy
# Saving: How to be a Good Girl
# Saving: Space Cows
# Saving: Theory of Religious Cycles
# Saving: Samantha Sanderson at the Movies
# Saving: The Sky People
# Saving: Samantha Sanderson on the Scene
# Saving: The Collected Poems of Audre Lorde
# Saving: Star Wars, Jedi Apprentice : The Rising Force
# Saving: Grumpy Mom Takes a Holiday
# Saving: Skinnamarink
# Saving: HITTING THE BOOKS
# Saving: Chancellorsville and the Germans nativism, ethnicity, and Civil War memory
# Saving: COWBOY AT ARMS
# Saving: RED VELVET CUPCAKE MURDER
# Saving: Diary of a Professional Commodity Trader
# Saving: Truly Devious
# Saving: IN HIS FATHER'S FOOTSTEPS
# Saving: Rich Dad, Poor Dad
# Saving: The Rest of the Story
# Saving: Deep Waters
# Saving: Spring Peeps!
# Saving: Look at me
# Saving: Tudor Roses
# Saving: Hot Commodities
# Saving: Restoration
# Saving: HEROES
# Saving: SNOWFALL AT WILLOW LAKE
# Saving: PSYCHOLOGY TODAY
# Saving: BAD BOYS GET HENPECKED
# Saving: Must Love Dogs
# Saving: Under Fire
# Saving: Living With the Dead
# Saving: Tu Zonas Erroneas
# Saving: GREAT AFRICAN FILMS
# Saving: Jesus on Mars
# Saving: 13 photos children should know
# Saving: The Khipu and the Final Key
# Saving: INFIDEL
# Saving: Street Smarts
# Saving: Winter Cottage
# Saving: MOMMY'S DISEASE
# Saving: test
# Saving: WAR OF EAGLES
# Saving: Economist
# Saving: Persons, Animals, Ourselves
# Saving: Only Apparently Real
# Saving: The New Mencken Letters
# Saving: the girl in the road
# Saving: See Night Run
# Saving: Sharp Edges
# Saving: Tin
# Saving: Eye of the Beholder
#                                                      Title           ISBN
# 4429     Stolen legacy: the Egyptian origins of western...           None
# 5336     A symposium in public librarianship; three add...           None
# 5510                        WWI : the Great War, 1914-1918           None
# 5511                                        LANKIE MANTITA           None
# 5931                                          My First Pet     9354401066
# ...                                                    ...            ...
# 1181091      Cognitive Mapping : Past, Present, and Future           None
# 1181093                                Eye of the Beholder     0671523066
# 1181101                                        Sharp Edges  9780671524098
# 1181291                               the girl in the road     0804138842
# 1181292                                      See Night Run     1930859171
#
# [28327 rows x 2 columns]

# %%
temp_df['ISBN'].isna().value_counts()
# Out:
# ISBN
# True     21245
# False     7082
# Name: count, dtype: int64

# %%
temp_df[temp_df['ISBN'].notna()]
# Out:
#                                Title           ISBN
# 5931                    My First Pet     9354401066
# 6383     O little town of Sugarcreek     1961125498
# 6405                      Act of War  9780451466198
# 6417            The Christmas riddle  9798586294586
# 6434              Castle of whispers  9781609451929
# ...                              ...            ...
# 1181089      The New Mencken Letters  9780803713796
# 1181093          Eye of the Beholder     0671523066
# 1181101                  Sharp Edges  9780671524098
# 1181291         the girl in the road     0804138842
# 1181292                See Night Run     1930859171
#
# [7082 rows x 2 columns]

# %%
# We found 7082 ISBN's using this API
# Merge the result with the original dataframe using the title column
# Merge the two dataframes using the title column
merged_df = lfpl_books.merge(temp_df, on='Title', how='left')
merged_df
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1        1341361           McGraw-Hill's American idioms dictionary
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3        1341362  McGraw-Hill's essential ESL grammar : a handbo...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1181239  2527332     The afrominimalist's guide to living with less
# 1181240  2527332     The afrominimalist's guide to living with less
# 1181241  2527332     The afrominimalist's guide to living with less
# 1181242  2527332     The afrominimalist's guide to living with less
# 1181243  2520634  Abstract painting : the elements of visual lan...
#
#                             Author         ISBN_x  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878             2009     Book
# 1               Spears, Richard A.  9780071478939             2007     Book
# 2             Miller, Robin, 1964-  9780307451408             2009     Book
# 3                    Lester, Mark.  9780071496421             2008     Book
# 4             Miller, Robin, 1964-  9780307451408             2009     Book
# ...                            ...            ...              ...      ...
# 1181239           Platt, Christine  9781982168056             2022     Book
# 1181240           Platt, Christine  9781982168056             2022     Book
# 1181241           Platt, Christine  9781982168056             2022     Book
# 1181242           Platt, Christine  9781982168056             2022     Book
# 1181243  Davies, Jane (Ceramicist)  9780692619803             2017     Book
#
#             ItemCollection             ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                     Main      25.95
# 1           ELL Collection            South Central      20.00
# 2        Adult Non-Fiction                Southwest      19.99
# 3           ELL Collection            South Central      20.00
# 4        Adult Non-Fiction                Southwest      19.99
# ...                    ...                      ...        ...
# 1181239  Adult Non-Fiction                     Main      10.02
# 1181240  Adult Non-Fiction                  Newburg      10.02
# 1181241  Adult Non-Fiction            South Central      10.02
# 1181242  Adult Non-Fiction                  Western      10.02
# 1181243  Adult Non-Fiction  Highlands - Shelby Park      24.95
#
#                      ReportDate  ObjectId ISBN_y
# 0        2022/07/01 04:00:00+00         1    NaN
# 1        2022/07/01 04:00:00+00         2    NaN
# 2        2022/07/01 04:00:00+00         3    NaN
# 3        2022/07/01 04:00:00+00         4    NaN
# 4        2022/07/01 04:00:00+00         5    NaN
# ...                         ...       ...    ...
# 1181239  2022/07/01 04:00:00+00   1657551    NaN
# 1181240  2022/07/01 04:00:00+00   1657552    NaN
# 1181241  2022/07/01 04:00:00+00   1657553    NaN
# 1181242  2022/07/01 04:00:00+00   1657554    NaN
# 1181243  2022/07/01 04:00:00+00   1657555    NaN
#
# [1181244 rows x 12 columns]

# %%
lfpl_books[lfpl_books['ISBN']=='nan']
# Out:
#           BibNum                                              Title  \
# 4429     1348353  Stolen legacy: the Egyptian origins of western...
# 5336     1353427  A symposium in public librarianship; three add...
# 5510     1353740                     WWI : the Great War, 1914-1918
# 5511     1353780                                     LANKIE MANTITA
# 5931     2511351                                       My First Pet
# ...          ...                                                ...
# 1181091  2528085      Cognitive Mapping : Past, Present, and Future
# 1181093  2528087                                Eye of the Beholder
# 1181101  2528088                                        Sharp Edges
# 1181291  2527399                               the girl in the road
# 1181292  2527400                                      See Night Run
#
#                                                     Author ISBN  \
# 4429                                    James, George G. M  nan
# 5336     University of California, Berkeley. School of ...  nan
# 5510         Brown, Hilary (Author of Two-liners for kids)  nan
# 5511                                     LESLIE PATRICELLI  nan
# 5931                                                   NaN  nan
# ...                                                    ...  ...
# 1181091                                       Kitchin, Rob  nan
# 1181093                                      Krentz, Jayne  nan
# 1181101                                      Krentz, Jayne  nan
# 1181291                                       MONICA BYRNE  nan
# 1181292                                                NaN  nan
#
#          PublicationYear ItemType     ItemCollection            ItemLocation  \
# 4429                   0     Book  Interlibrary Loan                    Main
# 5336                1952     Book   Kentucky History                    Main
# 5510                2014     Book  Adult Non-Fiction                    Main
# 5511                   0     Book                NaN                 Shively
# 5931                   0     Book                NaN                 Newburg
# ...                  ...      ...                ...                     ...
# 1181091                0     Book  Interlibrary Loan                    Main
# 1181093                0     Book  Interlibrary Loan                    Main
# 1181101                0     Book  Interlibrary Loan                    Main
# 1181291                0     Book                NaN                    Main
# 1181292                0     Book                NaN  Childrens Main Library
#
#          ItemPrice              ReportDate  ObjectId
# 4429           0.0  2022/07/01 04:00:00+00      5055
# 5336          25.0  2022/07/01 04:00:00+00      7761
# 5510          15.0  2022/07/01 04:00:00+00      8010
# 5511           0.0  2022/07/01 04:00:00+00      8027
# 5931           0.0  2022/07/01 04:00:00+00      8588
# ...            ...                     ...       ...
# 1181091        0.0  2022/07/01 04:00:00+00   1657144
# 1181093        0.0  2022/07/01 04:00:00+00   1657147
# 1181101        0.0  2022/07/01 04:00:00+00   1657176
# 1181291        0.0  2022/07/01 04:00:00+00   1657506
# 1181292        0.0  2022/07/01 04:00:00+00   1657507
#
# [36430 rows x 11 columns]

# %%
lfpl_books_1 = lfpl_books.merge(temp_df, on='Title', how='left', suffixes=('', '_temp'))

# %%
lfpl_books_1[lfpl_books_1['ISBN']=='nan'].value_counts()
# Out:
# BibNum   Title                                             Author                                         ISBN  PublicationYear  ItemType  ItemCollection     ItemLocation            ItemPrice  ReportDate              ObjectId  ISBN_temp
# 2313     Roughing it                                       Twain, Mark, 1835-1910.                        nan   1992             Book      Adult Non-Fiction  Jeffersontown           22.95      2022/07/01 04:00:00+00  82652     9798465049788    1
# 476060   The Orangeburg massacre                           Nelson, Jack, 1929 Oct. 11-                    nan   1970             Book      Adult Reference    Western                 55.00      2022/07/01 04:00:00+00  344282    9780865541207    1
# 476294   The Negro in the American Revolution              Aptheker, Herbert, 1915-                       nan   1940             Book      Adult Non-Fiction  Remote Shelving - Main  25.00      2022/07/01 04:00:00+00  344549    9780807838334    1
#                                                                                                                                                               Main                    25.00      2022/07/01 04:00:00+00  344548    9780807838334    1
# 476284   Story of the Negro                                Bontemps, Arna, 1902-1973.                     nan   1948             Book      Adult Reference    Western                 45.00      2022/07/01 04:00:00+00  344491    0812219368       1
#                                                                                                                                                                                                                                                    ..
# 434741   A Scots quair : a trilogy of novels               Mitchell, James Leslie, 1901-1935.             nan   1974             Book      Adult Fiction      Remote Shelving - Main  25.00      2022/07/01 04:00:00+00  319191    9781904598824    1
# 434721   Irish poetry : from the English invasion to 1798  Alspach, Russell K. (Russell King), 1901-1980  nan   1959             Book      Adult Non-Fiction  Crescent Hill           4.00       2022/07/01 04:00:00+00  319125    9781512800166    1
# 434695   Children's treasure box                           Svoboda, Tomas.                                nan   1977             Book      Adult Non-Fiction  Remote Shelving - Main  25.00      2022/07/01 04:00:00+00  319058    0895555646       1
#                                                                                                                                                                                                                          319017    0895555646       1
# 2529351  Theory of Religious Cycles                        Sergeev, Mikhail                               nan   0                Book      Interlibrary Loan  Main                    0.00       2022/07/01 04:00:00+00  1611871   9789004300033    1
# Name: count, Length: 8268, dtype: int64

# %%
# Update the missing values in the isbn column of lfpl_books using the values from temp_df
lfpl_books_1['ISBN'] = lfpl_books_1.apply(lambda row: row['ISBN_temp'] if row['ISBN']=='nan' else row['ISBN'], axis=1)
lfpl_books_1.drop('ISBN_temp', axis=1, inplace=True)

# %%
# 'nan' are now None
lfpl_books_1['ISBN'].isna().value_counts()
# Out:
# ISBN
# False    1154047
# True       27197
# Name: count, dtype: int64

# %%
# Still 27197 'nan' values
lfpl_books_1.to_csv('data\lfpl_books_1.csv',index=False)

# %%
lfpl_books_1
# Out:
#           BibNum                                              Title  \
# 0         707409  Jeff Immelt and the new GE way : innovation, t...
# 1        1341361           McGraw-Hill's American idioms dictionary
# 2         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3        1341362  McGraw-Hill's essential ESL grammar : a handbo...
# 4         707411  Robin rescues dinner : 52 weeks of quick-fix m...
# ...          ...                                                ...
# 1181239  2527332     The afrominimalist's guide to living with less
# 1181240  2527332     The afrominimalist's guide to living with less
# 1181241  2527332     The afrominimalist's guide to living with less
# 1181242  2527332     The afrominimalist's guide to living with less
# 1181243  2520634  Abstract painting : the elements of visual lan...
#
#                             Author         ISBN_x  PublicationYear ItemType  \
# 0              Magee, David, 1965-  9780071605878             2009     Book
# 1               Spears, Richard A.  9780071478939             2007     Book
# 2             Miller, Robin, 1964-  9780307451408             2009     Book
# 3                    Lester, Mark.  9780071496421             2008     Book
# 4             Miller, Robin, 1964-  9780307451408             2009     Book
# ...                            ...            ...              ...      ...
# 1181239           Platt, Christine  9781982168056             2022     Book
# 1181240           Platt, Christine  9781982168056             2022     Book
# 1181241           Platt, Christine  9781982168056             2022     Book
# 1181242           Platt, Christine  9781982168056             2022     Book
# 1181243  Davies, Jane (Ceramicist)  9780692619803             2017     Book
#
#             ItemCollection             ItemLocation  ItemPrice  \
# 0        Adult Non-Fiction                     Main      25.95
# 1           ELL Collection            South Central      20.00
# 2        Adult Non-Fiction                Southwest      19.99
# 3           ELL Collection            South Central      20.00
# 4        Adult Non-Fiction                Southwest      19.99
# ...                    ...                      ...        ...
# 1181239  Adult Non-Fiction                     Main      10.02
# 1181240  Adult Non-Fiction                  Newburg      10.02
# 1181241  Adult Non-Fiction            South Central      10.02
# 1181242  Adult Non-Fiction                  Western      10.02
# 1181243  Adult Non-Fiction  Highlands - Shelby Park      24.95
#
#                      ReportDate  ObjectId           ISBN
# 0        2022/07/01 04:00:00+00         1  9780071605878
# 1        2022/07/01 04:00:00+00         2  9780071478939
# 2        2022/07/01 04:00:00+00         3  9780307451408
# 3        2022/07/01 04:00:00+00         4  9780071496421
# 4        2022/07/01 04:00:00+00         5  9780307451408
# ...                         ...       ...            ...
# 1181239  2022/07/01 04:00:00+00   1657551  9780399544354
# 1181240  2022/07/01 04:00:00+00   1657552  9781787737372
# 1181241  2022/07/01 04:00:00+00   1657553  9780063055254
# 1181242  2022/07/01 04:00:00+00   1657554  9781974712533
# 1181243  2022/07/01 04:00:00+00   1657555  9781974712533
#
# [1181244 rows x 12 columns]

# %%
lfpl_books_1['ISBN'].isna().value_counts()
# Out:
# ISBN
# False    1154047
# True       27197
# Name: count, dtype: int64

# %% [markdown]
# ## Google API. It should be noted that the API respond with errors in too many calls are generated from the same IP address

# %%
# I used this method on the first phase but it was returning the response 429(too many requests). It had to be modified.
import requests

def find_isbn_by_book_name(book_name):
    # Define the API endpoint to search for ISBN using book names
    api_url = f"https://www.googleapis.com/books/v1/volumes?q={book_name}"
    # Using "intitle" find less ISBN numbers on the test
    #api_url = f"https://www.googleapis.com/books/v1/volumes?q=intitle:{book_name}"
    try:
        response = requests.get(api_url)
        if response.status_code == 200:
            data = response.json()
            book_response = data.get('totalItems', '')
            if book_response in (0, ""):
                return ""
            else:
                isbn = data.get('items','')[0].get('volumeInfo','').get('industryIdentifiers','')[0].get('identifier','')
                #return isbn if len(isbn) in {10, 13} else ""
                if len(isbn) in (10, 13): # Only acceptable ISBN length
                    return isbn
                else:
                    return ""
        
    except Exception as e:
        return ""
        #print(f"API request error: {str(e)}")

    return ''

# %%
# Function to apply to the DataFrame
def fill_missing_isbn(row):
    if row["ISBN"] == "nan":
        return find_isbn_by_book_name(row["Title"])
    else:
        return row["ISBN"]

# %%
# Example DataFrame
data = {
    "Title": ["Cognitive Mapping : Past, Present, and Future","LANKIE MANTITA", "WWI : the Great War, 1914-1918", "the girl in the road", "Sharp Edges", "My First Pet"],
    "ISBN": ["nan", "nan", "nan", "nan", "nan","nan"]
}

df = pd.DataFrame(data)



# Apply the function using lambda only to rows with missing ISBN
df["ISBN"] = df.apply(lambda row: fill_missing_isbn(row), axis=1)

print(df)
# Out:
#                                            Title           ISBN
# 0  Cognitive Mapping : Past, Present, and Future  9781317798071
# 1                                 LANKIE MANTITA
# 2                 WWI : the Great War, 1914-1918
# 3                           the girl in the road  9780804138864
# 4                                    Sharp Edges  9781439120118
# 5                                   My First Pet  9781465452955

# %% [markdown]
# The Google API appears to have more information than the previous one.
# The returned will be accepted if it has 10(ISBN-10) or 13(ISBN-13) characters.

# %%
# Experimenting with timing

print(f"My First Pet - ISBN: {find_isbn_by_book_name('My First Pet')}")
# Out:
# My First Pet - ISBN: 1620315491

# %%
# The following line of code might take a lot to process

#lfpl_books["ISBN"] = lfpl_books.apply(lambda row: fill_missing_isbn(row), axis=1)

# %% [markdown]
# ## Trying to use concurrent features

# %%
isbn_length
# Out:
# ISBN
# 13    1031252
# 12     102249
# 3       36430
# 11      10031
# 10       1137
# 9         140
# 8           4
# 7           1
# Name: count, dtype: int64

# %%
# Creating a copy of the dataframe with only the isbn and title columns
missing_isbn_df = lfpl_books_1[lfpl_books_1["ISBN"].isna()][["Title"]].drop_duplicates()
shape_c = missing_isbn_df.shape
print(f"Rows: {shape_c[0]:,}, Columns: {shape_c[1]}")
# Out:
# Rows: 21,245, Columns: 1

# %%
missing_isbn_df
# Out:
#                                                      Title
# 4429     Stolen legacy: the Egyptian origins of western...
# 5336     A symposium in public librarianship; three add...
# 5510                        WWI : the Great War, 1914-1918
# 5511                                        LANKIE MANTITA
# 6414                                  Pieces from the past
# ...                                                    ...
# 1180968  Never Surrender : A Soldier's Journey to the C...
# 1180971  The Secret of the Universe = Mysterium Cosmogr...
# 1180976            Mathematics : a Very Short Introduction
# 1180988                  ILL KDLA BOOK KIT - Hidden Places
# 1180994      Cognitive Mapping : Past, Present, and Future
#
# [21245 rows x 1 columns]

# %% [markdown]
# We saved a few thousands API calls removing the duplicates

# %%
# Trying to select the appropiate number of cores, depending on the CPU
import multiprocessing

def get_cpu_count():
  return multiprocessing.cpu_count()

def select_max_workers(cpu_count):
  if cpu_count <= 4:
    return cpu_count
  else:
    return int(cpu_count * 0.75)

# %%
print(select_max_workers(get_cpu_count()))
# Out:
# 18

# %%
import time

def get_isbn_from_api_with_retry(book_title, max_retries=3):
    
    #base_url = "https://www.googleapis.com/books/v1/volumes"
    #params = {"q": f"intitle:{book_title}", "maxResults": 1}

    api_url = f"https://www.googleapis.com/books/v1/volumes?q={book_title}"

    for retry in range(max_retries):
        try:
            #response = requests.get(api_url, params=params)
            response = requests.get(api_url)
            response.raise_for_status()  # Raise an HTTPError for bad responses
            data = response.json()

            # Check if any items were found
            if "items" in data and data["items"]:
                volume_info = data["items"][0]["volumeInfo"]
                isbn = volume_info.get("industryIdentifiers", [])

                # Validate ISBN length
                for identifier in isbn:
                    if identifier["type"] == "ISBN_10" and len(identifier["identifier"]) == 10:
                        return identifier["identifier"]
                    elif identifier["type"] == "ISBN_13" and len(identifier["identifier"]) == 13:
                        return identifier["identifier"]

            return ""
        except requests.exceptions.HTTPError as e:
            if e.response.status_code == 429:
                # Extract the 'Retry-After' header value
                retry_after = int(e.response.headers.get("Retry-After", 1))
                print(f"Rate limit exceeded. Retrying in {retry_after} seconds...")
                time.sleep(retry_after)
                return ""
            else:
                print(f"Error in API request: {e}")
                return ""
        except requests.exceptions.RequestException as e:
            print(f"Error in API request: {e}")
            return ""

    print(f"Exceeded maximum retries for {book_title}. Skipping...")
    return ""

# %%
def get_isbn(book_title, csvfile):
    isbn = get_isbn_from_api_with_retry(book_title)

    if isbn:
        with open(csvfile, "a", encoding="utf-8", newline="") as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow([isbn, book_title])
            print(f'Saving: {book_title}')
    return isbn

# %%
from concurrent.futures import ThreadPoolExecutor

cpu_count = get_cpu_count()
max_workers = select_max_workers(cpu_count)

with open('data/lfpl_books_2', "a", encoding="utf-8", newline="") as csvfile:
            
    with ThreadPoolExecutor( max_workers ) as executor:
        #missing_isbn_df["ISBN"] = list(executor.map(fill_missing_isbn, missing_isbn_df.itertuples(index=False)))
        missing_isbn_df["ISBN"] = list(executor.map(get_isbn_from_api_with_retry, missing_isbn_df['Title']))
        writer = csv.writer(csvfile)
        writer.writerow(missing_isbn_df['ISBN'], missing_isbn_df['Title'])
        print(f"Saving: {missing_isbn_df['Title']}")
# Out:
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL\01_Analysis.ipynb Cell 61 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=5'>6</a> with open('data/lfpl_books_2', "a", encoding="utf-8", newline="") as csvfile:
#       <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=7'>8</a>     with ThreadPoolExecutor( max_workers ) as executor:
#       <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=8'>9</a>         #missing_isbn_df["ISBN"] = list(executor.map(fill_missing_isbn, missing_isbn_df.itertuples(index=False)))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=9'>10</a>         missing_isbn_df["ISBN"] = list(executor.map(get_isbn_from_api_with_retry, missing_isbn_df['Title']))
#      <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=10'>11</a>         writer = csv.writer(csvfile)
#      <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=11'>12</a>         writer.writerow(missing_isbn_df['ISBN'], missing_isbn_df['Title'])
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %%
missing_isbn_df
# Out:
#                                                      Title
# 4429     Stolen legacy: the Egyptian origins of western...
# 5336     A symposium in public librarianship; three add...
# 5510                        WWI : the Great War, 1914-1918
# 5511                                        LANKIE MANTITA
# 6414                                  Pieces from the past
# ...                                                    ...
# 1180968  Never Surrender : A Soldier's Journey to the C...
# 1180971  The Secret of the Universe = Mysterium Cosmogr...
# 1180976            Mathematics : a Very Short Introduction
# 1180988                  ILL KDLA BOOK KIT - Hidden Places
# 1180994      Cognitive Mapping : Past, Present, and Future
#
# [21245 rows x 1 columns]

# %%
# Merge the result with the original dataframe using the title column
lfpl_books = pd.merge(lfpl_books, missing_isbn_df, on="Title", how="left", suffixes=("_old", ""))

#lfpl_books["ISBN"] = lfpl_books["ISBN_new"].combine_first(lfpl_books["ISBN"]).astype(str)  # Fill missing ISBN in the original dataframe

# Drop temporary columns
#lfpl_books = lfpl_books.drop(columns=["ISBN_new"])
lfpl_books = lfpl_books.drop(columns=["ISBN_old"])

# %%
lfpl_books['ISBN'].str.len().value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\lcabr\OneDrive\Documents\Code_Louisville\Data-Analysis-2023\Projects\LFPL\01_Analysis.ipynb Cell 46 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lcabr/OneDrive/Documents/Code_Louisville/Data-Analysis-2023/Projects/LFPL/01_Analysis.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> lfpl_books['ISBN'].str.len().value_counts()
#
# NameError: name 'lfpl_books' is not defined

# %% [markdown]
# 47 minutes and 55 seconds in a cpu with 16 cores, 24 logical procesors

# %%
lfpl_books['ISBN'].str.len().value_counts()
# Out:
# ISBN
# 13    1031252
# 12     102249
# 3       36527
# 11      10031
# 10       1137
# 9         140
# 8           4
# 7           1
# Name: count, dtype: int64

# %%
def summ_length(strings):
  """
  Summarizes a list of strings by length.

  Args:
    strings: A list of strings.

  Returns:
    A dictionary that maps string lengths to the number of strings of that length.
  """

  summary = {}

  for string in strings:
    length = len(string)

    if length not in summary:
      summary[length] = 0

    summary[length] += 1

  return summary

strings = ['hello', 'world', 'this', 'is', 'a', 'test']
summary = summ_length(results)

for length, count in summary.items():
  print(f"There are {count} strings with length {length}")
# Out:
# There are 1032881 strings with length 13
# There are 102384 strings with length 12
# There are 10036 strings with length 11
# There are 1864 strings with length 10
# There are 228 strings with length 15
# There are 31565 strings with length 0
# There are 89 strings with length 22
# There are 863 strings with length 14
# There are 152 strings with length 16
# There are 633 strings with length 18
# There are 172 strings with length 19
# There are 266 strings with length 23
# There are 46 strings with length 20
# There are 17 strings with length 17
# There are 140 strings with length 9
# There are 4 strings with length 8
# There are 1 strings with length 7

# %%
new_isbn = pd.DataFrame(results, columns=['ISBN'])
new_isbn['ISBN'].str.len().value_counts()
# Out:
# ISBN
# 13    1032881
# 12     102384
# 0       31565
# 11      10036
# 10       1864
# 14        863
# 18        633
# 23        266
# 15        228
# 19        172
# 16        152
# 9         140
# 22         89
# 20         46
# 17         17
# 8           4
# 7           1
# Name: count, dtype: int64

# %%
lfpl_books['ISBN'].str.len().value_counts()
# Out:
# ISBN
# 13    1031252
# 12     102249
# 3       36527
# 11      10031
# 10       1137
# 9         140
# 8           4
# 7           1
# Name: count, dtype: int64

# %%
new_isbn[new_isbn['ISBN'].str.len() == 17]
# Out:
#                      ISBN
# 60695   EAN:8596547062158
# 96189   EAN:4064066431020
# 102906  EAN:4064066397913
# 245348  SRLF:AX0000165175
# 252219  EAN:8596547026808
# 254818  EAN:8596547408710
# 259217  EAN:8596547378266
# 261460  EAN:8596547192480
# 262910  EAN:8596547403005
# 264185  SRLF:AA0002591691
# 265030  EAN:8596547062653
# 265509  EAN:8596547186557
# 265886  GENT:900000016407
# 272037  EAN:8596547196174
# 272038  EAN:8596547196174
# 575197  EAN:4064066059439
# 575201  EAN:4064066059439

# %%
new_isbn.shape
# Out:
# (1181341, 1)

# %%
lfpl_books.shape
# Out:
# (1181341, 12)

# %%
type(results)
# Out:
# list

# %% [markdown]
# ## Let's check the results

# %%
lfpl_books['ISBN'].isna().value_counts()
# Out:
# ISBN
# False    1181341
# Name: count, dtype: int64

# %%
lfpl_books[lfpl_books['ISBN'] == 'nan']
# Out:
#           BibNum                                              Title  \
# 4429     1348353  Stolen legacy: the Egyptian origins of western...
# 5336     1353427  A symposium in public librarianship; three add...
# 5510     1353740                     WWI : the Great War, 1914-1918
# 5511     1353780                                     LANKIE MANTITA
# 5931     2511351                                       My First Pet
# ...          ...                                                ...
# 1181091  2528085      Cognitive Mapping : Past, Present, and Future
# 1181093  2528087                                Eye of the Beholder
# 1181101  2528088                                        Sharp Edges
# 1181291  2527399                               the girl in the road
# 1181292  2527400                                      See Night Run
#
#                                                     Author ISBN  \
# 4429                                    James, George G. M  nan
# 5336     University of California, Berkeley. School of ...  nan
# 5510         Brown, Hilary (Author of Two-liners for kids)  nan
# 5511                                     LESLIE PATRICELLI  nan
# 5931                                                   NaN  nan
# ...                                                    ...  ...
# 1181091                                       Kitchin, Rob  nan
# 1181093                                      Krentz, Jayne  nan
# 1181101                                      Krentz, Jayne  nan
# 1181291                                       MONICA BYRNE  nan
# 1181292                                                NaN  nan
#
#          PublicationYear ItemType     ItemCollection            ItemLocation  \
# 4429                   0     Book  Interlibrary Loan                    Main
# 5336                1952     Book   Kentucky History                    Main
# 5510                2014     Book  Adult Non-Fiction                    Main
# 5511                   0     Book                NaN                 Shively
# 5931                   0     Book                NaN                 Newburg
# ...                  ...      ...                ...                     ...
# 1181091                0     Book  Interlibrary Loan                    Main
# 1181093                0     Book  Interlibrary Loan                    Main
# 1181101                0     Book  Interlibrary Loan                    Main
# 1181291                0     Book                NaN                    Main
# 1181292                0     Book                NaN  Childrens Main Library
#
#          ItemPrice              ReportDate  ObjectId
# 4429           0.0  2022/07/01 04:00:00+00      5055
# 5336          25.0  2022/07/01 04:00:00+00      7761
# 5510          15.0  2022/07/01 04:00:00+00      8010
# 5511           0.0  2022/07/01 04:00:00+00      8027
# 5931           0.0  2022/07/01 04:00:00+00      8588
# ...            ...                     ...       ...
# 1181091        0.0  2022/07/01 04:00:00+00   1657144
# 1181093        0.0  2022/07/01 04:00:00+00   1657147
# 1181101        0.0  2022/07/01 04:00:00+00   1657176
# 1181291        0.0  2022/07/01 04:00:00+00   1657506
# 1181292        0.0  2022/07/01 04:00:00+00   1657507
#
# [36526 rows x 11 columns]

# %%
# Finding books with no title
lfpl_books[lfpl_books['Title'].isna()]
# Out:
#          BibNum Title Author ISBN  PublicationYear ItemType ItemCollection  \
# 198351  2239375   NaN    NaN  nan                0     Book            NaN
#
#          ItemLocation  ItemPrice              ReportDate  ObjectId
# 198351  Crescent Hill        0.0  2022/07/01 04:00:00+00    243966

# %%
lfpl_books[lfpl_books['ItemCollection'].isna()]
# Out:
#           BibNum                        Title             Author ISBN  \
# 5511     1353780               LANKIE MANTITA  LESLIE PATRICELLI  nan
# 5931     2511351                 My First Pet                NaN  nan
# 6405     1362079                   Act of War        Brown, Dale  nan
# 9061     2410700                         FOUR      VERONICA ROTH  nan
# 12678    2481658     designing your work life       bill burnett  nan
# ...          ...                          ...                ...  ...
# 1180968  2528221  The Khipu and the Final Key      Dee Garretson  nan
# 1180972  2528222              MOMMY'S DISEASE     CAROLYN HANNAN  nan
# 1181047  2527377                          use                NaN  nan
# 1181291  2527399         the girl in the road       MONICA BYRNE  nan
# 1181292  2527400                See Night Run                NaN  nan
#
#          PublicationYear ItemType ItemCollection            ItemLocation  \
# 5511                   0     Book            NaN                 Shively
# 5931                   0     Book            NaN                 Newburg
# 6405                   0     Book            NaN                 Bon Air
# 9061                   0     Book            NaN           Crescent Hill
# 12678                  0     Book            NaN             St Matthews
# ...                  ...      ...            ...                     ...
# 1180968                0     Book            NaN               Northeast
# 1180972                0     Book            NaN               Southwest
# 1181047                0     Book            NaN               Northeast
# 1181291                0     Book            NaN                    Main
# 1181292                0     Book            NaN  Childrens Main Library
#
#          ItemPrice              ReportDate  ObjectId
# 5511           0.0  2022/07/01 04:00:00+00      8027
# 5931           0.0  2022/07/01 04:00:00+00      8588
# 6405           0.0  2022/07/01 04:00:00+00     10502
# 9061           0.0  2022/07/01 04:00:00+00     16849
# 12678          0.0  2022/07/01 04:00:00+00     22166
# ...            ...                     ...       ...
# 1180968        0.0  2022/07/01 04:00:00+00   1656928
# 1180972        0.0  2022/07/01 04:00:00+00   1656934
# 1181047        0.0  2022/07/01 04:00:00+00   1657039
# 1181291        0.0  2022/07/01 04:00:00+00   1657506
# 1181292        0.0  2022/07/01 04:00:00+00   1657507
#
# [201 rows x 11 columns]

# %%
lfpl_books['ItemCollection'].unique()
# Out:
# array(['Adult Non-Fiction', 'ELL Collection', 'Adult Fiction', 'Mystery',
#        "Children's Picture Book", 'Science Fiction', 'Older Teen Fiction',
#        'Younger Teen  Fiction', 'Adult Paperback', "Children's Fiction",
#        'Western', "Children's Picture Paperback", "Children's Paperback",
#        'International Collection', 'Teen Non-Fiction',
#        "Children's Non-Fiction", 'Kentucky History', 'Natural Resources',
#        'Oversize', 'Holiday', 'Urban Fiction', 'Bestsellers',
#        "Children's Board Book", 'Storytime Collection',
#        'Preschool  Picture Book', "Children's Easy Reader",
#        'Adult Reference', 'Interlibrary Loan', nan,
#        'Adult Paperbacks Tall', "Children's Easy Reader Paperback",
#        'Caldecott/Newbery', 'Laptop', 'Younger Teen  Paperback',
#        'Government Documents', 'Large Print', 'Telereference',
#        "Children's Non-Fiction Paperback", 'Big Book',
#        "Children's Reference", 'Older Teen Paperback', 'Teen Reference',
#        'College Shop', 'Magazines and Newspaper',
#        'Younger Teen  Audiobook', 'Readalongs', 'Listening Device',
#        'Adult Audiobook', 'Electronic', "Children's Music", 'Adult DVD',
#        'Music', 'Book Discussion Kit'], dtype=object)

# %%
lfpl_books['ItemCollection'].value_counts()
# Out:
# ItemCollection
# Adult Non-Fiction                   370372
# Adult Fiction                       173472
# Children's Non-Fiction               86723
# Mystery                              60152
# Children's Picture Book              58609
# Preschool  Picture Book              50564
# Children's Fiction                   47829
# Adult Paperback                      45733
# Children's Paperback                 44649
# Teen Non-Fiction                     24045
# Children's Easy Reader               24037
# Older Teen Fiction                   23476
# Children's Board Book                20180
# Younger Teen  Fiction                17227
# Kentucky History                     16766
# Science Fiction                      15714
# Children's Easy Reader Paperback     15566
# Holiday                              15482
# International Collection             15439
# Adult Reference                      11233
# Children's Picture Paperback          9638
# Urban Fiction                         7556
# Caldecott/Newbery                     6959
# Storytime Collection                  4231
# Government Documents                  3349
# Oversize                              2264
# Western                               2136
# Bestsellers                           1782
# ELL Collection                        1762
# Natural Resources                     1513
# Adult Paperbacks Tall                  758
# Younger Teen  Paperback                647
# Children's Reference                   583
# Interlibrary Loan                      159
# Older Teen Paperback                   151
# Laptop                                  96
# Children's Non-Fiction Paperback        70
# Big Book                                56
# Large Print                             53
# Readalongs                              38
# College Shop                            18
# Listening Device                        16
# Telereference                           10
# Teen Reference                           8
# Younger Teen  Audiobook                  4
# Electronic                               4
# Adult Audiobook                          3
# Adult DVD                                3
# Magazines and Newspaper                  1
# Children's Music                         1
# Music                                    1
# Book Discussion Kit                      1
# Name: count, dtype: int64
